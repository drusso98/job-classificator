# %% [markdown]
# ## TEXT PREPOCESSING

# %%
# !pip install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.2.3-py3-none-any.whl (342 kB)
#      |████████████████████████████████| 342 kB 3.2 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stanza) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from stanza) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from stanza) (4.62.0)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from stanza) (1.9.0+cu102)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from stanza) (3.17.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.0->stanza) (3.7.4.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf->stanza) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2021.5.30)
# Installing collected packages: stanza
# Successfully installed stanza-1.2.3

# %%
import stanza
import pickle

# %%
with open('dataset.pickle', 'rb') as handle:
    dataset = pickle.load(handle)

# %%
political_data = dataset["politics"]
sport_data = dataset["sport"]
science_data = dataset["scientist"]

# %%
print("Number of political documents: ", len(dataset["politics"]))
print("Number of scientific documents: ", len(dataset["scientist"]))
print("Number of sport documents: ", len(dataset["sport"]))
print("Total number of documents: ", len(dataset["politics"]) + len(dataset["scientist"]) + len(dataset["sport"]))
# Out:
# Number of political documents:  96
# Number of scientific documents:  136
# Number of sport documents:  95
# Total number of documents:  327

# %%
stanza.download('en')
nlp = stanza.Pipeline(lang="en", use_gpu=True, processors='tokenize,mwt,pos,lemma')
political_in_docs = [stanza.Document([], text=d.lower()) for d in political_data]
political_out_docs = nlp(political_in_docs)
political_in_docs[1]
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.2.2.json:   0%|   …
# 2021-09-06 14:43:10 INFO: Downloading default packages for language: en (English)...
# Downloading http://nlp.stanford.edu/software/stanza/1.2.2/en/default.zip:   0%|          | 0.00/412M [00:00<?,…
# 2021-09-06 14:44:31 INFO: Finished downloading models and saved to /root/stanza_resources.
# 2021-09-06 14:44:31 WARNING: Can not find mwt: default from official model list. Ignoring it.
# 2021-09-06 14:44:31 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# | lemma     | combined |
# ========================
#
# 2021-09-06 14:44:31 INFO: Use device: cpu
# 2021-09-06 14:44:31 INFO: Loading: tokenize
# 2021-09-06 14:44:31 INFO: Loading: pos
# 2021-09-06 14:44:32 INFO: Loading: lemma
# 2021-09-06 14:44:32 INFO: Done loading processors!
# [
#   [
#     {
#       "id": 1,
#       "text": "chief",
#       "lemma": "chief",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 1,
#       "end_char": 6
#     },
#     {
#       "id": 2,
#       "text": "justice",
#       "lemma": "justice",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 7,
#       "end_char": 14
#     },
#     {
#       "id": 3,
#       "text": "roberts",
#       "lemma": "robert",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 15,
#       "end_char": 22
#     },
#     {
#       "id": 4,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 22,
#       "end_char": 23
#     },
#     {
#       "id": 5,
#       "text": "vice",
#       "lemma": "vice",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 24,
#       "end_char": 28
#     },
#     {
#       "id": 6,
#       "text": "president",
#       "lemma": "president",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 29,
#       "end_char": 38
#     },
#     {
#       "id": 7,
#       "text": "harris",
#       "lemma": "harris",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 39,
#       "end_char": 45
#     },
#     {
#       "id": 8,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 45,
#       "end_char": 46
#     },
#     {
#       "id": 9,
#       "text": "speaker",
#       "lemma": "speaker",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 47,
#       "end_char": 54
#     },
#     {
#       "id": 10,
#       "text": "pelosi",
#       "lemma": "pelosi",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 55,
#       "end_char": 61
#     },
#     {
#       "id": 11,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 61,
#       "end_char": 62
#     },
#     {
#       "id": 12,
#       "text": "leader",
#       "lemma": "leader",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 63,
#       "end_char": 69
#     },
#     {
#       "id": 13,
#       "text": "schumer",
#       "lemma": "schumer",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 70,
#       "end_char": 77
#     },
#     {
#       "id": 14,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 77,
#       "end_char": 78
#     },
#     {
#       "id": 15,
#       "text": "leader",
#       "lemma": "leader",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 79,
#       "end_char": 85
#     },
#     {
#       "id": 16,
#       "text": "mcconnell",
#       "lemma": "mcconnell",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 86,
#       "end_char": 95
#     },
#     {
#       "id": 17,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 95,
#       "end_char": 96
#     },
#     {
#       "id": 18,
#       "text": "vice",
#       "lemma": "vice",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 97,
#       "end_char": 101
#     },
#     {
#       "id": 19,
#       "text": "president",
#       "lemma": "president",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 102,
#       "end_char": 111
#     },
#     {
#       "id": 20,
#       "text": "pence",
#       "lemma": "pence",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 112,
#       "end_char": 117
#     },
#     {
#       "id": 21,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 117,
#       "end_char": 118
#     },
#     {
#       "id": 22,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 119,
#       "end_char": 122
#     },
#     {
#       "id": 23,
#       "text": "my",
#       "lemma": "my",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Number=Sing|Person=1|Poss=Yes|PronType=Prs",
#       "start_char": 123,
#       "end_char": 125
#     },
#     {
#       "id": 24,
#       "text": "distinguished",
#       "lemma": "distinguished",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 126,
#       "end_char": 139
#     },
#     {
#       "id": 25,
#       "text": "guests",
#       "lemma": "guest",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 140,
#       "end_char": 146
#     },
#     {
#       "id": 26,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 146,
#       "end_char": 147
#     },
#     {
#       "id": 27,
#       "text": "my",
#       "lemma": "my",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Number=Sing|Person=1|Poss=Yes|PronType=Prs",
#       "start_char": 148,
#       "end_char": 150
#     },
#     {
#       "id": 28,
#       "text": "fellow",
#       "lemma": "fellow",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 151,
#       "end_char": 157
#     },
#     {
#       "id": 29,
#       "text": "americans",
#       "lemma": "American",
#       "upos": "PROPN",
#       "xpos": "NNPS",
#       "feats": "Number=Plur",
#       "start_char": 158,
#       "end_char": 167
#     },
#     {
#       "id": 30,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 167,
#       "end_char": 168
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "this",
#       "lemma": "this",
#       "upos": "PRON",
#       "xpos": "DT",
#       "feats": "Number=Sing|PronType=Dem",
#       "start_char": 169,
#       "end_char": 173
#     },
#     {
#       "id": 2,
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 174,
#       "end_char": 176
#     },
#     {
#       "id": 3,
#       "text": "america",
#       "lemma": "america",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 177,
#       "end_char": 184
#     },
#     {
#       "id": 4,
#       "text": "’s",
#       "lemma": "'s",
#       "upos": "PART",
#       "xpos": "POS",
#       "start_char": 184,
#       "end_char": 186
#     },
#     {
#       "id": 5,
#       "text": "day",
#       "lemma": "day",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 187,
#       "end_char": 190
#     },
#     {
#       "id": 6,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 190,
#       "end_char": 191
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "this",
#       "lemma": "this",
#       "upos": "PRON",
#       "xpos": "DT",
#       "feats": "Number=Sing|PronType=Dem",
#       "start_char": 192,
#       "end_char": 196
#     },
#     {
#       "id": 2,
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 197,
#       "end_char": 199
#     },
#     {
#       "id": 3,
#       "text": "democracy",
#       "lemma": "democracy",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 200,
#       "end_char": 209
#     },
#     {
#       "id": 4,
#       "text": "’s",
#       "lemma": "'s",
#       "upos": "PART",
#       "xpos": "POS",
#       "start_char": 209,
#       "end_char": 211
#     },
#     {
#       "id": 5,
#       "text": "day",
#       "lemma": "day",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 212,
#       "end_char": 215
#     },
#     {
#       "id": 6,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 215,
#       "end_char": 216
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 217,
#       "end_char": 218
#     },
#     {
#       "id": 2,
#       "text": "day",
#       "lemma": "day",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 219,
#       "end_char": 222
#     },
#     {
#       "id": 3,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 223,
#       "end_char": 225
#     },
#     {
#       "id": 4,
#       "text": "history",
#       "lemma": "history",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 226,
#       "end_char": 233
#     },
#     {
#       "id": 5,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 234,
#       "end_char": 237
#     },
#     {
#       "id": 6,
#       "text": "hope",
#       "lemma": "hope",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 238,
#       "end_char": 242
#     },
#     {
#       "id": 7,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 243,
#       "end_char": 245
#     },
#     {
#       "id": 8,
#       "text": "renewal",
#       "lemma": "renewal",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 246,
#       "end_char": 253
#     },
#     {
#       "id": 9,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 254,
#       "end_char": 257
#     },
#     {
#       "id": 10,
#       "text": "resolve",
#       "lemma": "resolve",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 258,
#       "end_char": 265
#     },
#     {
#       "id": 11,
#       "text": "through",
#       "lemma": "through",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 266,
#       "end_char": 273
#     },
#     {
#       "id": 12,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 274,
#       "end_char": 275
#     },
#     {
#       "id": 13,
#       "text": "crucible",
#       "lemma": "crucible",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 276,
#       "end_char": 284
#     },
#     {
#       "id": 14,
#       "text": "for",
#       "lemma": "for",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 285,
#       "end_char": 288
#     },
#     {
#       "id": 15,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 289,
#       "end_char": 292
#     },
#     {
#       "id": 16,
#       "text": "ages",
#       "lemma": "age",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 293,
#       "end_char": 297
#     },
#     {
#       "id": 17,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 297,
#       "end_char": 298
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "america",
#       "lemma": "america",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 299,
#       "end_char": 306
#     },
#     {
#       "id": 2,
#       "text": "has",
#       "lemma": "have",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 307,
#       "end_char": 310
#     },
#     {
#       "id": 3,
#       "text": "been",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 311,
#       "end_char": 315
#     },
#     {
#       "id": 4,
#       "text": "tested",
#       "lemma": "test",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "start_char": 316,
#       "end_char": 322
#     },
#     {
#       "id": 5,
#       "text": "anew",
#       "lemma": "anew",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 323,
#       "end_char": 327
#     },
#     {
#       "id": 6,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 328,
#       "end_char": 331
#     },
#     {
#       "id": 7,
#       "text": "america",
#       "lemma": "america",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 332,
#       "end_char": 339
#     },
#     {
#       "id": 8,
#       "text": "has",
#       "lemma": "have",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 340,
#       "end_char": 343
#     },
#     {
#       "id": 9,
#       "text": "risen",
#       "lemma": "rise",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 344,
#       "end_char": 349
#     },
#     {
#       "id": 10,
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 350,
#       "end_char": 352
#     },
#     {
#       "id": 11,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 353,
#       "end_char": 356
#     },
#     {
#       "id": 12,
#       "text": "challenge",
#       "lemma": "challenge",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 357,
#       "end_char": 366
#     },
#     {
#       "id": 13,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 366,
#       "end_char": 367
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "today",
#       "lemma": "today",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 368,
#       "end_char": 373
#     },
#     {
#       "id": 2,
#       "text": "we",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "start_char": 374,
#       "end_char": 376
#     },
#     {
#       "id": 3,
#       "text": "celebrate",
#       "lemma": "celebrate",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin",
#       "start_char": 377,
#       "end_char": 386
#     },
#     {
#       "id": 4,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 387,
#       "end_char": 390
#     },
#     {
#       "id": 5,
#       "text": "triumph",
#       "lemma": "triumph",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 391,
#       "end_char": 398
#     },
#     {
#       "id": 6,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 398,
#       "end_char": 399
#     },
#     {
#       "id": 7,
#       "text": "not",
#       "lemma": "not",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 400,
#       "end_char": 403
#     },
#     {
#       "id": 8,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 404,
#       "end_char": 406
#     },
#     {
#       "id": 9,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 407,
#       "end_char": 408
#     },
#     {
#       "id": 10,
#       "text": "candidate",
#       "lemma": "candidate",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 409,
#       "end_char": 418
#     },
#     {
#       "id": 11,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 418,
#       "end_char": 419
#     },
#     {
#       "id": 12,
#       "text": "but",
#       "lemma": "but",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 420,
#       "end_char": 423
#     },
#     {
#       "id": 13,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 424,
#       "end_char": 426
#     },
#     {
#       "id": 14,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 427,
#       "end_char": 428
#     },
#     {
#       "id": 15,
#       "text": "cause",
#       "lemma": "cause",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 429,
#       "end_char": 434
#     },
#     {
#       "id": 16,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 434,
#       "end_char": 435
#     },
#     {
#       "id": 17,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 436,
#       "end_char": 439
#     },
#     {
#       "id": 18,
#       "text": "cause",
#       "lemma": "cause",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 440,
#       "end_char": 445
#     },
#     {
#       "id": 19,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 446,
#       "end_char": 448
#     },
#     {
#       "id": 20,
#       "text": "democracy",
#       "lemma": "democracy",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 449,
#       "end_char": 458
#     },
#     {
#       "id": 21,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 458,
#       "end_char": 459
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 460,
#       "end_char": 463
#     },
#     {
#       "id": 2,
#       "text": "people",
#       "lemma": "people",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 464,
#       "end_char": 470
#     },
#     {
#       "id": 3,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 470,
#       "end_char": 471
#     },
#     {
#       "id": 4,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 472,
#       "end_char": 475
#     },
#     {
#       "id": 5,
#       "text": "will",
#       "lemma": "will",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 476,
#       "end_char": 480
#     },
#     {
#       "id": 6,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 481,
#       "end_char": 483
#     },
#     {
#       "id": 7,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 484,
#       "end_char": 487
#     },
#     {
#       "id": 8,
#       "text": "people",
#       "lemma": "people",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 488,
#       "end_char": 494
#     },
#     {
#       "id": 9,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 494,
#       "end_char": 495
#     },
#     {
#       "id": 10,
#       "text": "has",
#       "lemma": "have",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 496,
#       "end_char": 499
#     },
#     {
#       "id": 11,
#       "text": "been",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 500,
#       "end_char": 504
#     },
#     {
#       "id": 12,
#       "text": "heard",
#       "lemma": "hear",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "start_char": 505,
#       "end_char": 510
#     },
#     {
#       "id": 13,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 511,
#       "end_char": 514
#     },
#     {
#       "id": 14,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 515,
#       "end_char": 518
#     },
#     {
#       "id": 15,
#       "text": "will",
#       "lemma": "will",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 519,
#       "end_char": 523
#     },
#     {
#       "id": 16,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 524,
#       "end_char": 526
#     },
#     {
#       "id": 17,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 527,
#       "end_char": 530
#     },
#     {
#       "id": 18,
#       "text": "people",
#       "lemma": "people",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 531,
#       "end_char": 537
#     },
#     {
#       "id": 19,
#       "text": "has",
#       "lemma": "have",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 538,
#       "end_char": 541
#     },
#     {
#       "id": 20,
#       "text": "been",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 542,
#       "end_char": 546
#     },
#     {
#       "id": 21,
#       "text": "heeded",
#       "lemma": "heed",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "start_char": 547,
#       "end_char": 553
#     },
#     {
#       "id": 22,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 553,
#       "end_char": 554
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "we",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "start_char": 555,
#       "end_char": 557
#     },
#     {
#       "id": 2,
#       "text": "’ve",
#       "lemma": "have",
#       "upos": "AUX",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 557,
#       "end_char": 560
#     },
#     {
#       "id": 3,
#       "text": "learned",
#       "lemma": "learn",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 561,
#       "end_char": 568
#     },
#     {
#       "id": 4,
#       "text": "again",
#       "lemma": "again",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 569,
#       "end_char": 574
#     },
#     {
#       "id": 5,
#       "text": "that",
#       "lemma": "that",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 575,
#       "end_char": 579
#     },
#     {
#       "id": 6,
#       "text": "democracy",
#       "lemma": "democracy",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 580,
#       "end_char": 589
#     },
#     {
#       "id": 7,
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 590,
#       "end_char": 592
#     },
#     {
#       "id": 8,
#       "text": "precious",
#       "lemma": "precious",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 593,
#       "end_char": 601
#     },
#     {
#       "id": 9,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 601,
#       "end_char": 602
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "democracy",
#       "lemma": "democracy",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 603,
#       "end_char": 612
#     },
#     {
#       "id": 2,
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 613,
#       "end_char": 615
#     },
#     {
#       "id": 3,
#       "text": "fragile",
#       "lemma": "fragile",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 616,
#       "end_char": 623
#     },
#     {
#       "id": 4,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 623,
#       "end_char": 624
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 625,
#       "end_char": 628
#     },
#     {
#       "id": 2,
#       "text": "at",
#       "lemma": "at",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 629,
#       "end_char": 631
#     },
#     {
#       "id": 3,
#       "text": "this",
#       "lemma": "this",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Number=Sing|PronType=Dem",
#       "start_char": 632,
#       "end_char": 636
#     },
#     {
#       "id": 4,
#       "text": "hour",
#       "lemma": "hour",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 637,
#       "end_char": 641
#     },
#     {
#       "id": 5,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 641,
#       "end_char": 642
#     },
#     {
#       "id": 6,
#       "text": "my",
#       "lemma": "my",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Number=Sing|Person=1|Poss=Yes|PronType=Prs",
#       "start_char": 643,
#       "end_char": 645
#     },
#     {
#       "id": 7,
#       "text": "friends",
#       "lemma": "friend",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 646,
#       "end_char": 653
#     },
#     {
#       "id": 8,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 653,
#       "end_char": 654
#     },
#     {
#       "id": 9,
#       "text": "democracy",
#       "lemma": "democracy",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 655,
#       "end_char": 664
#     },
#     {
#       "id": 10,
#       "text": "has",
#       "lemma": "have",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 665,
#       "end_char": 668
#     },
#     {
#       "id": 11,
#       "text": "prevailed",
#       "lemma": "prevail",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 669,
#       "end_char": 678
#     },
#     {
#       "id": 12,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 678,
#       "end_char": 679
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "so",
#       "lemma": "so",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 680,
#       "end_char": 682
#     },
#     {
#       "id": 2,
#       "text": "now",
#       "lemma": "now",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 683,
#       "end_char": 686
#     },
#     {
#       "id": 3,
#       "text": "on",
#       "lemma": "on",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 687,
#       "end_char": 689
#     },
#     {
#       "id": 4,
#       "text": "this",
#       "lemma": "this",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Number=Sing|PronType=Dem",
#       "start_char": 690,
#       "end_char": 694
#     },
#     {
#       "id": 5,
#       "text": "hallowed",
#       "lemma": "hallow",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 695,
#       "end_char": 703
#     },
#     {
#       "id": 6,
#       "text": "ground",
#       "lemma": "ground",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 704,
#       "end_char": 710
#     },
#     {
#       "id": 7,
#       "text": "where",
#       "lemma": "where",
#       "upos": "SCONJ",
#       "xpos": "WRB",
#       "feats": "PronType=Rel",
#       "start_char": 711,
#       "end_char": 716
#     },
#     {
#       "id": 8,
#       "text": "just",
#       "lemma": "just",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 717,
#       "end_char": 721
#     },
#     {
#       "id": 9,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 722,
#       "end_char": 723
#     },
#     {
#       "id": 10,
#       "text": "few",
#       "lemma": "few",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 724,
#       "end_char": 727
#     },
#     {
#       "id": 11,
#       "text": "days",
#       "lemma": "day",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 728,
#       "end_char": 732
#     },
#     {
#       "id": 12,
#       "text": "ago",
#       "lemma": "ago",
#       "upos": "ADV",
#       "xpos": "RB",
#       "feats": "Degree=Pos",
#       "start_char": 733,
#       "end_char": 736
#     },
#     {
#       "id": 13,
#       "text": "violence",
#       "lemma": "violence",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 737,
#       "end_char": 745
#     },
#     {
#       "id": 14,
#       "text": "sought",
#       "lemma": "seek",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Person=3|Tense=Past|VerbForm=Fin",
#       "start_char": 746,
#       "end_char": 752
#     },
#     {
#       "id": 15,
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "start_char": 753,
#       "end_char": 755
#     },
#     {
#       "id": 16,
#       "text": "shake",
#       "lemma": "shake",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 756,
#       "end_char": 761
#     },
#     {
#       "id": 17,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 762,
#       "end_char": 765
#     },
#     {
#       "id": 18,
#       "text": "capital",
#       "lemma": "capital",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 766,
#       "end_char": 773
#     },
#     {
#       "id": 19,
#       "text": "’s",
#       "lemma": "'s",
#       "upos": "PART",
#       "xpos": "POS",
#       "start_char": 773,
#       "end_char": 775
#     },
#     {
#       "id": 20,
#       "text": "very",
#       "lemma": "very",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 776,
#       "end_char": 780
#     },
#     {
#       "id": 21,
#       "text": "foundation",
#       "lemma": "foundation",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 781,
#       "end_char": 791
#     },
#     {
#       "id": 22,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 791,
#       "end_char": 792
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "we",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "start_char": 793,
#       "end_char": 795
#     },
#     {
#       "id": 2,
#       "text": "come",
#       "lemma": "come",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin",
#       "start_char": 796,
#       "end_char": 800
#     },
#     {
#       "id": 3,
#       "text": "together",
#       "lemma": "together",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 801,
#       "end_char": 809
#     },
#     {
#       "id": 4,
#       "text": "as",
#       "lemma": "as",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 810,
#       "end_char": 812
#     },
#     {
#       "id": 5,
#       "text": "one",
#       "lemma": "one",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 813,
#       "end_char": 816
#     },
#     {
#       "id": 6,
#       "text": "nation",
#       "lemma": "nation",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 817,
#       "end_char": 823
#     },
#     {
#       "id": 7,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 823,
#       "end_char": 824
#     },
#     {
#       "id": 8,
#       "text": "under",
#       "lemma": "under",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 825,
#       "end_char": 830
#     },
#     {
#       "id": 9,
#       "text": "god",
#       "lemma": "god",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 831,
#       "end_char": 834
#     },
#     {
#       "id": 10,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 834,
#       "end_char": 835
#     },
#     {
#       "id": 11,
#       "text": "indivisible",
#       "lemma": "indivisible",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 836,
#       "end_char": 847
#     },
#     {
#       "id": 12,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 847,
#       "end_char": 848
#     },
#     {
#       "id": 13,
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "start_char": 849,
#       "end_char": 851
#     },
#     {
#       "id": 14,
#       "text": "carry",
#       "lemma": "carry",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 852,
#       "end_char": 857
#     },
#     {
#       "id": 15,
#       "text": "out",
#       "lemma": "out",
#       "upos": "ADP",
#       "xpos": "RP",
#       "start_char": 858,
#       "end_char": 861
#     },
#     {
#       "id": 16,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 862,
#       "end_char": 865
#     },
#     {
#       "id": 17,
#       "text": "peaceful",
#       "lemma": "peaceful",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 866,
#       "end_char": 874
#     },
#     {
#       "id": 18,
#       "text": "transfer",
#       "lemma": "transfer",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 875,
#       "end_char": 883
#     },
#     {
#       "id": 19,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 884,
#       "end_char": 886
#     },
#     {
#       "id": 20,
#       "text": "power",
#       "lemma": "power",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 887,
#       "end_char": 892
#     },
#     {
#       "id": 21,
#       "text": "as",
#       "lemma": "as",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 893,
#       "end_char": 895
#     },
#     {
#       "id": 22,
#       "text": "we",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "start_char": 896,
#       "end_char": 898
#     },
#     {
#       "id": 23,
#       "text": "have",
#       "lemma": "have",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Number=Plur|Tense=Pres|VerbForm=Fin",
#       "start_char": 899,
#       "end_char": 903
#     },
#     {
#       "id": 24,
#       "text": "for",
#       "lemma": "for",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 904,
#       "end_char": 907
#     },
#     {
#       "id": 25,
#       "text": "more",
#       "lemma": "more",
#       "upos": "ADJ",
#       "xpos": "JJR",
#       "feats": "Degree=Cmp",
#       "start_char": 908,
#       "end_char": 912
#     },
#     {
#       "id": 26,
#       "text": "than",
#       "lemma": "than",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 913,
#       "end_char": 917
#     },
#     {
#       "id": 27,
#       "text": "two",
#       "lemma": "two",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 918,
#       "end_char": 921
#     },
#     {
#       "id": 28,
#       "text": "centuries",
#       "lemma": "century",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 922,
#       "end_char": 931
#     },
#     {
#       "id": 29,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 931,
#       "end_char": 932
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "as",
#       "lemma": "as",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 933,
#       "end_char": 935
#     },
#     {
#       "id": 2,
#       "text": "we",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "start_char": 936,
#       "end_char": 938
#     },
#     {
#       "id": 3,
#       "text": "look",
#       "lemma": "look",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 939,
#       "end_char": 943
#     },
#     {
#       "id": 4,
#       "text": "ahead",
#       "lemma": "ahead",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 944,
#       "end_char": 949
#     },
#     {
#       "id": 5,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 950,
#       "end_char": 952
#     },
#     {
#       "id": 6,
#       "text": "our",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Number=Plur|Person=1|Poss=Yes|PronType=Prs",
#       "start_char": 953,
#       "end_char": 956
#     },
#     {
#       "id": 7,
#       "text": "uniquely",
#       "lemma": "uniquely",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 957,
#       "end_char": 965
#     },
#     {
#       "id": 8,
#       "text": "american",
#       "lemma": "American",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 966,
#       "end_char": 974
#     },
#     {
#       "id": 9,
#       "text": "way",
#       "lemma": "way",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 975,
#       "end_char": 978
#     },
#     {
#       "id": 10,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 978,
#       "end_char": 979
#     },
#     {
#       "id": 11,
#       "text": "restless",
#       "lemma": "restless",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 980,
#       "end_char": 988
#     },
#     {
#       "id": 12,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 988,
#       "end_char": 989
#     },
#     {
#       "id": 13,
#       "text": "bold",
#       "lemma": "bold",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 990,
#       "end_char": 994
#     },
#     {
#       "id": 14,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 994,
#       "end_char": 995
#     },
#     {
#       "id": 15,
#       "text": "optimistic",
#       "lemma": "optimistic",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 996,
#       "end_char": 1006
#     },
#     {
#       "id": 16,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 1006,
#       "end_char": 1007
#     },
#     {
#       "id": 17,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 1008,
#       "end_char": 1011
#     },
#     {
#       "id": 18,
#       "text": "set",
#       "lemma": "set",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Tense=Past|VerbForm=Fin",
#       "start_char": 1012,
#       "end_char": 1015
#     },
#     {
#       "id": 19,
#       "text": "our",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Number=Plur|Person=1|Poss=Yes|PronType=Prs",
#       "start_char": 1016,
#       "end_char": 1019
#     },
#     {
#       "id": 20,
#       "text": "sights",
#       "lemma": "sight",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 1020,
#       "end_char": 1026
#     },
#     {
#       "id": 21,
#       "text": "on",
#       "lemma": "on",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 1027,
#       "end_char": 1029
#     },
#     {
#       "id": 22,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 1030,
#       "end_char": 1033
#     },
#     {
#       "id": 23,
#       "text": "nation",
#       "lemma": "nation",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1034,
#       "end_char": 1040
#     },
#     {
#       "id": 24,
#       "text": "we",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "start_char": 1041,
#       "end_char": 1043
#     },
#     {
#       "id": 25,
#       "text": "know",
#       "lemma": "know",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 1044,
#       "end_char": 1048
#     },
#     {
#       "id": 26,
#       "text": "we",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "start_char": 1049,
#       "end_char": 1051
#     },
#     {
#       "id": 27,
#       "text": "can",
#       "lemma": "can",
#       "upos": "AUX",
#       "xpos": "MD",
#       "feats": "VerbForm=Fin",
#       "start_char": 1052,
#       "end_char": 1055
#     },
#     {
#       "id": 28,
#       "text": "be",
#       "lemma": "be",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 1056,
#       "end_char": 1058
#     },
#     {
#       "id": 29,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 1058,
#       "end_char": 1059
#     },
#     {
#       "id": 30,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 1060,
#       "end_char": 1063
#     },
#     {
#       "id": 31,
#       "text": "we",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "start_char": 1064,
#       "end_char": 1066
#     },
#     {
#       "id": 32,
#       "text": "must",
#       "lemma": "must",
#       "upos": "AUX",
#       "xpos": "MD",
#       "feats": "VerbForm=Fin",
#       "start_char": 1067,
#       "end_char": 1071
#     },
#     {
#       "id": 33,
#       "text": "be",
#       "lemma": "be",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 1072,
#       "end_char": 1074
#     },
#     {
#       "id": 34,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 1074,
#       "end_char": 1075
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "i",
#       "lemma": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 1076,
#       "end_char": 1077
#     },
#     {
#       "id": 2,
#       "text": "thank",
#       "lemma": "thank",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 1078,
#       "end_char": 1083
#     },
#     {
#       "id": 3,
#       "text": "my",
#       "lemma": "my",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Number=Sing|Person=1|Poss=Yes|PronType=Prs",
#       "start_char": 1084,
#       "end_char": 1086
#     },
#     {
#       "id": 4,
#       "text": "predecessors",
#       "lemma": "predecessor",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 1087,
#       "end_char": 1099
#     },
#     {
#       "id": 5,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 1100,
#       "end_char": 1102
#     },
#     {
#       "id": 6,
#       "text": "both",
#       "lemma": "both",
#       "upos": "DET",
#       "xpos": "DT",
#       "start_char": 1103,
#       "end_char": 1107
#     },
#     {
#       "id": 7,
#       "text": "parties",
#       "lemma": "party",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 1108,
#       "end_char": 1115
#     },
#     {
#       "id": 8,
#       "text": "for",
#       "lemma": "for",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 1116,
#       "end_char": 1119
#     },
#     {
#       "id": 9,
#       "text": "their",
#       "lemma": "they",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Number=Plur|Person=3|Poss=Yes|PronType=Prs",
#       "start_char": 1120,
#       "end_char": 1125
#     },
#     {
#       "id": 10,
#       "text": "presence",
#       "lemma": "presence",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1126,
#       "end_char": 1134
#     },
#     {
#       "id": 11,
#       "text": "here",
#       "lemma": "here",
#       "upos": "ADV",
#       "xpos": "RB",
#       "feats": "PronType=Dem",
#       "start_char": 1135,
#       "end_char": 1139
#     },
#     {
#       "id": 12,
#       "text": "today",
#       "lemma": "today",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1140,
#       "end_char": 1145
#     },
#     {
#       "id": 13,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 1145,
#       "end_char": 1146
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "i",
#       "lemma": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 1147,
#       "end_char": 1148
#     },
#     {
#       "id": 2,
#       "text": "thank",
#       "lemma": "thank",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 1149,
#       "end_char": 1154
#     },
#     {
#       "id": 3,
#       "text": "them",
#       "lemma": "they",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Number=Plur|Person=3|PronType=Prs",
#       "start_char": 1155,
#       "end_char": 1159
#     },
#     {
#       "id": 4,
#       "text": "from",
#       "lemma": "from",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 1160,
#       "end_char": 1164
#     },
#     {
#       "id": 5,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 1165,
#       "end_char": 1168
#     },
#     {
#       "id": 6,
#       "text": "bottom",
#       "lemma": "bottom",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1169,
#       "end_char": 1175
#     },
#     {
#       "id": 7,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 1176,
#       "end_char": 1178
#     },
#     {
#       "id": 8,
#       "text": "my",
#       "lemma": "my",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Number=Sing|Person=1|Poss=Yes|PronType=Prs",
#       "start_char": 1179,
#       "end_char": 1181
#     },
#     {
#       "id": 9,
#       "text": "heart",
#       "lemma": "heart",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1182,
#       "end_char": 1187
#     },
#     {
#       "id": 10,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 1187,
#       "end_char": 1188
#     },
#     {
#       "id": 11,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
# ...
#       "feats": "Number=Sing",
#       "start_char": 13343,
#       "end_char": 13350
#     },
#     {
#       "id": 3,
#       "text": "secured",
#       "lemma": "secure",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "start_char": 13351,
#       "end_char": 13358
#     },
#     {
#       "id": 4,
#       "text": "liberty",
#       "lemma": "liberty",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 13359,
#       "end_char": 13366
#     },
#     {
#       "id": 5,
#       "text": "at",
#       "lemma": "at",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 13367,
#       "end_char": 13369
#     },
#     {
#       "id": 6,
#       "text": "home",
#       "lemma": "home",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 13370,
#       "end_char": 13374
#     },
#     {
#       "id": 7,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 13375,
#       "end_char": 13378
#     },
#     {
#       "id": 8,
#       "text": "stood",
#       "lemma": "stand",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "start_char": 13379,
#       "end_char": 13384
#     },
#     {
#       "id": 9,
#       "text": "once",
#       "lemma": "once",
#       "upos": "ADV",
#       "xpos": "RB",
#       "feats": "NumType=Mult",
#       "start_char": 13385,
#       "end_char": 13389
#     },
#     {
#       "id": 10,
#       "text": "again",
#       "lemma": "again",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 13390,
#       "end_char": 13395
#     },
#     {
#       "id": 11,
#       "text": "as",
#       "lemma": "as",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 13396,
#       "end_char": 13398
#     },
#     {
#       "id": 12,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 13399,
#       "end_char": 13400
#     },
#     {
#       "id": 13,
#       "text": "beacon",
#       "lemma": "beacon",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 13401,
#       "end_char": 13407
#     },
#     {
#       "id": 14,
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 13408,
#       "end_char": 13410
#     },
#     {
#       "id": 15,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 13411,
#       "end_char": 13414
#     },
#     {
#       "id": 16,
#       "text": "world",
#       "lemma": "world",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 13415,
#       "end_char": 13420
#     },
#     {
#       "id": 17,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 13420,
#       "end_char": 13421
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "that",
#       "lemma": "that",
#       "upos": "PRON",
#       "xpos": "DT",
#       "feats": "Number=Sing|PronType=Dem",
#       "start_char": 13422,
#       "end_char": 13426
#     },
#     {
#       "id": 2,
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 13427,
#       "end_char": 13429
#     },
#     {
#       "id": 3,
#       "text": "what",
#       "lemma": "what",
#       "upos": "PRON",
#       "xpos": "WP",
#       "feats": "PronType=Int",
#       "start_char": 13430,
#       "end_char": 13434
#     },
#     {
#       "id": 4,
#       "text": "we",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "start_char": 13435,
#       "end_char": 13437
#     },
#     {
#       "id": 5,
#       "text": "owe",
#       "lemma": "owe",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 13438,
#       "end_char": 13441
#     },
#     {
#       "id": 6,
#       "text": "our",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Number=Plur|Person=1|Poss=Yes|PronType=Prs",
#       "start_char": 13442,
#       "end_char": 13445
#     },
#     {
#       "id": 7,
#       "text": "forebearers",
#       "lemma": "forebearer",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 13446,
#       "end_char": 13457
#     },
#     {
#       "id": 8,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 13457,
#       "end_char": 13458
#     },
#     {
#       "id": 9,
#       "text": "one",
#       "lemma": "one",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 13459,
#       "end_char": 13462
#     },
#     {
#       "id": 10,
#       "text": "another",
#       "lemma": "another",
#       "upos": "DET",
#       "xpos": "DT",
#       "start_char": 13463,
#       "end_char": 13470
#     },
#     {
#       "id": 11,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 13471,
#       "end_char": 13474
#     },
#     {
#       "id": 12,
#       "text": "generation",
#       "lemma": "generation",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 13475,
#       "end_char": 13485
#     },
#     {
#       "id": 13,
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "start_char": 13486,
#       "end_char": 13488
#     },
#     {
#       "id": 14,
#       "text": "follow",
#       "lemma": "follow",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 13489,
#       "end_char": 13495
#     },
#     {
#       "id": 15,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 13495,
#       "end_char": 13496
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "so",
#       "lemma": "so",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 13497,
#       "end_char": 13499
#     },
#     {
#       "id": 2,
#       "text": "with",
#       "lemma": "with",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 13500,
#       "end_char": 13504
#     },
#     {
#       "id": 3,
#       "text": "purpose",
#       "lemma": "purpose",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 13505,
#       "end_char": 13512
#     },
#     {
#       "id": 4,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 13513,
#       "end_char": 13516
#     },
#     {
#       "id": 5,
#       "text": "resolve",
#       "lemma": "resolve",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "Mood=Imp|VerbForm=Fin",
#       "start_char": 13517,
#       "end_char": 13524
#     },
#     {
#       "id": 6,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 13524,
#       "end_char": 13525
#     },
#     {
#       "id": 7,
#       "text": "we",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "start_char": 13526,
#       "end_char": 13528
#     },
#     {
#       "id": 8,
#       "text": "turn",
#       "lemma": "turn",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 13529,
#       "end_char": 13533
#     },
#     {
#       "id": 9,
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 13534,
#       "end_char": 13536
#     },
#     {
#       "id": 10,
#       "text": "those",
#       "lemma": "that",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Number=Plur|PronType=Dem",
#       "start_char": 13537,
#       "end_char": 13542
#     },
#     {
#       "id": 11,
#       "text": "task",
#       "lemma": "task",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 13543,
#       "end_char": 13547
#     },
#     {
#       "id": 12,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 13548,
#       "end_char": 13550
#     },
#     {
#       "id": 13,
#       "text": "our",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Number=Plur|Person=1|Poss=Yes|PronType=Prs",
#       "start_char": 13551,
#       "end_char": 13554
#     },
#     {
#       "id": 14,
#       "text": "time",
#       "lemma": "time",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 13555,
#       "end_char": 13559
#     },
#     {
#       "id": 15,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 13559,
#       "end_char": 13560
#     },
#     {
#       "id": 16,
#       "text": "sustained",
#       "lemma": "sustain",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 13561,
#       "end_char": 13570
#     },
#     {
#       "id": 17,
#       "text": "by",
#       "lemma": "by",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 13571,
#       "end_char": 13573
#     },
#     {
#       "id": 18,
#       "text": "faith",
#       "lemma": "faith",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 13574,
#       "end_char": 13579
#     },
#     {
#       "id": 19,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 13579,
#       "end_char": 13580
#     },
#     {
#       "id": 20,
#       "text": "driven",
#       "lemma": "drive",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 13581,
#       "end_char": 13587
#     },
#     {
#       "id": 21,
#       "text": "by",
#       "lemma": "by",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 13588,
#       "end_char": 13590
#     },
#     {
#       "id": 22,
#       "text": "conviction",
#       "lemma": "conviction",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 13591,
#       "end_char": 13601
#     },
#     {
#       "id": 23,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 13601,
#       "end_char": 13602
#     },
#     {
#       "id": 24,
#       "text": "devoted",
#       "lemma": "devote",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 13603,
#       "end_char": 13610
#     },
#     {
#       "id": 25,
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 13611,
#       "end_char": 13613
#     },
#     {
#       "id": 26,
#       "text": "one",
#       "lemma": "one",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 13614,
#       "end_char": 13617
#     },
#     {
#       "id": 27,
#       "text": "another",
#       "lemma": "another",
#       "upos": "DET",
#       "xpos": "DT",
#       "start_char": 13618,
#       "end_char": 13625
#     },
#     {
#       "id": 28,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 13626,
#       "end_char": 13629
#     },
#     {
#       "id": 29,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 13630,
#       "end_char": 13633
#     },
#     {
#       "id": 30,
#       "text": "country",
#       "lemma": "country",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 13634,
#       "end_char": 13641
#     },
#     {
#       "id": 31,
#       "text": "we",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "start_char": 13642,
#       "end_char": 13644
#     },
#     {
#       "id": 32,
#       "text": "love",
#       "lemma": "love",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 13645,
#       "end_char": 13649
#     },
#     {
#       "id": 33,
#       "text": "with",
#       "lemma": "with",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 13650,
#       "end_char": 13654
#     },
#     {
#       "id": 34,
#       "text": "all",
#       "lemma": "all",
#       "upos": "DET",
#       "xpos": "PDT",
#       "start_char": 13655,
#       "end_char": 13658
#     },
#     {
#       "id": 35,
#       "text": "our",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Number=Plur|Person=1|Poss=Yes|PronType=Prs",
#       "start_char": 13659,
#       "end_char": 13662
#     },
#     {
#       "id": 36,
#       "text": "hearts",
#       "lemma": "heart",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 13663,
#       "end_char": 13669
#     },
#     {
#       "id": 37,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 13669,
#       "end_char": 13670
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "may",
#       "lemma": "may",
#       "upos": "AUX",
#       "xpos": "MD",
#       "feats": "VerbForm=Fin",
#       "start_char": 13671,
#       "end_char": 13674
#     },
#     {
#       "id": 2,
#       "text": "god",
#       "lemma": "god",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 13675,
#       "end_char": 13678
#     },
#     {
#       "id": 3,
#       "text": "bless",
#       "lemma": "bless",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 13679,
#       "end_char": 13684
#     },
#     {
#       "id": 4,
#       "text": "america",
#       "lemma": "america",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 13685,
#       "end_char": 13692
#     },
#     {
#       "id": 5,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 13693,
#       "end_char": 13696
#     },
#     {
#       "id": 6,
#       "text": "may",
#       "lemma": "may",
#       "upos": "AUX",
#       "xpos": "MD",
#       "feats": "VerbForm=Fin",
#       "start_char": 13697,
#       "end_char": 13700
#     },
#     {
#       "id": 7,
#       "text": "god",
#       "lemma": "god",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 13701,
#       "end_char": 13704
#     },
#     {
#       "id": 8,
#       "text": "protect",
#       "lemma": "protect",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 13705,
#       "end_char": 13712
#     },
#     {
#       "id": 9,
#       "text": "our",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Number=Plur|Person=1|Poss=Yes|PronType=Prs",
#       "start_char": 13713,
#       "end_char": 13716
#     },
#     {
#       "id": 10,
#       "text": "troops",
#       "lemma": "troops",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 13717,
#       "end_char": 13723
#     },
#     {
#       "id": 11,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 13723,
#       "end_char": 13724
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "thank",
#       "lemma": "thank",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 13725,
#       "end_char": 13730
#     },
#     {
#       "id": 2,
#       "text": "you",
#       "lemma": "you",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Person=2|PronType=Prs",
#       "start_char": 13731,
#       "end_char": 13734
#     },
#     {
#       "id": 3,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 13734,
#       "end_char": 13735
#     },
#     {
#       "id": 4,
#       "text": "america",
#       "lemma": "america",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 13736,
#       "end_char": 13743
#     },
#     {
#       "id": 5,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 13743,
#       "end_char": 13744
#     }
#   ]
# ]

# %%
sport_in_docs = [stanza.Document([], text=d.lower()) for d in sport_data]
sport_out_docs = nlp(sport_in_docs)
sport_in_docs[1]
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "thank",
#       "lemma": "thank",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 1,
#       "end_char": 6
#     },
#     {
#       "id": 2,
#       "text": "you",
#       "lemma": "you",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Person=2|PronType=Prs",
#       "start_char": 7,
#       "end_char": 10
#     },
#     {
#       "id": 3,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 10,
#       "end_char": 11
#     },
#     {
#       "id": 4,
#       "text": "guys",
#       "lemma": "guy",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 12,
#       "end_char": 16
#     },
#     {
#       "id": 5,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 16,
#       "end_char": 17
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "thank",
#       "lemma": "thank",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 18,
#       "end_char": 23
#     },
#     {
#       "id": 2,
#       "text": "you",
#       "lemma": "you",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Person=2|PronType=Prs",
#       "start_char": 24,
#       "end_char": 27
#     },
#     {
#       "id": 3,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 27,
#       "end_char": 28
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "congratulations",
#       "lemma": "congratulation",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 29,
#       "end_char": 44
#     },
#     {
#       "id": 2,
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 45,
#       "end_char": 47
#     },
#     {
#       "id": 3,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 48,
#       "end_char": 51
#     },
#     {
#       "id": 4,
#       "text": "class",
#       "lemma": "class",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 52,
#       "end_char": 57
#     },
#     {
#       "id": 5,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 58,
#       "end_char": 60
#     },
#     {
#       "id": 6,
#       "text": "2020",
#       "lemma": "2020",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 61,
#       "end_char": 65
#     },
#     {
#       "id": 7,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 65,
#       "end_char": 66
#     },
#     {
#       "id": 8,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 67,
#       "end_char": 70
#     },
#     {
#       "id": 9,
#       "text": "class",
#       "lemma": "class",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 71,
#       "end_char": 76
#     },
#     {
#       "id": 10,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 77,
#       "end_char": 79
#     },
#     {
#       "id": 11,
#       "text": "2021",
#       "lemma": "2021",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 80,
#       "end_char": 84
#     },
#     {
#       "id": 12,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 84,
#       "end_char": 85
#     },
#     {
#       "id": 13,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 86,
#       "end_char": 89
#     },
#     {
#       "id": 14,
#       "text": "welcome",
#       "lemma": "welcome",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Fin",
#       "start_char": 90,
#       "end_char": 97
#     },
#     {
#       "id": 15,
#       "text": "back",
#       "lemma": "back",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 98,
#       "end_char": 102
#     },
#     {
#       "id": 16,
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "start_char": 103,
#       "end_char": 105
#     },
#     {
#       "id": 17,
#       "text": "fill",
#       "lemma": "fill",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 106,
#       "end_char": 110
#     },
#     {
#       "id": 18,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 111,
#       "end_char": 114
#     },
#     {
#       "id": 19,
#       "text": "gold",
#       "lemma": "gold",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 115,
#       "end_char": 119
#     },
#     {
#       "id": 20,
#       "text": "jackets",
#       "lemma": "jacket",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 120,
#       "end_char": 127
#     },
#     {
#       "id": 21,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 127,
#       "end_char": 128
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "your",
#       "lemma": "you",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Person=2|Poss=Yes|PronType=Prs",
#       "start_char": 129,
#       "end_char": 133
#     },
#     {
#       "id": 2,
#       "text": "presence",
#       "lemma": "presence",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 134,
#       "end_char": 142
#     },
#     {
#       "id": 3,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 142,
#       "end_char": 143
#     },
#     {
#       "id": 4,
#       "text": "without",
#       "lemma": "without",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 144,
#       "end_char": 151
#     },
#     {
#       "id": 5,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 152,
#       "end_char": 153
#     },
#     {
#       "id": 6,
#       "text": "doubt",
#       "lemma": "doubt",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 154,
#       "end_char": 159
#     },
#     {
#       "id": 7,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 159,
#       "end_char": 160
#     },
#     {
#       "id": 8,
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 161,
#       "end_char": 163
#     },
#     {
#       "id": 9,
#       "text": "most",
#       "lemma": "most",
#       "upos": "ADV",
#       "xpos": "RBS",
#       "start_char": 164,
#       "end_char": 168
#     },
#     {
#       "id": 10,
#       "text": "definitely",
#       "lemma": "definitely",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 169,
#       "end_char": 179
#     },
#     {
#       "id": 11,
#       "text": "felt",
#       "lemma": "feel",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "start_char": 180,
#       "end_char": 184
#     },
#     {
#       "id": 12,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 184,
#       "end_char": 185
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "thank",
#       "lemma": "thank",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 186,
#       "end_char": 191
#     },
#     {
#       "id": 2,
#       "text": "you",
#       "lemma": "you",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Person=2|PronType=Prs",
#       "start_char": 192,
#       "end_char": 195
#     },
#     {
#       "id": 3,
#       "text": "for",
#       "lemma": "for",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 196,
#       "end_char": 199
#     },
#     {
#       "id": 4,
#       "text": "being",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "start_char": 200,
#       "end_char": 205
#     },
#     {
#       "id": 5,
#       "text": "here",
#       "lemma": "here",
#       "upos": "ADV",
#       "xpos": "RB",
#       "feats": "PronType=Dem",
#       "start_char": 206,
#       "end_char": 210
#     },
#     {
#       "id": 6,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 210,
#       "end_char": 211
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "i",
#       "lemma": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 212,
#       "end_char": 213
#     },
#     {
#       "id": 2,
#       "text": "love",
#       "lemma": "love",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 214,
#       "end_char": 218
#     },
#     {
#       "id": 3,
#       "text": "football",
#       "lemma": "football",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 219,
#       "end_char": 227
#     },
#     {
#       "id": 4,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 227,
#       "end_char": 228
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "i",
#       "lemma": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 229,
#       "end_char": 230
#     },
#     {
#       "id": 2,
#       "text": "love",
#       "lemma": "love",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 231,
#       "end_char": 235
#     },
#     {
#       "id": 3,
#       "text": "football",
#       "lemma": "football",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 236,
#       "end_char": 244
#     },
#     {
#       "id": 4,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 244,
#       "end_char": 245
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "it",
#       "lemma": "it",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs",
#       "start_char": 246,
#       "end_char": 248
#     },
#     {
#       "id": 2,
#       "text": "was",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#       "start_char": 249,
#       "end_char": 252
#     },
#     {
#       "id": 3,
#       "text": "my",
#       "lemma": "my",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Number=Sing|Person=1|Poss=Yes|PronType=Prs",
#       "start_char": 253,
#       "end_char": 255
#     },
#     {
#       "id": 4,
#       "text": "entire",
#       "lemma": "entire",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 256,
#       "end_char": 262
#     },
#     {
#       "id": 5,
#       "text": "life",
#       "lemma": "life",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 263,
#       "end_char": 267
#     },
#     {
#       "id": 6,
#       "text": "since",
#       "lemma": "since",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 268,
#       "end_char": 273
#     },
#     {
#       "id": 7,
#       "text": "as",
#       "lemma": "as",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 274,
#       "end_char": 276
#     },
#     {
#       "id": 8,
#       "text": "long",
#       "lemma": "long",
#       "upos": "ADV",
#       "xpos": "RB",
#       "feats": "Degree=Pos",
#       "start_char": 277,
#       "end_char": 281
#     },
#     {
#       "id": 9,
#       "text": "as",
#       "lemma": "as",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 282,
#       "end_char": 284
#     },
#     {
#       "id": 10,
#       "text": "i",
#       "lemma": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 285,
#       "end_char": 286
#     },
#     {
#       "id": 11,
#       "text": "can",
#       "lemma": "can",
#       "upos": "AUX",
#       "xpos": "MD",
#       "feats": "VerbForm=Fin",
#       "start_char": 287,
#       "end_char": 290
#     },
#     {
#       "id": 12,
#       "text": "remember",
#       "lemma": "remember",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 291,
#       "end_char": 299
#     },
#     {
#       "id": 13,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 299,
#       "end_char": 300
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "i",
#       "lemma": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 301,
#       "end_char": 302
#     },
#     {
#       "id": 2,
#       "text": "fostered",
#       "lemma": "foster",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "start_char": 303,
#       "end_char": 311
#     },
#     {
#       "id": 3,
#       "text": "an",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 312,
#       "end_char": 314
#     },
#     {
#       "id": 4,
#       "text": "obsession",
#       "lemma": "obsession",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 315,
#       "end_char": 324
#     },
#     {
#       "id": 5,
#       "text": "with",
#       "lemma": "with",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 325,
#       "end_char": 329
#     },
#     {
#       "id": 6,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 330,
#       "end_char": 333
#     },
#     {
#       "id": 7,
#       "text": "game",
#       "lemma": "game",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 334,
#       "end_char": 338
#     },
#     {
#       "id": 8,
#       "text": "early",
#       "lemma": "early",
#       "upos": "ADV",
#       "xpos": "RB",
#       "feats": "Degree=Pos",
#       "start_char": 339,
#       "end_char": 344
#     },
#     {
#       "id": 9,
#       "text": "on",
#       "lemma": "on",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 345,
#       "end_char": 347
#     },
#     {
#       "id": 10,
#       "text": "that",
#       "lemma": "that",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 348,
#       "end_char": 352
#     },
#     {
#       "id": 11,
#       "text": "i",
#       "lemma": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 353,
#       "end_char": 354
#     },
#     {
#       "id": 12,
#       "text": "modeled",
#       "lemma": "model",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "start_char": 355,
#       "end_char": 362
#     },
#     {
#       "id": 13,
#       "text": "after",
#       "lemma": "after",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 363,
#       "end_char": 368
#     },
#     {
#       "id": 14,
#       "text": "meticulous",
#       "lemma": "meticulous",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 369,
#       "end_char": 379
#     },
#     {
#       "id": 15,
#       "text": "regiments",
#       "lemma": "regiment",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 380,
#       "end_char": 389
#     },
#     {
#       "id": 16,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 390,
#       "end_char": 392
#     },
#     {
#       "id": 17,
#       "text": "some",
#       "lemma": "some",
#       "upos": "DET",
#       "xpos": "DT",
#       "start_char": 393,
#       "end_char": 397
#     },
#     {
#       "id": 18,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 398,
#       "end_char": 400
#     },
#     {
#       "id": 19,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 401,
#       "end_char": 404
#     },
#     {
#       "id": 20,
#       "text": "greatest",
#       "lemma": "great",
#       "upos": "ADJ",
#       "xpos": "JJS",
#       "feats": "Degree=Sup",
#       "start_char": 405,
#       "end_char": 413
#     },
#     {
#       "id": 21,
#       "text": "artists",
#       "lemma": "artist",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 414,
#       "end_char": 421
#     },
#     {
#       "id": 22,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 422,
#       "end_char": 424
#     },
#     {
#       "id": 23,
#       "text": "past",
#       "lemma": "past",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 425,
#       "end_char": 429
#     },
#     {
#       "id": 24,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 429,
#       "end_char": 430
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "dickens",
#       "lemma": "dicken",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Sing",
#       "start_char": 431,
#       "end_char": 438
#     },
#     {
#       "id": 2,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 438,
#       "end_char": 439
#     },
#     {
#       "id": 3,
#       "text": "beethoven",
#       "lemma": "beethoven",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 440,
#       "end_char": 449
#     },
#     {
#       "id": 4,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 449,
#       "end_char": 450
#     },
#     {
#       "id": 5,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 451,
#       "end_char": 452
#     },
#     {
#       "id": 6,
#       "text": "these",
#       "lemma": "this",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Number=Plur|PronType=Dem",
#       "start_char": 453,
#       "end_char": 458
#     },
#     {
#       "id": 7,
#       "text": "great",
#       "lemma": "great",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 459,
#       "end_char": 464
#     },
#     {
#       "id": 8,
#       "text": "men",
#       "lemma": "man",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 465,
#       "end_char": 468
#     },
#     {
#       "id": 9,
#       "text": "were",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "start_char": 469,
#       "end_char": 473
#     },
#     {
#       "id": 10,
#       "text": "known",
#       "lemma": "know",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "start_char": 474,
#       "end_char": 479
#     },
#     {
#       "id": 11,
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "start_char": 480,
#       "end_char": 482
#     },
#     {
#       "id": 12,
#       "text": "have",
#       "lemma": "have",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 483,
#       "end_char": 487
#     },
#     {
#       "id": 13,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 488,
#       "end_char": 489
#     },
#     {
#       "id": 14,
#       "text": "beast",
#       "lemma": "beast",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 490,
#       "end_char": 495
#     },
#     {
#       "id": 15,
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "start_char": 495,
#       "end_char": 496
#     },
#     {
#       "id": 16,
#       "text": "like",
#       "lemma": "like",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 496,
#       "end_char": 500
#     },
#     {
#       "id": 17,
#       "text": "work",
#       "lemma": "work",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 501,
#       "end_char": 505
#     },
#     {
#       "id": 18,
#       "text": "ethic",
#       "lemma": "ethic",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 506,
#       "end_char": 511
#     },
#     {
#       "id": 19,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 511,
#       "end_char": 512
#     },
#     {
#       "id": 20,
#       "text": "coupled",
#       "lemma": "couple",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 513,
#       "end_char": 520
#     },
#     {
#       "id": 21,
#       "text": "with",
#       "lemma": "with",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 521,
#       "end_char": 525
#     },
#     {
#       "id": 22,
#       "text": "an",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 526,
#       "end_char": 528
#     },
#     {
#       "id": 23,
#       "text": "unwavering",
#       "lemma": "unwavering",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 529,
#       "end_char": 539
#     },
#     {
#       "id": 24,
#       "text": "ability",
#       "lemma": "ability",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 540,
#       "end_char": 547
#     },
#     {
#       "id": 25,
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "start_char": 548,
#       "end_char": 550
#     },
#     {
#       "id": 26,
#       "text": "create",
#       "lemma": "create",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 551,
#       "end_char": 557
#     },
#     {
#       "id": 27,
#       "text": "until",
#       "lemma": "until",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 558,
#       "end_char": 563
#     },
#     {
#       "id": 28,
#       "text": "perfection",
#       "lemma": "perfection",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 564,
#       "end_char": 574
#     },
#     {
#       "id": 29,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 574,
#       "end_char": 575
#     },
#     {
#       "id": 30,
#       "text": "beyond",
#       "lemma": "beyond",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 576,
#       "end_char": 582
#     },
#     {
#       "id": 31,
#       "text": "what",
#       "lemma": "what",
#       "upos": "PRON",
#       "xpos": "WP",
#       "feats": "PronType=Int",
#       "start_char": 583,
#       "end_char": 587
#     },
#     {
#       "id": 32,
#       "text": "most",
#       "lemma": "most",
#       "upos": "ADV",
#       "xpos": "RBS",
#       "start_char": 588,
#       "end_char": 592
#     },
#     {
#       "id": 33,
#       "text": "believe",
#       "lemma": "believe",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 593,
#       "end_char": 600
#     },
#     {
#       "id": 34,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 601,
#       "end_char": 604
#     },
#     {
#       "id": 35,
#       "text": "human",
#       "lemma": "human",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 605,
#       "end_char": 610
#     },
#     {
#       "id": 36,
#       "text": "body",
#       "lemma": "body",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 611,
#       "end_char": 615
#     },
#     {
#       "id": 37,
#       "text": "will",
#       "lemma": "will",
#       "upos": "AUX",
#       "xpos": "MD",
#       "feats": "VerbForm=Fin",
#       "start_char": 616,
#       "end_char": 620
#     },
#     {
#       "id": 38,
#       "text": "allow",
#       "lemma": "allow",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 621,
#       "end_char": 626
#     },
#     {
#       "id": 39,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 626,
#       "end_char": 627
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 628,
#       "end_char": 630
#     },
#     {
#       "id": 2,
#       "text": "me",
#       "lemma": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 631,
#       "end_char": 633
#     },
#     {
#       "id": 3,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 633,
#       "end_char": 634
#     },
#     {
#       "id": 4,
#       "text": "that",
#       "lemma": "that",
#       "upos": "PRON",
#       "xpos": "DT",
#       "feats": "Number=Sing|PronType=Dem",
#       "start_char": 635,
#       "end_char": 639
#     },
#     {
#       "id": 5,
#       "text": "’s",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 639,
#       "end_char": 641
#     },
#     {
#       "id": 6,
#       "text": "what",
#       "lemma": "what",
#       "upos": "PRON",
#       "xpos": "WP",
#       "feats": "PronType=Int",
#       "start_char": 642,
#       "end_char": 646
#     },
#     {
#       "id": 7,
#       "text": "it",
#       "lemma": "it",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs",
#       "start_char": 647,
#       "end_char": 649
#     },
#     {
#       "id": 8,
#       "text": "takes",
#       "lemma": "take",
#       "upos": "VERB",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 650,
#       "end_char": 655
#     },
#     {
#       "id": 9,
#       "text": "from",
#       "lemma": "from",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 656,
#       "end_char": 660
#     },
#     {
#       "id": 10,
#       "text": "being",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "start_char": 661,
#       "end_char": 666
#     },
#     {
#       "id": 11,
#       "text": "ordinary",
#       "lemma": "ordinary",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 667,
#       "end_char": 675
#     },
#     {
#       "id": 12,
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 676,
#       "end_char": 678
#     },
#     {
#       "id": 13,
#       "text": "extraordinary",
#       "lemma": "extraordinary",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 679,
#       "end_char": 692
#     },
#     {
#       "id": 14,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 692,
#       "end_char": 693
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "it",
#       "lemma": "it",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs",
#       "start_char": 694,
#       "end_char": 696
#     },
#     {
#       "id": 2,
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 697,
#       "end_char": 699
#     },
#     {
#       "id": 3,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 700,
#       "end_char": 703
#     },
#     {
#       "id": 4,
#       "text": "willingness",
#       "lemma": "willingness",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 704,
#       "end_char": 715
#     },
#     {
#       "id": 5,
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "start_char": 716,
#       "end_char": 718
#     },
#     {
#       "id": 6,
#       "text": "push",
#       "lemma": "push",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 719,
#       "end_char": 723
#     },
#     {
#       "id": 7,
#       "text": "beyond",
#       "lemma": "beyond",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 724,
#       "end_char": 730
#     },
#     {
#       "id": 8,
#       "text": "what",
#       "lemma": "what",
#       "upos": "PRON",
#       "xpos": "WP",
#       "feats": "PronType=Int",
#       "start_char": 731,
#       "end_char": 735
#     },
#     {
#       "id": 9,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 736,
#       "end_char": 739
#     },
#     {
#       "id": 10,
#       "text": "brain",
#       "lemma": "brain",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 740,
#       "end_char": 745
#     },
#     {
#       "id": 11,
#       "text": "says",
#       "lemma": "say",
#       "upos": "VERB",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 746,
#       "end_char": 750
#     },
#     {
#       "id": 12,
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 751,
#       "end_char": 753
#     },
#     {
#       "id": 13,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 754,
#       "end_char": 757
#     },
#     {
#       "id": 14,
#       "text": "body",
#       "lemma": "body",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 758,
#       "end_char": 762
#     },
#     {
#       "id": 15,
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 763,
#       "end_char": 765
#     },
#     {
#       "id": 16,
#       "text": "possible",
#       "lemma": "possible",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 766,
#       "end_char": 774
#     },
#     {
#       "id": 17,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 775,
#       "end_char": 778
#     },
#     {
#       "id": 18,
#       "text": "create",
#       "lemma": "create",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 779,
#       "end_char": 785
#     },
#     {
#       "id": 19,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 786,
#       "end_char": 787
#     },
#     {
#       "id": 20,
#       "text": "new",
#       "lemma": "new",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 788,
#       "end_char": 791
#     },
#     {
#       "id": 21,
#       "text": "order",
#       "lemma": "order",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 792,
#       "end_char": 797
#     },
#     {
#       "id": 22,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 798,
#       "end_char": 800
#     },
#     {
#       "id": 23,
#       "text": "boundaries",
#       "lemma": "boundary",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 801,
#       "end_char": 811
#     },
#     {
#       "id": 24,
#       "text": "for",
#       "lemma": "for",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 812,
#       "end_char": 815
#     },
#     {
#       "id": 25,
#       "text": "one",
#       "lemma": "one",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 816,
#       "end_char": 819
#     },
#     {
#       "id": 26,
#       "text": "’s",
#       "lemma": "'s",
#       "upos": "PART",
#       "xpos": "POS",
#       "start_char": 819,
#       "end_char": 821
#     },
#     {
#       "id": 27,
#       "text": "self",
#       "lemma": "self",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 822,
#       "end_char": 826
#     },
#     {
#       "id": 28,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 826,
#       "end_char": 827
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "it",
#       "lemma": "it",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs",
#       "start_char": 828,
#       "end_char": 830
#     },
#     {
#       "id": 2,
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 831,
#       "end_char": 833
#     },
#     {
#       "id": 3,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 834,
#       "end_char": 837
#     },
#     {
#       "id": 4,
#       "text": "ability",
#       "lemma": "ability",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 838,
#       "end_char": 845
#     },
#     {
#       "id": 5,
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "start_char": 846,
#       "end_char": 848
#     },
#     {
#       "id": 6,
#       "text": "learn",
#       "lemma": "learn",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 849,
#       "end_char": 854
#     },
#     {
#       "id": 7,
#       "text": "from",
#       "lemma": "from",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 855,
#       "end_char": 859
#     },
#     {
#       "id": 8,
#       "text": "greatness",
#       "lemma": "greatness",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 860,
#       "end_char": 869
#     },
#     {
#       "id": 9,
#       "text": "around",
#       "lemma": "around",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 870,
#       "end_char": 876
#     },
#     {
#       "id": 10,
#       "text": "you",
#       "lemma": "you",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Person=2|PronType=Prs",
#       "start_char": 877,
#       "end_char": 880
#     },
#     {
#       "id": 11,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 881,
#       "end_char": 884
#     },
#     {
#       "id": 12,
#       "text": "curate",
#       "lemma": "curate",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 885,
#       "end_char": 891
#     },
#     {
#       "id": 13,
#       "text": "for",
#       "lemma": "for",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 892,
#       "end_char": 895
#     },
#     {
#       "id": 14,
#       "text": "yourself",
#       "lemma": "yourself",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Number=Sing|Person=2|PronType=Prs|Reflex=Yes",
#       "start_char": 896,
#       "end_char": 904
#     },
#     {
#       "id": 15,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 905,
#       "end_char": 906
#     },
#     {
#       "id": 16,
#       "text": "unique",
#       "lemma": "unique",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 907,
#       "end_char": 913
#     },
#     {
#       "id": 17,
#       "text": "version",
#       "lemma": "version",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 914,
#       "end_char": 921
#     },
#     {
#       "id": 18,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 922,
#       "end_char": 924
#     },
#     {
#       "id": 19,
#       "text": "their",
#       "lemma": "they",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Number=Plur|Person=3|Poss=Yes|PronType=Prs",
#       "start_char": 925,
#       "end_char": 930
#     },
#     {
#       "id": 20,
#       "text": "efforts",
#       "lemma": "effort",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 931,
#       "end_char": 938
#     },
#     {
#       "id": 21,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 938,
#       "end_char": 939
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "football",
#       "lemma": "football",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 940,
#       "end_char": 948
#     },
#     {
#       "id": 2,
#       "text": "challenged",
#       "lemma": "challenge",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "start_char": 949,
#       "end_char": 959
#     },
#     {
#       "id": 3,
#       "text": "me",
#       "lemma": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 960,
#       "end_char": 962
#     },
#     {
#       "id": 4,
#       "text": "mentally",
#       "lemma": "mentally",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 963,
#       "end_char": 971
#     },
#     {
#       "id": 5,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 971,
#       "end_char": 972
#     },
#     {
#       "id": 6,
#       "text": "physically",
#       "lemma": "physically",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 973,
#       "end_char": 983
#     },
#     {
#       "id": 7,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 983,
#       "end_char": 984
#     },
#     {
#       "id": 8,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 985,
#       "end_char": 988
#     },
#     {
#       "id": 9,
#       "text": "spiritually",
#       "lemma": "spiritually",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 989,
#       "end_char": 1000
#     },
#     {
#       "id": 10,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 1000,
#       "end_char": 1001
#     },
#     {
#       "id": 11,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 1002,
#       "end_char": 1004
#     },
#     {
#       "id": 12,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 1005,
#       "end_char": 1006
#     },
#     {
#       "id": 13,
#       "text": "way",
#       "lemma": "way",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1007,
#       "end_char": 1010
#     },
#     {
#       "id": 14,
#       "text": "that",
#       "lemma": "that",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 1011,
#       "end_char": 1015
#     },
#     {
#       "id": 15,
#       "text": "no",
#       "lemma": "no",
#       "upos": "DET",
#       "xpos": "DT",
#       "start_char": 1016,
#       "end_char": 1018
#     },
#     {
#       "id": 16,
#       "text": "other",
#       "lemma": "other",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 1019,
#       "end_char": 1024
#     },
#     {
#       "id": 17,
#       "text": "feature",
#       "lemma": "feature",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1025,
#       "end_char": 1032
#     },
#     {
#       "id": 18,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 1033,
#       "end_char": 1035
#     },
#     {
#       "id": 19,
#       "text": "life",
#       "lemma": "life",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1036,
#       "end_char": 1040
#     },
#     {
#       "id": 20,
#       "text": "could",
#       "lemma": "could",
#       "upos": "AUX",
#       "xpos": "MD",
#       "feats": "VerbForm=Fin",
#       "start_char": 1041,
#       "end_char": 1046
#     },
#     {
#       "id": 21,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 1046,
#       "end_char": 1047
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "so",
#       "lemma": "so",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 1048,
#       "end_char": 1050
#     },
#     {
#       "id": 2,
#       "text": "i",
#       "lemma": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 1051,
#       "end_char": 1052
#     },
#     {
#       "id": 3,
#       "text": "was",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#       "start_char": 1053,
#       "end_char": 1056
#     },
#     {
#       "id": 4,
#       "text": "hooked",
#       "lemma": "hook",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "start_char": 1057,
#       "end_char": 1063
#     },
#     {
#       "id": 5,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 1063,
#       "end_char": 1064
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "i",
#       "lemma": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 1065,
#       "end_char": 1066
#     },
#     {
#       "id": 2,
#       "text": "had",
#       "lemma": "have",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "start_char": 1067,
#       "end_char": 1070
#     },
#     {
#       "id": 3,
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "start_char": 1071,
#       "end_char": 1073
#     },
#     {
#       "id": 4,
#       "text": "succeed",
#       "lemma": "succeed",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 1074,
#       "end_char": 1081
#     },
#     {
#       "id": 5,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 1082,
#       "end_char": 1084
#     },
#     {
#       "id": 6,
#       "text": "order",
#       "lemma": "order",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1085,
#       "end_char": 1090
#     },
#     {
#       "id": 7,
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "start_char": 1091,
#       "end_char": 1093
#     },
#     {
#       "id": 8,
#       "text": "quench",
#       "lemma": "quench",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 1094,
#       "end_char": 1100
#     },
#     {
#       "id": 9,
#       "text": "this",
#       "lemma": "this",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Number=Sing|PronType=Dem",
#       "start_char": 1101,
#       "end_char": 1105
#     },
#     {
#       "id": 10,
#       "text": "desire",
#       "lemma": "desire",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1106,
#       "end_char": 1112
#     },
#     {
#       "id": 11,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 1112,
#       "end_char": 1113
#     },
#     {
#       "id": 12,
#       "text": "or",
#       "lemma": "or",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 1114,
#       "end_char": 1116
#     },
#     {
#       "id": 13,
#       "text": "i",
#       "lemma": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 1117,
#       "end_char": 1118
#     },
#     {
#       "id": 14,
#       "text": "knew",
#       "lemma": "know",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "start_char": 1119,
#       "end_char": 1123
#     },
#     {
#       "id": 15,
#       "text": "i",
#       "lemma": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 1124,
#       "end_char": 1125
#     },
#     {
#       "id": 16,
#       "text": "would",
#       "lemma": "would",
#       "upos": "AUX",
#       "xpos": "MD",
#       "feats": "VerbForm=Fin",
#       "start_char": 1126,
#       "end_char": 1131
#     },
#     {
#       "id": 17,
#       "text": "have",
#       "lemma": "have",
#       "upos": "AUX",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 1132,
#       "end_char": 1136
#     },
#     {
#       "id": 18,
#       "text": "lived",
#       "lemma": "live",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 1137,
#       "end_char": 1142
#     },
#     {
#       "id": 19,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 1143,
#       "end_char": 1144
#     },
#     {
#       "id": 20,
#       "text": "life",
#       "lemma": "life",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1145,
#       "end_char": 1149
#     },
#     {
#       "id": 21,
#       "text": "without",
#       "lemma": "without",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 1150,
#       "end_char": 1157
#     },
#     {
#       "id": 22,
#       "text": "direction",
#       "lemma": "direction",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1158,
#       "end_char": 1167
#     },
#     {
#       "id": 23,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 1167,
#       "end_char": 1168
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "thank",
#       "lemma": "thank",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 1169,
#       "end_char": 1174
#     },
#     {
#       "id": 2,
#       "text": "you",
#       "lemma": "you",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Person=2|PronType=Prs",
#       "start_char": 1175,
#       "end_char": 1178
#     },
#     {
#       "id": 3,
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 1179,
#       "end_char": 1181
#     },
#     {
#       "id": 4,
#       "text": "everyone",
#       "lemma": "everyone",
#       "upos": "PRON",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1182,
#       "end_char": 1190
#     },
#     {
#       "id": 5,
#       "text": "who",
#       "lemma": "who",
#       "upos": "PRON",
#       "xpos": "WP",
#       "feats": "PronType=Rel",
#       "start_char": 1191,
#       "end_char": 1194
#     },
#     {
#       "id": 6,
#       "text": "has",
#       "lemma": "have",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 1195,
#       "end_char": 1198
#     },
#     {
#       "id": 7,
#       "text": "been",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 1199,
#       "end_char": 1203
#     },
#     {
#       "id": 8,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 1204,
#       "end_char": 1205
#     },
#     {
#       "id": 9,
#       "text": "part",
#       "lemma": "part",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1206,
#       "end_char": 1210
#     },
#     {
#       "id": 10,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 1211,
#       "end_char": 1213
#     },
#     {
#       "id": 11,
#       "text": "my",
#       "lemma": "my",
#       "upos": "PRON",
# ...
#       "start_char": 6889,
#       "end_char": 6890
#     },
#     {
#       "id": 7,
#       "text": "could",
#       "lemma": "could",
#       "upos": "AUX",
#       "xpos": "MD",
#       "feats": "VerbForm=Fin",
#       "start_char": 6891,
#       "end_char": 6896
#     },
#     {
#       "id": 8,
#       "text": "do",
#       "lemma": "do",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 6897,
#       "end_char": 6899
#     },
#     {
#       "id": 9,
#       "text": "for",
#       "lemma": "for",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 6900,
#       "end_char": 6903
#     },
#     {
#       "id": 10,
#       "text": "you",
#       "lemma": "you",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Person=2|PronType=Prs",
#       "start_char": 6904,
#       "end_char": 6907
#     },
#     {
#       "id": 11,
#       "text": "guys",
#       "lemma": "guy",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 6908,
#       "end_char": 6912
#     },
#     {
#       "id": 12,
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 6913,
#       "end_char": 6915
#     },
#     {
#       "id": 13,
#       "text": "love",
#       "lemma": "love",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 6916,
#       "end_char": 6920
#     },
#     {
#       "id": 14,
#       "text": "your",
#       "lemma": "you",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Person=2|Poss=Yes|PronType=Prs",
#       "start_char": 6921,
#       "end_char": 6925
#     },
#     {
#       "id": 15,
#       "text": "mother",
#       "lemma": "mother",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 6926,
#       "end_char": 6932
#     },
#     {
#       "id": 16,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 6932,
#       "end_char": 6933
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "i",
#       "lemma": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 6934,
#       "end_char": 6935
#     },
#     {
#       "id": 2,
#       "text": "love",
#       "lemma": "love",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 6936,
#       "end_char": 6940
#     },
#     {
#       "id": 3,
#       "text": "you",
#       "lemma": "you",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Person=2|PronType=Prs",
#       "start_char": 6941,
#       "end_char": 6944
#     },
#     {
#       "id": 4,
#       "text": "guys",
#       "lemma": "guy",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 6945,
#       "end_char": 6949
#     },
#     {
#       "id": 5,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 6949,
#       "end_char": 6950
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "thank",
#       "lemma": "thank",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 6951,
#       "end_char": 6956
#     },
#     {
#       "id": 2,
#       "text": "you",
#       "lemma": "you",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Person=2|PronType=Prs",
#       "start_char": 6957,
#       "end_char": 6960
#     },
#     {
#       "id": 3,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 6960,
#       "end_char": 6961
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "thank",
#       "lemma": "thank",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 6962,
#       "end_char": 6967
#     },
#     {
#       "id": 2,
#       "text": "you",
#       "lemma": "you",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Person=2|PronType=Prs",
#       "start_char": 6968,
#       "end_char": 6971
#     },
#     {
#       "id": 3,
#       "text": "for",
#       "lemma": "for",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 6972,
#       "end_char": 6975
#     },
#     {
#       "id": 4,
#       "text": "holding",
#       "lemma": "hold",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "start_char": 6976,
#       "end_char": 6983
#     },
#     {
#       "id": 5,
#       "text": "me",
#       "lemma": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 6984,
#       "end_char": 6986
#     },
#     {
#       "id": 6,
#       "text": "accountable",
#       "lemma": "accountable",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 6987,
#       "end_char": 6998
#     },
#     {
#       "id": 7,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 6998,
#       "end_char": 6999
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "i",
#       "lemma": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 7000,
#       "end_char": 7001
#     },
#     {
#       "id": 2,
#       "text": "’m",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin",
#       "start_char": 7001,
#       "end_char": 7003
#     },
#     {
#       "id": 3,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 7004,
#       "end_char": 7005
#     },
#     {
#       "id": 4,
#       "text": "follower",
#       "lemma": "follower",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 7006,
#       "end_char": 7014
#     },
#     {
#       "id": 5,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 7014,
#       "end_char": 7015
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "everyone",
#       "lemma": "everyone",
#       "upos": "PRON",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 7016,
#       "end_char": 7024
#     },
#     {
#       "id": 2,
#       "text": "’s",
#       "lemma": "'s",
#       "upos": "PART",
#       "xpos": "POS",
#       "start_char": 7024,
#       "end_char": 7026
#     },
#     {
#       "id": 3,
#       "text": "little",
#       "lemma": "little",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 7027,
#       "end_char": 7033
#     },
#     {
#       "id": 4,
#       "text": "brother",
#       "lemma": "brother",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 7034,
#       "end_char": 7041
#     },
#     {
#       "id": 5,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 7041,
#       "end_char": 7042
#     },
#     {
#       "id": 6,
#       "text": "nephew",
#       "lemma": "nephew",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 7043,
#       "end_char": 7049
#     },
#     {
#       "id": 7,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 7049,
#       "end_char": 7050
#     },
#     {
#       "id": 8,
#       "text": "son",
#       "lemma": "son",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 7051,
#       "end_char": 7054
#     },
#     {
#       "id": 9,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 7054,
#       "end_char": 7055
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "i",
#       "lemma": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 7056,
#       "end_char": 7057
#     },
#     {
#       "id": 2,
#       "text": "love",
#       "lemma": "love",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 7058,
#       "end_char": 7062
#     },
#     {
#       "id": 3,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 7063,
#       "end_char": 7066
#     },
#     {
#       "id": 4,
#       "text": "thank",
#       "lemma": "thank",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 7067,
#       "end_char": 7072
#     },
#     {
#       "id": 5,
#       "text": "god",
#       "lemma": "god",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 7073,
#       "end_char": 7076
#     },
#     {
#       "id": 6,
#       "text": "for",
#       "lemma": "for",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 7077,
#       "end_char": 7080
#     },
#     {
#       "id": 7,
#       "text": "my",
#       "lemma": "my",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Number=Sing|Person=1|Poss=Yes|PronType=Prs",
#       "start_char": 7081,
#       "end_char": 7083
#     },
#     {
#       "id": 8,
#       "text": "life",
#       "lemma": "life",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 7084,
#       "end_char": 7088
#     },
#     {
#       "id": 9,
#       "text": "because",
#       "lemma": "because",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 7089,
#       "end_char": 7096
#     },
#     {
#       "id": 10,
#       "text": "i",
#       "lemma": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 7097,
#       "end_char": 7098
#     },
#     {
#       "id": 11,
#       "text": "have",
#       "lemma": "have",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 7099,
#       "end_char": 7103
#     },
#     {
#       "id": 12,
#       "text": "all",
#       "lemma": "all",
#       "upos": "DET",
#       "xpos": "DT",
#       "start_char": 7104,
#       "end_char": 7107
#     },
#     {
#       "id": 13,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 7108,
#       "end_char": 7110
#     },
#     {
#       "id": 14,
#       "text": "you",
#       "lemma": "you",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Person=2|PronType=Prs",
#       "start_char": 7111,
#       "end_char": 7114
#     },
#     {
#       "id": 15,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 7114,
#       "end_char": 7115
#     },
#     {
#       "id": 16,
#       "text": "my",
#       "lemma": "my",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Number=Sing|Person=1|Poss=Yes|PronType=Prs",
#       "start_char": 7116,
#       "end_char": 7118
#     },
#     {
#       "id": 17,
#       "text": "family",
#       "lemma": "family",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 7119,
#       "end_char": 7125
#     },
#     {
#       "id": 18,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 7125,
#       "end_char": 7126
#     },
#     {
#       "id": 19,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 7127,
#       "end_char": 7130
#     },
#     {
#       "id": 20,
#       "text": "biggest",
#       "lemma": "big",
#       "upos": "ADJ",
#       "xpos": "JJS",
#       "feats": "Degree=Sup",
#       "start_char": 7131,
#       "end_char": 7138
#     },
#     {
#       "id": 21,
#       "text": "family",
#       "lemma": "family",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 7139,
#       "end_char": 7145
#     },
#     {
#       "id": 22,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 7146,
#       "end_char": 7148
#     },
#     {
#       "id": 23,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 7149,
#       "end_char": 7152
#     },
#     {
#       "id": 24,
#       "text": "world",
#       "lemma": "world",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 7153,
#       "end_char": 7158
#     },
#     {
#       "id": 25,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 7158,
#       "end_char": 7159
#     },
#     {
#       "id": 26,
#       "text": "steeler",
#       "lemma": "steeler",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 7160,
#       "end_char": 7167
#     },
#     {
#       "id": 27,
#       "text": "nation",
#       "lemma": "nation",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 7168,
#       "end_char": 7174
#     },
#     {
#       "id": 28,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 7174,
#       "end_char": 7175
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "thank",
#       "lemma": "thank",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 7176,
#       "end_char": 7181
#     },
#     {
#       "id": 2,
#       "text": "you",
#       "lemma": "you",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Person=2|PronType=Prs",
#       "start_char": 7182,
#       "end_char": 7185
#     },
#     {
#       "id": 3,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 7185,
#       "end_char": 7186
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "what",
#       "lemma": "what",
#       "upos": "PRON",
#       "xpos": "WP",
#       "feats": "PronType=Int",
#       "start_char": 7187,
#       "end_char": 7191
#     },
#     {
#       "id": 2,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 7192,
#       "end_char": 7193
#     },
#     {
#       "id": 3,
#       "text": "beautiful",
#       "lemma": "beautiful",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 7194,
#       "end_char": 7203
#     },
#     {
#       "id": 4,
#       "text": "speech",
#       "lemma": "speech",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 7204,
#       "end_char": 7210
#     },
#     {
#       "id": 5,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 7210,
#       "end_char": 7211
#     },
#     {
#       "id": 6,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 7212,
#       "end_char": 7215
#     },
#     {
#       "id": 7,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 7216,
#       "end_char": 7219
#     },
#     {
#       "id": 8,
#       "text": "place",
#       "lemma": "place",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 7220,
#       "end_char": 7225
#     },
#     {
#       "id": 9,
#       "text": "here",
#       "lemma": "here",
#       "upos": "ADV",
#       "xpos": "RB",
#       "feats": "PronType=Dem",
#       "start_char": 7226,
#       "end_char": 7230
#     },
#     {
#       "id": 10,
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 7231,
#       "end_char": 7233
#     },
#     {
#       "id": 11,
#       "text": "lit",
#       "lemma": "light",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "start_char": 7234,
#       "end_char": 7237
#     },
#     {
#       "id": 12,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 7237,
#       "end_char": 7238
#     }
#   ]
# ]

# %%
science_in_docs = [stanza.Document([], text=d.lower()) for d in science_data]
science_out_docs = nlp(science_in_docs)
science_in_docs[1]
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "arrays",
#       "lemma": "array",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 0,
#       "end_char": 6
#     },
#     {
#       "id": 2,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 7,
#       "end_char": 9
#     },
#     {
#       "id": 3,
#       "text": "optical",
#       "lemma": "optical",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 10,
#       "end_char": 17
#     },
#     {
#       "id": 4,
#       "text": "tweezers",
#       "lemma": "tweezers",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 18,
#       "end_char": 26
#     },
#     {
#       "id": 5,
#       "text": "can",
#       "lemma": "can",
#       "upos": "AUX",
#       "xpos": "MD",
#       "feats": "VerbForm=Fin",
#       "start_char": 27,
#       "end_char": 30
#     },
#     {
#       "id": 6,
#       "text": "be",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 31,
#       "end_char": 33
#     },
#     {
#       "id": 7,
#       "text": "used",
#       "lemma": "use",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "start_char": 34,
#       "end_char": 38
#     },
#     {
#       "id": 8,
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "start_char": 39,
#       "end_char": 41
#     },
#     {
#       "id": 9,
#       "text": "trap",
#       "lemma": "trap",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 42,
#       "end_char": 46
#     },
#     {
#       "id": 10,
#       "text": "atoms",
#       "lemma": "atom",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 47,
#       "end_char": 52
#     },
#     {
#       "id": 11,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 52,
#       "end_char": 53
#     },
#     {
#       "id": 12,
#       "text": "which",
#       "lemma": "which",
#       "upos": "PRON",
#       "xpos": "WDT",
#       "feats": "PronType=Rel",
#       "start_char": 54,
#       "end_char": 59
#     },
#     {
#       "id": 13,
#       "text": "can",
#       "lemma": "can",
#       "upos": "AUX",
#       "xpos": "MD",
#       "feats": "VerbForm=Fin",
#       "start_char": 60,
#       "end_char": 63
#     },
#     {
#       "id": 14,
#       "text": "then",
#       "lemma": "then",
#       "upos": "ADV",
#       "xpos": "RB",
#       "feats": "PronType=Dem",
#       "start_char": 64,
#       "end_char": 68
#     },
#     {
#       "id": 15,
#       "text": "be",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 69,
#       "end_char": 71
#     },
#     {
#       "id": 16,
#       "text": "manipulated",
#       "lemma": "manipulate",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "start_char": 72,
#       "end_char": 83
#     },
#     {
#       "id": 17,
#       "text": "individually",
#       "lemma": "individually",
#       "upos": "ADV",
#       "xpos": "RB",
#       "feats": "Degree=Pos",
#       "start_char": 84,
#       "end_char": 96
#     },
#     {
#       "id": 18,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 96,
#       "end_char": 97
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "such",
#       "lemma": "such",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 98,
#       "end_char": 102
#     },
#     {
#       "id": 2,
#       "text": "arrays",
#       "lemma": "array",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 103,
#       "end_char": 109
#     },
#     {
#       "id": 3,
#       "text": "have",
#       "lemma": "have",
#       "upos": "AUX",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 110,
#       "end_char": 114
#     },
#     {
#       "id": 4,
#       "text": "shown",
#       "lemma": "show",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 115,
#       "end_char": 120
#     },
#     {
#       "id": 5,
#       "text": "promise",
#       "lemma": "promise",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 121,
#       "end_char": 128
#     },
#     {
#       "id": 6,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 129,
#       "end_char": 131
#     },
#     {
#       "id": 7,
#       "text": "quantum",
#       "lemma": "quantum",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 132,
#       "end_char": 139
#     },
#     {
#       "id": 8,
#       "text": "simulation",
#       "lemma": "simulation",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 140,
#       "end_char": 150
#     },
#     {
#       "id": 9,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 151,
#       "end_char": 153
#     },
#     {
#       "id": 10,
#       "text": "many",
#       "lemma": "many",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 154,
#       "end_char": 158
#     },
#     {
#       "id": 11,
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "start_char": 158,
#       "end_char": 159
#     },
#     {
#       "id": 12,
#       "text": "body",
#       "lemma": "body",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 159,
#       "end_char": 163
#     },
#     {
#       "id": 13,
#       "text": "systems",
#       "lemma": "system",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 164,
#       "end_char": 171
#     },
#     {
#       "id": 14,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 171,
#       "end_char": 172
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "norcia",
#       "lemma": "norcia",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 173,
#       "end_char": 179
#     },
#     {
#       "id": 2,
#       "text": "et",
#       "lemma": "et",
#       "upos": "X",
#       "xpos": "FW",
#       "start_char": 180,
#       "end_char": 182
#     },
#     {
#       "id": 3,
#       "text": "al.",
#       "lemma": "al.",
#       "upos": "X",
#       "xpos": "FW",
#       "start_char": 183,
#       "end_char": 186
#     },
#     {
#       "id": 4,
#       "text": "now",
#       "lemma": "now",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 187,
#       "end_char": 190
#     },
#     {
#       "id": 5,
#       "text": "demonstrate",
#       "lemma": "demonstrate",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 191,
#       "end_char": 202
#     },
#     {
#       "id": 6,
#       "text": "that",
#       "lemma": "that",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 203,
#       "end_char": 207
#     },
#     {
#       "id": 7,
#       "text": "they",
#       "lemma": "they",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=3|PronType=Prs",
#       "start_char": 208,
#       "end_char": 212
#     },
#     {
#       "id": 8,
#       "text": "can",
#       "lemma": "can",
#       "upos": "AUX",
#       "xpos": "MD",
#       "feats": "VerbForm=Fin",
#       "start_char": 213,
#       "end_char": 216
#     },
#     {
#       "id": 9,
#       "text": "also",
#       "lemma": "also",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 217,
#       "end_char": 221
#     },
#     {
#       "id": 10,
#       "text": "be",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 222,
#       "end_char": 224
#     },
#     {
#       "id": 11,
#       "text": "used",
#       "lemma": "use",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "start_char": 225,
#       "end_char": 229
#     },
#     {
#       "id": 12,
#       "text": "as",
#       "lemma": "as",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 230,
#       "end_char": 232
#     },
#     {
#       "id": 13,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 233,
#       "end_char": 234
#     },
#     {
#       "id": 14,
#       "text": "platform",
#       "lemma": "platform",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 235,
#       "end_char": 243
#     },
#     {
#       "id": 15,
#       "text": "for",
#       "lemma": "for",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 244,
#       "end_char": 247
#     },
#     {
#       "id": 16,
#       "text": "optical",
#       "lemma": "optical",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 248,
#       "end_char": 255
#     },
#     {
#       "id": 17,
#       "text": "clocks",
#       "lemma": "clock",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 256,
#       "end_char": 262
#     },
#     {
#       "id": 18,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 262,
#       "end_char": 263
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 264,
#       "end_char": 267
#     },
#     {
#       "id": 2,
#       "text": "researchers",
#       "lemma": "researcher",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 268,
#       "end_char": 279
#     },
#     {
#       "id": 3,
#       "text": "lined",
#       "lemma": "line",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin",
#       "start_char": 280,
#       "end_char": 285
#     },
#     {
#       "id": 4,
#       "text": "up",
#       "lemma": "up",
#       "upos": "ADP",
#       "xpos": "RP",
#       "start_char": 286,
#       "end_char": 288
#     },
#     {
#       "id": 5,
#       "text": "10",
#       "lemma": "10",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "start_char": 289,
#       "end_char": 291
#     },
#     {
#       "id": 6,
#       "text": "optical",
#       "lemma": "optical",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 292,
#       "end_char": 299
#     },
#     {
#       "id": 7,
#       "text": "tweezers",
#       "lemma": "tweezers",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 300,
#       "end_char": 308
#     },
#     {
#       "id": 8,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 309,
#       "end_char": 311
#     },
#     {
#       "id": 9,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 312,
#       "end_char": 313
#     },
#     {
#       "id": 10,
#       "text": "one-dimensional",
#       "lemma": "one-dimensional",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos|Polarity=Neg",
#       "start_char": 314,
#       "end_char": 329
#     },
#     {
#       "id": 11,
#       "text": "array",
#       "lemma": "array",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 330,
#       "end_char": 335
#     },
#     {
#       "id": 12,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 335,
#       "end_char": 336
#     },
#     {
#       "id": 13,
#       "text": "where",
#       "lemma": "where",
#       "upos": "SCONJ",
#       "xpos": "WRB",
#       "feats": "PronType=Rel",
#       "start_char": 337,
#       "end_char": 342
#     },
#     {
#       "id": 14,
#       "text": "each",
#       "lemma": "each",
#       "upos": "DET",
#       "xpos": "DT",
#       "start_char": 343,
#       "end_char": 347
#     },
#     {
#       "id": 15,
#       "text": "tweezer",
#       "lemma": "tweezer",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 348,
#       "end_char": 355
#     },
#     {
#       "id": 16,
#       "text": "held",
#       "lemma": "hold",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#       "start_char": 356,
#       "end_char": 360
#     },
#     {
#       "id": 17,
#       "text": "either",
#       "lemma": "either",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 361,
#       "end_char": 367
#     },
#     {
#       "id": 18,
#       "text": "one",
#       "lemma": "one",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Word|NumType=Card",
#       "start_char": 368,
#       "end_char": 371
#     },
#     {
#       "id": 19,
#       "text": "or",
#       "lemma": "or",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 372,
#       "end_char": 374
#     },
#     {
#       "id": 20,
#       "text": "zero",
#       "lemma": "zero",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Word|NumType=Card",
#       "start_char": 375,
#       "end_char": 379
#     },
#     {
#       "id": 21,
#       "text": "atoms",
#       "lemma": "atom",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 380,
#       "end_char": 385
#     },
#     {
#       "id": 22,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 386,
#       "end_char": 388
#     },
#     {
#       "id": 23,
#       "text": "strontium",
#       "lemma": "strontium",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 389,
#       "end_char": 398
#     },
#     {
#       "id": 24,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 398,
#       "end_char": 399
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 400,
#       "end_char": 403
#     },
#     {
#       "id": 2,
#       "text": "atoms",
#       "lemma": "atom",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 404,
#       "end_char": 409
#     },
#     {
#       "id": 3,
#       "text": "were",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "start_char": 410,
#       "end_char": 414
#     },
#     {
#       "id": 4,
#       "text": "subjected",
#       "lemma": "subject",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "start_char": 415,
#       "end_char": 424
#     },
#     {
#       "id": 5,
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 425,
#       "end_char": 427
#     },
#     {
#       "id": 6,
#       "text": "laser",
#       "lemma": "laser",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 428,
#       "end_char": 433
#     },
#     {
#       "id": 7,
#       "text": "light",
#       "lemma": "light",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 434,
#       "end_char": 439
#     },
#     {
#       "id": 8,
#       "text": "whose",
#       "lemma": "whose",
#       "upos": "PRON",
#       "xpos": "WP$",
#       "feats": "Poss=Yes|PronType=Rel",
#       "start_char": 440,
#       "end_char": 445
#     },
#     {
#       "id": 9,
#       "text": "frequency",
#       "lemma": "frequency",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 446,
#       "end_char": 455
#     },
#     {
#       "id": 10,
#       "text": "was",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#       "start_char": 456,
#       "end_char": 459
#     },
#     {
#       "id": 11,
#       "text": "tuned",
#       "lemma": "tune",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "start_char": 460,
#       "end_char": 465
#     },
#     {
#       "id": 12,
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 466,
#       "end_char": 468
#     },
#     {
#       "id": 13,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 469,
#       "end_char": 470
#     },
#     {
#       "id": 14,
#       "text": "clock",
#       "lemma": "clock",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 471,
#       "end_char": 476
#     },
#     {
#       "id": 15,
#       "text": "transition",
#       "lemma": "transition",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 477,
#       "end_char": 487
#     },
#     {
#       "id": 16,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 488,
#       "end_char": 490
#     },
#     {
#       "id": 17,
#       "text": "strontium",
#       "lemma": "strontium",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 491,
#       "end_char": 500
#     },
#     {
#       "id": 18,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 500,
#       "end_char": 501
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "by",
#       "lemma": "by",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 502,
#       "end_char": 504
#     },
#     {
#       "id": 2,
#       "text": "monitoring",
#       "lemma": "monitor",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "start_char": 505,
#       "end_char": 515
#     },
#     {
#       "id": 3,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 516,
#       "end_char": 519
#     },
#     {
#       "id": 4,
#       "text": "number",
#       "lemma": "number",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 520,
#       "end_char": 526
#     },
#     {
#       "id": 5,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 527,
#       "end_char": 529
#     },
#     {
#       "id": 6,
#       "text": "atoms",
#       "lemma": "atom",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 530,
#       "end_char": 535
#     },
#     {
#       "id": 7,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 536,
#       "end_char": 538
#     },
#     {
#       "id": 8,
#       "text": "each",
#       "lemma": "each",
#       "upos": "DET",
#       "xpos": "DT",
#       "start_char": 539,
#       "end_char": 543
#     },
#     {
#       "id": 9,
#       "text": "tweezer",
#       "lemma": "tweezer",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 544,
#       "end_char": 551
#     },
#     {
#       "id": 10,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 551,
#       "end_char": 552
#     },
#     {
#       "id": 11,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 553,
#       "end_char": 556
#     },
#     {
#       "id": 12,
#       "text": "researchers",
#       "lemma": "researcher",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 557,
#       "end_char": 568
#     },
#     {
#       "id": 13,
#       "text": "measured",
#       "lemma": "measure",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "start_char": 569,
#       "end_char": 577
#     },
#     {
#       "id": 14,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 578,
#       "end_char": 579
#     },
#     {
#       "id": 15,
#       "text": "long",
#       "lemma": "long",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 580,
#       "end_char": 584
#     },
#     {
#       "id": 16,
#       "text": "coherence",
#       "lemma": "coherence",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 585,
#       "end_char": 594
#     },
#     {
#       "id": 17,
#       "text": "time",
#       "lemma": "time",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 595,
#       "end_char": 599
#     },
#     {
#       "id": 18,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 600,
#       "end_char": 602
#     },
#     {
#       "id": 19,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 603,
#       "end_char": 604
#     },
#     {
#       "id": 20,
#       "text": "few",
#       "lemma": "few",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 605,
#       "end_char": 608
#     },
#     {
#       "id": 21,
#       "text": "seconds",
#       "lemma": "second",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 609,
#       "end_char": 616
#     },
#     {
#       "id": 22,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 616,
#       "end_char": 617
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "increasing",
#       "lemma": "increase",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "start_char": 618,
#       "end_char": 628
#     },
#     {
#       "id": 2,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 629,
#       "end_char": 632
#     },
#     {
#       "id": 3,
#       "text": "number",
#       "lemma": "number",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 633,
#       "end_char": 639
#     },
#     {
#       "id": 4,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 640,
#       "end_char": 642
#     },
#     {
#       "id": 5,
#       "text": "tweezers",
#       "lemma": "tweezers",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 643,
#       "end_char": 651
#     },
#     {
#       "id": 6,
#       "text": "should",
#       "lemma": "should",
#       "upos": "AUX",
#       "xpos": "MD",
#       "feats": "VerbForm=Fin",
#       "start_char": 652,
#       "end_char": 658
#     },
#     {
#       "id": 7,
#       "text": "improve",
#       "lemma": "improve",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 659,
#       "end_char": 666
#     },
#     {
#       "id": 8,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 667,
#       "end_char": 670
#     },
#     {
#       "id": 9,
#       "text": "figures",
#       "lemma": "figure",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 671,
#       "end_char": 678
#     },
#     {
#       "id": 10,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 679,
#       "end_char": 681
#     },
#     {
#       "id": 11,
#       "text": "merit",
#       "lemma": "merit",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 682,
#       "end_char": 687
#     },
#     {
#       "id": 12,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 688,
#       "end_char": 690
#     },
#     {
#       "id": 13,
#       "text": "this",
#       "lemma": "this",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Number=Sing|PronType=Dem",
#       "start_char": 691,
#       "end_char": 695
#     },
#     {
#       "id": 14,
#       "text": "platform",
#       "lemma": "platform",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 696,
#       "end_char": 704
#     },
#     {
#       "id": 15,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 704,
#       "end_char": 705
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "many",
#       "lemma": "many",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 706,
#       "end_char": 710
#     },
#     {
#       "id": 2,
#       "text": "stars",
#       "lemma": "star",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 711,
#       "end_char": 716
#     },
#     {
#       "id": 3,
#       "text": "are",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Number=Plur|Tense=Pres|VerbForm=Fin",
#       "start_char": 717,
#       "end_char": 720
#     },
#     {
#       "id": 4,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 721,
#       "end_char": 723
#     },
#     {
#       "id": 5,
#       "text": "binary",
#       "lemma": "binary",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 724,
#       "end_char": 730
#     },
#     {
#       "id": 6,
#       "text": "systems",
#       "lemma": "system",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 731,
#       "end_char": 738
#     },
#     {
#       "id": 7,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 738,
#       "end_char": 739
#     },
#     {
#       "id": 8,
#       "text": "pairs",
#       "lemma": "pair",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 740,
#       "end_char": 745
#     },
#     {
#       "id": 9,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 746,
#       "end_char": 748
#     },
#     {
#       "id": 10,
#       "text": "stars",
#       "lemma": "star",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 749,
#       "end_char": 754
#     },
#     {
#       "id": 11,
#       "text": "gravitationally",
#       "lemma": "gravitationally",
#       "upos": "ADV",
#       "xpos": "RB",
#       "feats": "Degree=Pos",
#       "start_char": 755,
#       "end_char": 770
#     },
#     {
#       "id": 12,
#       "text": "bound",
#       "lemma": "bind",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 771,
#       "end_char": 776
#     },
#     {
#       "id": 13,
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 777,
#       "end_char": 779
#     },
#     {
#       "id": 14,
#       "text": "each",
#       "lemma": "each",
#       "upos": "DET",
#       "xpos": "DT",
#       "start_char": 780,
#       "end_char": 784
#     },
#     {
#       "id": 15,
#       "text": "other",
#       "lemma": "other",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 785,
#       "end_char": 790
#     },
#     {
#       "id": 16,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 790,
#       "end_char": 791
#     },
#     {
#       "id": 17,
#       "text": "often",
#       "lemma": "often",
#       "upos": "ADV",
#       "xpos": "RB",
#       "feats": "Degree=Pos",
#       "start_char": 792,
#       "end_char": 797
#     },
#     {
#       "id": 18,
#       "text": "with",
#       "lemma": "with",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 798,
#       "end_char": 802
#     },
#     {
#       "id": 19,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 803,
#       "end_char": 806
#     },
#     {
#       "id": 20,
#       "text": "two",
#       "lemma": "two",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 807,
#       "end_char": 810
#     },
#     {
#       "id": 21,
#       "text": "components",
#       "lemma": "component",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 811,
#       "end_char": 821
#     },
#     {
#       "id": 22,
#       "text": "having",
#       "lemma": "have",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "start_char": 822,
#       "end_char": 828
#     },
#     {
#       "id": 23,
#       "text": "similar",
#       "lemma": "similar",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 829,
#       "end_char": 836
#     },
#     {
#       "id": 24,
#       "text": "masses",
#       "lemma": "mass",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 837,
#       "end_char": 843
#     },
#     {
#       "id": 25,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 843,
#       "end_char": 844
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "it",
#       "lemma": "it",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs",
#       "start_char": 845,
#       "end_char": 847
#     },
#     {
#       "id": 2,
#       "text": "remains",
#       "lemma": "remain",
#       "upos": "VERB",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 848,
#       "end_char": 855
#     },
#     {
#       "id": 3,
#       "text": "unclear",
#       "lemma": "unclear",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 856,
#       "end_char": 863
#     },
#     {
#       "id": 4,
#       "text": "how",
#       "lemma": "how",
#       "upos": "SCONJ",
#       "xpos": "WRB",
#       "feats": "PronType=Int",
#       "start_char": 864,
#       "end_char": 867
#     },
#     {
#       "id": 5,
#       "text": "these",
#       "lemma": "this",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Number=Plur|PronType=Dem",
#       "start_char": 868,
#       "end_char": 873
#     },
#     {
#       "id": 6,
#       "text": "systems",
#       "lemma": "system",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 874,
#       "end_char": 881
#     },
#     {
#       "id": 7,
#       "text": "assemble",
#       "lemma": "assemble",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 882,
#       "end_char": 890
#     },
#     {
#       "id": 8,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 891,
#       "end_char": 894
#     },
#     {
#       "id": 9,
#       "text": "accrete",
#       "lemma": "accrete",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 895,
#       "end_char": 902
#     },
#     {
#       "id": 10,
#       "text": "material",
#       "lemma": "material",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 903,
#       "end_char": 911
#     },
#     {
#       "id": 11,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 911,
#       "end_char": 912
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "alves",
#       "lemma": "alves",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 913,
#       "end_char": 918
#     },
#     {
#       "id": 2,
#       "text": "et",
#       "lemma": "et",
#       "upos": "X",
#       "xpos": "FW",
#       "start_char": 919,
#       "end_char": 921
#     },
#     {
#       "id": 3,
#       "text": "al.",
#       "lemma": "al.",
#       "upos": "X",
#       "xpos": "FW",
#       "start_char": 922,
#       "end_char": 925
#     },
#     {
#       "id": 4,
#       "text": "made",
#       "lemma": "make",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "start_char": 926,
#       "end_char": 930
#     },
#     {
#       "id": 5,
#       "text": "high",
#       "lemma": "high",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 931,
#       "end_char": 935
#     },
#     {
#       "id": 6,
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "start_char": 935,
#       "end_char": 936
#     },
#     {
#       "id": 7,
#       "text": "resolution",
#       "lemma": "resolution",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 936,
#       "end_char": 946
#     },
#     {
#       "id": 8,
#       "text": "observations",
#       "lemma": "observation",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 947,
#       "end_char": 959
#     },
#     {
#       "id": 9,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 960,
#       "end_char": 962
#     },
#     {
#       "id": 10,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 963,
#       "end_char": 964
#     },
#     {
#       "id": 11,
#       "text": "young",
#       "lemma": "young",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 965,
#       "end_char": 970
#     },
#     {
#       "id": 12,
#       "text": "binary",
#       "lemma": "binary",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 971,
#       "end_char": 977
#     },
#     {
#       "id": 13,
#       "text": "star",
#       "lemma": "star",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 978,
#       "end_char": 982
#     },
#     {
#       "id": 14,
#       "text": "that",
#       "lemma": "that",
#       "upos": "PRON",
#       "xpos": "WDT",
#       "feats": "PronType=Rel",
#       "start_char": 983,
#       "end_char": 987
#     },
#     {
#       "id": 15,
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 988,
#       "end_char": 990
#     },
#     {
#       "id": 16,
#       "text": "still",
#       "lemma": "still",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 991,
#       "end_char": 996
#     },
#     {
#       "id": 17,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 997,
#       "end_char": 999
#     },
#     {
#       "id": 18,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 1000,
#       "end_char": 1003
#     },
#     {
#       "id": 19,
#       "text": "process",
#       "lemma": "process",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1004,
#       "end_char": 1011
#     },
#     {
#       "id": 20,
#       "text": "of",
#       "lemma": "of",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 1012,
#       "end_char": 1014
#     },
#     {
#       "id": 21,
#       "text": "forming",
#       "lemma": "form",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "start_char": 1015,
#       "end_char": 1022
#     },
#     {
#       "id": 22,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 1022,
#       "end_char": 1023
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 1024,
#       "end_char": 1025
#     },
#     {
#       "id": 2,
#       "text": "large",
#       "lemma": "large",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 1026,
#       "end_char": 1031
#     },
#     {
#       "id": 3,
#       "text": "disk",
#       "lemma": "disk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1032,
#       "end_char": 1036
#     },
#     {
#       "id": 4,
#       "text": "surrounds",
#       "lemma": "surround",
#       "upos": "VERB",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 1037,
#       "end_char": 1046
#     },
#     {
#       "id": 5,
#       "text": "both",
#       "lemma": "both",
#       "upos": "DET",
#       "xpos": "DT",
#       "start_char": 1047,
#       "end_char": 1051
#     },
#     {
#       "id": 6,
#       "text": "stars",
#       "lemma": "star",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 1052,
#       "end_char": 1057
#     },
#     {
#       "id": 7,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 1057,
#       "end_char": 1058
#     },
#     {
#       "id": 8,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 1059,
#       "end_char": 1062
#     },
#     {
#       "id": 9,
#       "text": "each",
#       "lemma": "each",
#       "upos": "DET",
#       "xpos": "DT",
#       "start_char": 1063,
#       "end_char": 1067
#     },
#     {
#       "id": 10,
#       "text": "component",
#       "lemma": "component",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1068,
#       "end_char": 1077
#     },
#     {
#       "id": 11,
#       "text": "also",
#       "lemma": "also",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 1078,
#       "end_char": 1082
#     },
#     {
#       "id": 12,
#       "text": "has",
#       "lemma": "have",
#       "upos": "VERB",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 1083,
#       "end_char": 1086
#     },
#     {
#       "id": 13,
#       "text": "its",
#       "lemma": "its",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Gender=Neut|Number=Sing|Person=3|Poss=Yes|PronType=Prs",
#       "start_char": 1087,
#       "end_char": 1090
#     },
#     {
#       "id": 14,
#       "text": "own",
#       "lemma": "own",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 1091,
#       "end_char": 1094
#     },
#     {
#       "id": 15,
#       "text": "smaller",
#       "lemma": "small",
#       "upos": "ADJ",
#       "xpos": "JJR",
#       "feats": "Degree=Cmp",
#       "start_char": 1095,
#       "end_char": 1102
#     },
#     {
#       "id": 16,
#       "text": "circumstellar",
#       "lemma": "circumstellar",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 1103,
#       "end_char": 1116
#     },
#     {
#       "id": 17,
#       "text": "disk",
#       "lemma": "disk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1117,
#       "end_char": 1121
#     },
#     {
#       "id": 18,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 1121,
#       "end_char": 1122
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "spiral",
#       "lemma": "spiral",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 1123,
#       "end_char": 1129
#     },
#     {
#       "id": 2,
#       "text": "filaments",
#       "lemma": "filament",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 1130,
#       "end_char": 1139
#     },
#     {
#       "id": 3,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 1140,
#       "end_char": 1142
#     },
#     {
#       "id": 4,
#       "text": "dust",
#       "lemma": "dust",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1143,
#       "end_char": 1147
#     },
#     {
#       "id": 5,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 1148,
#       "end_char": 1151
#     },
#     {
#       "id": 6,
#       "text": "gas",
#       "lemma": "gas",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1152,
#       "end_char": 1155
#     },
#     {
#       "id": 7,
#       "text": "connect",
#       "lemma": "connect",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 1156,
#       "end_char": 1163
#     },
#     {
#       "id": 8,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 1164,
#       "end_char": 1167
#     },
#     {
#       "id": 9,
#       "text": "small",
#       "lemma": "small",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 1168,
#       "end_char": 1173
#     },
#     {
#       "id": 10,
#       "text": "disks",
#       "lemma": "disk",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 1174,
#       "end_char": 1179
#     },
#     {
#       "id": 11,
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 1180,
#       "end_char": 1182
#     },
#     {
#       "id": 12,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 1183,
#       "end_char": 1186
#     },
#     {
#       "id": 13,
#       "text": "larger",
#       "lemma": "large",
#       "upos": "ADJ",
#       "xpos": "JJR",
#       "feats": "Degree=Cmp",
#       "start_char": 1187,
#       "end_char": 1193
#     },
#     {
#       "id": 14,
#       "text": "one",
#       "lemma": "one",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Word|NumType=Card",
#       "start_char": 1194,
#       "end_char": 1197
#     },
#     {
#       "id": 15,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 1197,
#       "end_char": 1198
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "material",
#       "lemma": "material",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1199,
#       "end_char": 1207
#     },
#     {
#       "id": 2,
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 1208,
#       "end_char": 1210
#     },
#     {
#       "id": 3,
#       "text": "accreting",
#       "lemma": "accrete",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "Tense=Pres|VerbForm=Part",
#       "start_char": 1211,
#       "end_char": 1220
#     },
#     {
#       "id": 4,
#       "text": "preferentially",
#       "lemma": "preferentially",
#       "upos": "ADV",
#       "xpos": "RB",
#       "feats": "Degree=Pos",
#       "start_char": 1221,
#       "end_char": 1235
#     },
#     {
#       "id": 5,
#       "text": "onto",
#       "lemma": "onto",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 1236,
#       "end_char": 1240
#     },
#     {
#       "id": 6,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 1241,
#       "end_char": 1244
#     },
#     {
#       "id": 7,
#       "text": "star",
#       "lemma": "star",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1245,
#       "end_char": 1249
#     },
#     {
#       "id": 8,
#       "text": "that",
#       "lemma": "that",
#       "upos": "PRON",
#       "xpos": "WDT",
#       "feats": "PronType=Rel",
#       "start_char": 1250,
#       "end_char": 1254
#     },
#     {
#       "id": 9,
#       "text": "currently",
#       "lemma": "currently",
#       "upos": "ADV",
#       "xpos": "RB",
#       "feats": "Degree=Pos",
#       "start_char": 1255,
#       "end_char": 1264
#     },
#     {
#       "id": 10,
#       "text": "has",
#       "lemma": "have",
#       "upos": "VERB",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 1265,
#       "end_char": 1268
#     },
#     {
#       "id": 11,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 1269,
#       "end_char": 1270
#     },
#     {
#       "id": 12,
#       "text": "lower",
#       "lemma": "low",
#       "upos": "ADJ",
#       "xpos": "JJR",
#       "feats": "Degree=Cmp",
#       "start_char": 1271,
#       "end_char": 1276
#     },
#     {
#       "id": 13,
#       "text": "mass",
#       "lemma": "mass",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1277,
#       "end_char": 1281
#     },
#     {
#       "id": 14,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 1281,
#       "end_char": 1282
#     },
#     {
#       "id": 15,
#       "text": "driving",
#       "lemma": "drive",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "start_char": 1283,
#       "end_char": 1290
#     },
#     {
#       "id": 16,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 1291,
#       "end_char": 1294
#     },
#     {
#       "id": 17,
#       "text": "masses",
#       "lemma": "mass",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 1295,
#       "end_char": 1301
#     },
#     {
#       "id": 18,
#       "text": "toward",
#       "lemma": "toward",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 1302,
#       "end_char": 1308
#     },
#     {
#       "id": 19,
#       "text": "similar",
#       "lemma": "similar",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 1309,
#       "end_char": 1316
#     },
#     {
#       "id": 20,
#       "text": "values",
#       "lemma": "value",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 1317,
#       "end_char": 1323
#     },
#     {
#       "id": 21,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 1323,
#       "end_char": 1324
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 1325,
#       "end_char": 1328
#     },
#     {
#       "id": 2,
#       "text": "lack",
#       "lemma": "lack",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1329,
#       "end_char": 1333
#     },
#     {
#       "id": 3,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 1334,
#       "end_char": 1336
#     },
#     {
#       "id": 4,
#       "text": "sensory",
#       "lemma": "sensory",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 1337,
#       "end_char": 1344
#     },
#     {
#       "id": 5,
#       "text": "feedback",
#       "lemma": "feedback",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1345,
#       "end_char": 1353
#     },
#     {
#       "id": 6,
#       "text": "from",
#       "lemma": "from",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 1354,
#       "end_char": 1358
#     },
#     {
#       "id": 7,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 1359,
#       "end_char": 1362
#     },
#     {
#       "id": 8,
#       "text": "leg",
#       "lemma": "leg",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1363,
#       "end_char": 1366
#     },
#     {
#       "id": 9,
#       "text": "prosthesis",
#       "lemma": "prosthesis",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 1367,
#       "end_char": 1377
#     },
#     {
#       "id": 10,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 1378,
#       "end_char": 1380
#     },
#     {
#       "id": 11,
#       "text": "lower",
#       "lemma": "low",
#       "upos": "ADJ",
#       "xpos": "JJR",
#       "feats": "Degree=Cmp",
#       "start_char": 1381,
#       "end_char": 1386
#     },
#     {
# ...
#       "end_char": 11634
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "by",
#       "lemma": "by",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 11635,
#       "end_char": 11637
#     },
#     {
#       "id": 2,
#       "text": "studying",
#       "lemma": "study",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "start_char": 11638,
#       "end_char": 11646
#     },
#     {
#       "id": 3,
#       "text": "b",
#       "lemma": "b",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11647,
#       "end_char": 11648
#     },
#     {
#       "id": 4,
#       "text": "cell",
#       "lemma": "cell",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11649,
#       "end_char": 11653
#     },
#     {
#       "id": 5,
#       "text": "development",
#       "lemma": "development",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11654,
#       "end_char": 11665
#     },
#     {
#       "id": 6,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 11666,
#       "end_char": 11668
#     },
#     {
#       "id": 7,
#       "text": "neonatal",
#       "lemma": "neonatal",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 11669,
#       "end_char": 11677
#     },
#     {
#       "id": 8,
#       "text": "mice",
#       "lemma": "mouse",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 11678,
#       "end_char": 11682
#     },
#     {
#       "id": 9,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 11682,
#       "end_char": 11683
#     },
#     {
#       "id": 10,
#       "text": "vanhee",
#       "lemma": "vanhee",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 11684,
#       "end_char": 11690
#     },
#     {
#       "id": 11,
#       "text": "et",
#       "lemma": "et",
#       "upos": "X",
#       "xpos": "FW",
#       "start_char": 11691,
#       "end_char": 11693
#     },
#     {
#       "id": 12,
#       "text": "al",
#       "lemma": "al",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 11694,
#       "end_char": 11696
#     },
#     {
#       "id": 13,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 11696,
#       "end_char": 11697
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "uncovered",
#       "lemma": "uncover",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "start_char": 11698,
#       "end_char": 11707
#     },
#     {
#       "id": 2,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 11708,
#       "end_char": 11711
#     },
#     {
#       "id": 3,
#       "text": "importance",
#       "lemma": "importance",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11712,
#       "end_char": 11722
#     },
#     {
#       "id": 4,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 11723,
#       "end_char": 11725
#     },
#     {
#       "id": 5,
#       "text": "rna",
#       "lemma": "rna",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11726,
#       "end_char": 11729
#     },
#     {
#       "id": 6,
#       "text": "binding",
#       "lemma": "bind",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "start_char": 11730,
#       "end_char": 11737
#     },
#     {
#       "id": 7,
#       "text": "protein",
#       "lemma": "protein",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11738,
#       "end_char": 11745
#     },
#     {
#       "id": 8,
#       "text": "lin28",
#       "lemma": "lin28",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11746,
#       "end_char": 11751
#     },
#     {
#       "id": 9,
#       "text": "b",
#       "lemma": "b",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11751,
#       "end_char": 11752
#     },
#     {
#       "id": 10,
#       "text": "in",
#       "lemma": "in",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 11753,
#       "end_char": 11755
#     },
#     {
#       "id": 11,
#       "text": "facilitating",
#       "lemma": "facilitate",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "start_char": 11756,
#       "end_char": 11768
#     },
#     {
#       "id": 12,
#       "text": "positive",
#       "lemma": "positive",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 11769,
#       "end_char": 11777
#     },
#     {
#       "id": 13,
#       "text": "selection",
#       "lemma": "selection",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11778,
#       "end_char": 11787
#     },
#     {
#       "id": 14,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 11788,
#       "end_char": 11790
#     },
#     {
#       "id": 15,
#       "text": "self",
#       "lemma": "self",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11791,
#       "end_char": 11795
#     },
#     {
#       "id": 16,
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "start_char": 11795,
#       "end_char": 11796
#     },
#     {
#       "id": 17,
#       "text": "reactive",
#       "lemma": "reactive",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 11796,
#       "end_char": 11804
#     },
#     {
#       "id": 18,
#       "text": "b-",
#       "lemma": "b-",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11805,
#       "end_char": 11807
#     },
#     {
#       "id": 19,
#       "text": "1",
#       "lemma": "1",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 11807,
#       "end_char": 11808
#     },
#     {
#       "id": 20,
#       "text": "cells",
#       "lemma": "cell",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 11809,
#       "end_char": 11814
#     },
#     {
#       "id": 21,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 11815,
#       "end_char": 11817
#     },
#     {
#       "id": 22,
#       "text": "neonates",
#       "lemma": "neonate",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 11818,
#       "end_char": 11826
#     },
#     {
#       "id": 23,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 11826,
#       "end_char": 11827
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "they",
#       "lemma": "they",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=3|PronType=Prs",
#       "start_char": 11828,
#       "end_char": 11832
#     },
#     {
#       "id": 2,
#       "text": "also",
#       "lemma": "also",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 11833,
#       "end_char": 11837
#     },
#     {
#       "id": 3,
#       "text": "found",
#       "lemma": "find",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "start_char": 11838,
#       "end_char": 11843
#     },
#     {
#       "id": 4,
#       "text": "that",
#       "lemma": "that",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 11844,
#       "end_char": 11848
#     },
#     {
#       "id": 5,
#       "text": "ectopic",
#       "lemma": "ectopic",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 11849,
#       "end_char": 11856
#     },
#     {
#       "id": 6,
#       "text": "expression",
#       "lemma": "expression",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11857,
#       "end_char": 11867
#     },
#     {
#       "id": 7,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 11868,
#       "end_char": 11870
#     },
#     {
#       "id": 8,
#       "text": "lin28",
#       "lemma": "lin28",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11871,
#       "end_char": 11876
#     },
#     {
#       "id": 9,
#       "text": "b",
#       "lemma": "b",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11876,
#       "end_char": 11877
#     },
#     {
#       "id": 10,
#       "text": "was",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#       "start_char": 11878,
#       "end_char": 11881
#     },
#     {
#       "id": 11,
#       "text": "sufficient",
#       "lemma": "sufficient",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 11882,
#       "end_char": 11892
#     },
#     {
#       "id": 12,
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "start_char": 11893,
#       "end_char": 11895
#     },
#     {
#       "id": 13,
#       "text": "promote",
#       "lemma": "promote",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 11896,
#       "end_char": 11903
#     },
#     {
#       "id": 14,
#       "text": "selection",
#       "lemma": "selection",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11904,
#       "end_char": 11913
#     },
#     {
#       "id": 15,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 11914,
#       "end_char": 11916
#     },
#     {
#       "id": 16,
#       "text": "self",
#       "lemma": "self",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11917,
#       "end_char": 11921
#     },
#     {
#       "id": 17,
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "start_char": 11921,
#       "end_char": 11922
#     },
#     {
#       "id": 18,
#       "text": "reactive",
#       "lemma": "reactive",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 11922,
#       "end_char": 11930
#     },
#     {
#       "id": 19,
#       "text": "b-",
#       "lemma": "b-",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11931,
#       "end_char": 11933
#     },
#     {
#       "id": 20,
#       "text": "1",
#       "lemma": "1",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 11933,
#       "end_char": 11934
#     },
#     {
#       "id": 21,
#       "text": "cells",
#       "lemma": "cell",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 11935,
#       "end_char": 11940
#     },
#     {
#       "id": 22,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 11941,
#       "end_char": 11943
#     },
#     {
#       "id": 23,
#       "text": "adult",
#       "lemma": "adult",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 11944,
#       "end_char": 11949
#     },
#     {
#       "id": 24,
#       "text": "mice",
#       "lemma": "mouse",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 11950,
#       "end_char": 11954
#     },
#     {
#       "id": 25,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 11954,
#       "end_char": 11955
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 11956,
#       "end_char": 11959
#     },
#     {
#       "id": 2,
#       "text": "authors",
#       "lemma": "author",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 11960,
#       "end_char": 11967
#     },
#     {
#       "id": 3,
#       "text": "propose",
#       "lemma": "propose",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 11968,
#       "end_char": 11975
#     },
#     {
#       "id": 4,
#       "text": "that",
#       "lemma": "that",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 11976,
#       "end_char": 11980
#     },
#     {
#       "id": 5,
#       "text": "lin28",
#       "lemma": "lin28",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11981,
#       "end_char": 11986
#     },
#     {
#       "id": 6,
#       "text": "b",
#       "lemma": "b",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 11986,
#       "end_char": 11987
#     },
#     {
#       "id": 7,
#       "text": "functions",
#       "lemma": "function",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 11988,
#       "end_char": 11997
#     },
#     {
#       "id": 8,
#       "text": "as",
#       "lemma": "as",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 11998,
#       "end_char": 12000
#     },
#     {
#       "id": 9,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 12001,
#       "end_char": 12002
#     },
#     {
#       "id": 10,
#       "text": "cell-intrinsic",
#       "lemma": "cell-intrinsic",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 12003,
#       "end_char": 12017
#     },
#     {
#       "id": 11,
#       "text": "switch",
#       "lemma": "switch",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 12018,
#       "end_char": 12024
#     },
#     {
#       "id": 12,
#       "text": "that",
#       "lemma": "that",
#       "upos": "PRON",
#       "xpos": "WDT",
#       "feats": "PronType=Rel",
#       "start_char": 12025,
#       "end_char": 12029
#     },
#     {
#       "id": 13,
#       "text": "jumpstarts",
#       "lemma": "jumpstart",
#       "upos": "VERB",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 12030,
#       "end_char": 12040
#     },
#     {
#       "id": 14,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 12041,
#       "end_char": 12044
#     },
#     {
#       "id": 15,
#       "text": "generation",
#       "lemma": "generation",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 12045,
#       "end_char": 12055
#     },
#     {
#       "id": 16,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 12056,
#       "end_char": 12058
#     },
#     {
#       "id": 17,
#       "text": "b",
#       "lemma": "b",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 12059,
#       "end_char": 12060
#     },
#     {
#       "id": 18,
#       "text": "cells",
#       "lemma": "cell",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 12061,
#       "end_char": 12066
#     },
#     {
#       "id": 19,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 12067,
#       "end_char": 12069
#     },
#     {
#       "id": 20,
#       "text": "early",
#       "lemma": "early",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 12070,
#       "end_char": 12075
#     },
#     {
#       "id": 21,
#       "text": "life",
#       "lemma": "life",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 12076,
#       "end_char": 12080
#     },
#     {
#       "id": 22,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 12080,
#       "end_char": 12081
#     }
#   ]
# ]

# %%
processed_dataset = [political_out_docs, science_out_docs, sport_out_docs]

# %%
def save_pickle(data, name):
    with open(name, 'wb') as handle:
        pickle.dump(data, handle)

# %%
save_pickle(processed_dataset,"processed_dataset.pickle")

# %%
save_pickle(political_out_docs,"political_out.pickle")
save_pickle(science_out_docs,"science_out.pickle")
save_pickle(sport_out_docs,"sport_out.pickle")

# %% [markdown]
# # NAIVE BAYES CLASSIFICATION

# %%
def get_pos(data):
  pos_dict = []
  for el in data:
    pos_doc = []
    for word in el.iter_words():
      pos_doc.append(word.xpos)
    pos_dict.append(pos_doc)
  return pos_dict

# %%
political_pos = get_pos(political_out_docs)
science_pos = get_pos(science_out_docs)
sport_pos = get_pos(sport_out_docs)

# %%
 from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer()
bigrams_vectorizer = CountVectorizer(ngram_range=(2,2))
trigrams_vectorizer = CountVectorizer(ngram_range=(3,3))

pos_corpus = political_pos + science_pos + sport_pos
pos_corpus = [" ".join(el) for el in pos_corpus]
pos_bow = vectorizer.fit_transform(pos_corpus)
bigrams_bow = bigrams_vectorizer.fit_transform(pos_corpus)
trigrams_bow = trigrams_vectorizer.fit_transform(pos_corpus)

# %% [markdown]
# ## Experiment 1: Naive Bayes with unigram pos tags

# %%
import numpy as np
from sklearn.naive_bayes import MultinomialNB
import scipy.sparse as sp
from sklearn.model_selection import train_test_split

clf = MultinomialNB()

X = pos_bow.toarray()
y = np.concatenate((np.zeros(96, dtype=int),np.ones(136, dtype=int),np.full(shape=95,fill_value=2,dtype=np.int)))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
y_pred = clf.fit(X_train, y_train).predict(X_test)
print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 99 points : 16

# %% [markdown]
# ## Experiment 2: Naive Bayes with bigram pos tags

# %%
X = bigrams_bow.toarray()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
y_pred = clf.fit(X_train, y_train).predict(X_test)
print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 99 points : 10

# %% [markdown]
# ## Experiment 3: Naive Bayes with trigram pos tags

# %%
X = trigrams_bow.toarray()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
y_pred = clf.fit(X_train, y_train).predict(X_test)
print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 99 points : 10

# %% [markdown]
# # SVM CLASSIFICATION

# %% [markdown]
# ## features extraction

# %%
pos_freq = {}
for docs in processed_dataset: 
  for el in docs:
    for word in el.iter_words():
      if word.pos not in pos_freq:
        pos_freq[word.pos] = 1 
      else:
        pos_freq[word.pos] += 1

pos_freq = sorted(pos_freq.items(), key = lambda x:x[1], reverse=True)
pos_freq
# Out:
# [('NOUN', 226136),
#  ('VERB', 157099),
#  ('PUNCT', 156309),
#  ('PRON', 143886),
#  ('ADP', 108045),
#  ('DET', 95356),
#  ('AUX', 83176),
#  ('ADJ', 78692),
#  ('ADV', 61275),
#  ('CCONJ', 43747),
#  ('PART', 36036),
#  ('SCONJ', 26854),
#  ('PROPN', 24752),
#  ('NUM', 15003),
#  ('INTJ', 5818),
#  ('X', 5443),
#  ('SYM', 1782)]

# %%
xpos_freq = {}
for docs in processed_dataset: 
  for el in docs:
    for word in el.iter_words():
      if word.xpos not in xpos_freq:
        xpos_freq[word.xpos] = 1 
      else:
        xpos_freq[word.xpos] += 1

xpos_freq = sorted(xpos_freq.items(), key = lambda x:x[1], reverse=True)
xpos_freq
# Out:
# [('NN', 168279),
#  ('IN', 122104),
#  ('DT', 106129),
#  ('PRP', 95609),
#  ('.', 75332),
#  ('JJ', 72807),
#  ('RB', 68339),
#  (',', 67062),
#  ('NNS', 61691),
#  ('VB', 56388),
#  ('VBP', 49665),
#  ('CC', 43747),
#  ('VBD', 34672),
#  ('VBZ', 33245),
#  ('VBN', 25912),
#  ('VBG', 24911),
#  ('NNP', 24225),
#  ('TO', 23609),
#  ('MD', 15470),
#  ('CD', 14928),
#  ('PRP$', 13712),
#  ('WDT', 9390),
#  ('WRB', 7278),
#  ('WP', 6953),
#  ('RP', 6754),
#  ('UH', 5818),
#  ('FW', 5397),
#  ('HYPH', 3492),
#  ('JJR', 3186),
#  ('EX', 2845),
#  ('``', 2560),
#  ("''", 2543),
#  ('JJS', 2279),
#  ('-RRB-', 2260),
#  ('-LRB-', 2249),
#  ('RBR', 1781),
#  ('POS', 1740),
#  ('PDT', 1359),
#  ('NNPS', 953),
#  (':', 892),
#  ('SYM', 763),
#  ('RBS', 599),
#  ('$', 289),
#  ('LS', 85),
#  ('WP$', 42),
#  ('ADD', 42),
#  ('NFP', 18),
#  ('AFX', 6)]

# %%
functors = ["ADP","AUX","CCONJ","DET","PART","PRON","SCONJ"]
functors_freq = {}
for docs in processed_dataset: 
  for el in docs:
    for word in el.iter_words():
      if word.pos in functors:
        if word.text not in functors_freq:
          functors_freq[word.text] = 1 
        else:
          functors_freq[word.text] += 1

functors_freq = sorted(functors_freq.items(), key = lambda x:x[1], reverse=True)
functors_freq[:405]
# Out:
# [('the', 48281),
#  ('and', 33986),
#  ('to', 33120),
#  ('of', 25190),
#  ('that', 23772),
#  ('a', 22381),
#  ('i', 21713),
#  ('in', 18603),
#  ('you', 16953),
#  ('we', 16622),
#  ('it', 14691),
#  ('’s', 12669),
#  ('for', 9339),
#  ('is', 9073),
#  ('this', 8594),
#  ('they', 8566),
#  ('n’t', 6656),
#  ('with', 6573),
#  ('be', 6330),
#  ('but', 6308),
#  ('on', 6170),
#  ('he', 6120),
#  ('was', 6093),
#  ('’re', 5480),
#  ('are', 5448),
#  ('what', 4897),
#  ('by', 4045),
#  ('our', 4036),
#  ('not', 4012),
#  ('at', 3898),
#  ('all', 3799),
#  ('do', 3779),
#  ('as', 3733),
#  ('from', 3686),
#  ('can', 3672),
#  ('’ve', 3197),
#  ('about', 3031),
#  ('me', 2988),
#  ('my', 2963),
#  ('if', 2933),
#  ('an', 2917),
#  ('or', 2863),
#  ('have', 2860),
#  ('there', 2855),
#  ('will', 2852),
#  ('been', 2828),
#  ('because', 2824),
#  ('’m', 2788),
#  ('out', 2729),
#  ('your', 2728),
#  ('were', 2660),
#  ('up', 2532),
#  ('when', 2485),
#  ('these', 2460),
#  ('like', 2357),
#  ('who', 2248),
#  ('would', 2147),
#  ('them', 2061),
#  ('their', 1942),
#  ('which', 1830),
#  ('some', 1804),
#  ('those', 1742),
#  ('could', 1730),
#  ('has', 1692),
#  ('us', 1632),
#  ('how', 1619),
#  ('than', 1585),
#  ('did', 1584),
#  ('no', 1388),
#  ('into', 1375),
#  ('him', 1367),
#  ('his', 1324),
#  ('’ll', 1318),
#  ('where', 1253),
#  ('through', 1082),
#  ('every', 1076),
#  ('any', 995),
#  ('over', 954),
#  ('she', 910),
#  ('ca', 887),
#  ('after', 871),
#  ('down', 842),
#  ('being', 828),
#  ('may', 777),
#  ('does', 748),
#  ('should', 740),
#  ('why', 625),
#  ('between', 586),
#  ('before', 585),
#  ('both', 579),
#  ('during', 535),
#  ('under', 526),
#  ('off', 502),
#  ('against', 491),
#  ('everything', 489),
#  ('something', 485),
#  ('her', 475),
#  ('another', 461),
#  ('everybody', 446),
#  ('its', 444),
#  ('each', 433),
#  ('across', 403),
#  ('had', 390),
#  ('around', 388),
#  ('’d', 386),
#  ('whether', 366),
#  ('might', 359),
#  ('without', 355),
#  ('within', 354),
#  ('nothing', 353),
#  ('everyone', 332),
#  ('am', 330),
#  ('since', 305),
#  ("'s", 293),
#  ('anything', 279),
#  ('while', 247),
#  ('i’m', 238),
#  ('nobody', 232),
#  ('until', 224),
#  ('whatever', 222),
#  ('must', 211),
#  ('throughout', 207),
#  ('anybody', 204),
#  ('myself', 203),
#  ('i’ll', 203),
#  ('wo', 193),
#  ('get', 187),
#  ('although', 184),
#  ('somebody', 181),
#  ('either', 174),
#  ('got', 164),
#  ('i’d', 159),
#  ('such', 156),
#  ('behind', 147),
#  ('cannot', 145),
#  ('along', 138),
#  ('once', 136),
#  ('so', 130),
#  ('among', 117),
#  ('yourself', 115),
#  ('themselves', 111),
#  ('anyone', 108),
#  ('toward', 95),
#  ('whereas', 95),
#  ('someone', 94),
#  ('though', 93),
#  ('y’all', 93),
#  ('itself', 90),
#  ('beyond', 87),
#  ('despite', 87),
#  ('himself', 84),
#  ('upon', 83),
#  ('outside', 79),
#  ('half', 75),
#  ('inside', 71),
#  ('per', 69),
#  ('versus', 68),
#  ('plus', 68),
#  ('getting', 68),
#  ('ai', 67),
#  ('yet', 62),
#  ('towards', 62),
#  ('back', 60),
#  ('ourselves', 58),
#  ('unless', 57),
#  ('mine', 56),
#  ('’', 51),
#  ('due', 51),
#  ('except', 50),
#  ('gets', 48),
#  ('above', 46),
#  ('whoever', 45),
#  ('unlike', 43),
#  ('whose', 42),
#  ("'", 42),
#  ('quite', 41),
#  ('near', 38),
#  ('onto', 38),
#  ('whenever', 36),
#  ('having', 35),
#  ('till', 34),
#  ('past', 33),
#  ('via', 33),
#  ('below', 30),
#  ('away', 26),
#  ('whom', 25),
#  ('alongside', 23),
#  ('wherever', 22),
#  ('neither', 22),
#  ('one', 21),
#  ('covid', 20),
#  ('it.', 19),
#  ('aside', 18),
#  ('yours', 18),
#  ('ours', 18),
#  ('s', 18),
#  ('shall', 16),
#  ('yourselves', 15),
#  ('together', 15),
#  ('ought', 15),
#  ('herself', 14),
#  ('yo', 11),
#  ('nor', 10),
#  ('cause', 10),
#  ('yes.', 9),
#  ('besides', 9),
#  ('amongst', 8),
#  ('n’t.', 8),
#  ('re', 7),
#  ('’t', 7),
#  ('a…', 7),
#  ('n', 7),
#  ('t', 7),
#  ('til', 6),
#  ('the…', 6),
#  ('underneath', 6),
#  ('&', 6),
#  ('round', 6),
#  ('on.', 6),
#  ('beneath', 6),
#  ('bro.', 6),
#  ('dare', 5),
#  ('whichever', 5),
#  ('yep.', 5),
#  ('wow.', 5),
#  ('et', 5),
#  ('amidst', 5),
#  ('forth', 4),
#  ('hi.', 4),
#  ('whoa.', 4),
#  ('ya', 4),
#  ('wherein', 4),
#  ('em', 4),
#  ('right.', 3),
#  ('hey.', 3),
#  ('apart', 3),
#  ("n't", 3),
#  ('∼', 3),
#  ('hsv2', 3),
#  ('ing', 3),
#  ('themself', 3),
#  ('khabib', 3),
#  ('amid', 2),
#  ('beside', 2),
#  ('ab', 2),
#  ('minus', 2),
#  ('v.', 2),
#  ('didn', 2),
#  ('theirs', 2),
#  ('whomever', 2),
#  ('non-', 2),
#  ('’all', 2),
#  ('h', 2),
#  ('i…', 2),
#  ('is.', 2),
#  ('uphill', 2),
#  ('ya.', 2),
#  ('need', 2),
#  ('na', 2),
#  ('eif5', 2),
#  ('more-', 2),
#  ('th9', 2),
#  ('opposite', 2),
#  ('o', 2),
#  ('en', 2),
#  ('whereby', 2),
#  ('self-', 2),
#  ('ain', 2),
#  ('ben.', 2),
#  ('iu', 2),
#  ('bob.', 2),
#  ('i?', 2),
#  ('i-', 2),
#  ('afresh', 1),
#  ('upward', 1),
#  ('oneself', 1),
#  ('ahmaud', 1),
#  ('3rd.', 1),
#  ('doke', 1),
#  ('i’ve', 1),
#  ('2a.', 1),
#  ('doe', 1),
#  ('thy', 1),
#  ('whence', 1),
#  ('god.', 1),
#  ('or-', 1),
#  ('zero', 1),
#  ('ahead', 1),
#  ('so…', 1),
#  ('usmca', 1),
#  ('we-', 1),
#  ('ron.', 1),
#  ('pro', 1),
#  ('1h1', 1),
#  ('bu', 1),
#  ('ge', 1),
#  ('.we', 1),
#  ('whoa!', 1),
#  ('cornpop', 1),
#  ('too.', 1),
#  ('….', 1),
#  ('me.', 1),
#  ('i’', 1),
#  ('b’d', 1),
#  ('ah.', 1),
#  ('joe.', 1),
#  ('her.', 1),
#  ('home', 1),
#  ('us.', 1),
#  ('oh…', 1),
#  ('shot.', 1),
#  ('i’l', 1),
#  ('wasn', 1),
#  ('’t.', 1),
#  ('let', 1),
#  ('wil', 1),
#  ('-”', 1),
#  ('bnab', 1),
#  ('on-', 1),
#  ('γδ', 1),
#  ('ihpc', 1),
#  ('card9', 1),
#  ('αv', 1),
#  ('mait', 1),
#  ('-atom', 1),
#  ('wen', 1),
#  ('–cd', 1),
#  ('d.', 1),
#  ('irf2', 1),
#  ('ampars', 1),
#  ('dpp4', 1),
#  ('u1', 1),
#  ('rem', 1),
#  ('v-k', 1),
#  ('hspc', 1),
#  ('hk2', 1),
#  ('β-', 1),
#  ('zikv', 1),
#  ('up-', 1),
#  ('—even', 1),
#  ('aβ-', 1),
#  ('ca1', 1),
#  ('c–h', 1),
#  ('up.', 1),
#  ('whereupon', 1),
#  ('v', 1),
#  ('wwp1', 1),
#  ('cptx', 1),
#  ('vqe', 1),
#  ('pkm2', 1),
#  ('atg4', 1),
#  ('nmdars', 1),
#  ('fabp', 1),
#  ('nsp12', 1),
#  ('mt7', 1),
#  ('gcs', 1),
#  ('hem1', 1),
#  ('fese', 1),
#  ('sex-', 1),
#  ('gi1', 1),
#  ('dkk1', 1),
#  ('smbh', 1),
#  ('co-co', 1),
#  ('r', 1),
#  ('tet1', 1),
#  ('pol', 1),
#  ('a.', 1),
#  ('-l1', 1),
#  ('ebov', 1),
#  ('xist', 1),
#  ('sidp', 1),
#  ('laliga', 1),
#  ('barce', 1),
#  ('unada', 1),
#  ('b***h', 1),
#  ('y', 1),
#  ('woo!', 1),
#  ('am.', 1),
#  ('floyd', 1),
#  ('l.', 1),
#  ('jon.', 1),
#  ('i’m-', 1),
#  ('pre', 1),
#  (':i', 1),
#  ('ourself', 1),
#  ('mahome', 1),
#  ('ran.', 1),
#  ('vs', 1),
#  ('in-', 1),
#  ('b', 1),
#  ('shanique', 1),
#  ('classic', 1),
#  ('viddal', 1),
#  ('pound', 1),
#  ('dawodu', 1),
#  ('triple', 1),
#  ('if.', 1),
#  ('atop', 1),
#  ('upwards', 1),
#  ('jt', 1),
#  ('salumani', 1),
#  ('whycom', 1),
#  ('zuora', 1),
#  ('afoul', 1),
#  ('gotten', 1)]

# %%
def get_tokens(data):
  docs = []
  for doc in data:
    tokens = []
    for token in doc.iter_tokens():
      tokens.append(token.text)
    docs.append(tokens)
  return docs

# %%
political_tokens = get_tokens(political_out_docs)
science_tokens = get_tokens(science_out_docs)
sport_tokens = get_tokens(sport_out_docs)

# %%
def get_ngrams(data,n):
  ngrams = zip(*[data[i:] for i in range(n)])
  return [" ".join(ngram) for ngram in ngrams]

# %%
dataset_pos = {}
dataset_pos["politics"] = [(political_tokens[idx], get_ngrams(political_pos[idx],2), get_ngrams(political_pos[idx],3)) for idx in range(len(political_pos))]
dataset_pos["scientist"] = [(science_tokens[idx], get_ngrams(science_pos[idx],2), get_ngrams(science_pos[idx],3)) for idx in range(len(science_pos))]
dataset_pos["sport"] = [(sport_tokens[idx], get_ngrams(sport_pos[idx],2), get_ngrams(sport_pos[idx],3)) for idx in range(len(sport_pos))]

# %%
for el in dataset_pos["sport"]:
  if len(el[0]) == 0:
    print("zero found")
    dataset_pos["sport"].remove(el)
# Out:
# zero found

# %%
bigram_freq = {}

for docs in dataset_pos.items():
  for el in docs[1]:
    for bigram in el[1]: 
      if bigram not in bigram_freq:
        bigram_freq[bigram] = 1
      else:
        bigram_freq[bigram] += 1

bigram_freq = sorted(bigram_freq.items(), key = lambda x:x[1], reverse=True)
bigram_freq
# Out:
# [('DT NN', 51461),
#  ('IN DT', 40641),
#  ('NN IN', 35962),
#  ('PRP VBP', 33880),
#  ('JJ NN', 31402),
#  ('NN .', 26622),
#  ('TO VB', 22980),
#  ('. PRP', 22173),
#  ('NN ,', 21781),
#  ('NN NN', 21724),
#  ('DT JJ', 21701),
#  ('IN NN', 18357),
#  ('PRP VBD', 17520),
#  ('NNS IN', 14238),
#  ('IN PRP', 14193),
#  ('JJ NNS', 13946),
#  (', PRP', 12970),
#  ('VB DT', 11538),
#  ('MD VB', 11001),
#  (', CC', 10624),
#  ('NNS .', 10239),
#  ('CC PRP', 10071),
#  ('DT NNS', 9944),
#  ('IN JJ', 9834),
#  ('NN NNS', 9798),
#  ('NN CC', 9390),
#  ('PRP VBZ', 9373),
#  ('NNS ,', 9138),
#  ('RB VB', 8826),
#  ('PRP MD', 8476),
#  ('. DT', 8269),
#  ('PRP$ NN', 8195),
#  ('. CC', 8176),
#  ('VBP RB', 7983),
#  ('VBN IN', 7896),
#  ('VB IN', 7823),
#  ('RB IN', 7543),
#  ('IN NNS', 7450),
#  ('NN VBZ', 7415),
#  ('RB ,', 6891),
#  ('RB .', 6753),
#  ('RB RB', 6631),
#  ('VB PRP', 6602),
#  ('VBZ DT', 6585),
#  ('IN NNP', 6517),
#  ('VBD DT', 6393),
#  ('. RB', 6262),
#  ('VBP PRP', 6251),
#  (', DT', 6007),
#  ('RB JJ', 5954),
#  ('VBZ RB', 5685),
#  ('JJ IN', 5552),
#  ('IN PRP$', 5529),
#  ('VBP VBG', 5349),
#  ('VBP VBN', 5313),
#  (', IN', 5246),
#  ('VBP DT', 5208),
#  ('PRP .', 5197),
#  ('JJ .', 5177),
#  (', RB', 5058),
#  ('PRP RB', 5026),
#  ('NNS VBP', 5018),
#  ('CC DT', 5000),
#  ('DT VBZ', 4958),
#  ('JJ JJ', 4619),
#  ('CC NN', 4598),
#  ('VBG TO', 4588),
#  ('VBD IN', 4582),
#  ('NNS CC', 4468),
#  ('CC RB', 4390),
#  ('VBP IN', 4328),
#  ('. IN', 4327),
#  ('VBD RB', 4315),
#  ('NNP ,', 4216),
#  ('CD NNS', 4115),
#  ('VBG IN', 3966),
#  ('IN VBG', 3946),
#  ('RB VBN', 3894),
#  ('NNP .', 3801),
#  ('RB PRP', 3795),
#  (', NN', 3585),
#  ('VBG DT', 3572),
#  ('NN RB', 3562),
#  ('VB JJ', 3543),
#  ('NN WDT', 3542),
#  ('VBZ VBN', 3528),
#  ('UH ,', 3517),
#  ('NN TO', 3451),
#  ('NNP NNP', 3412),
#  ('. NNP', 3404),
#  ('NN VBD', 3393),
#  ('VB RB', 3298),
#  ('MD RB', 3210),
#  ('WRB PRP', 3200),
#  ('JJ ,', 3164),
#  ('IN CD', 3159),
#  ('. UH', 3090),
#  (', NNP', 3064),
#  ('VB .', 3046),
#  ('VB NN', 3039),
#  ('NNS WDT', 3025),
#  ('RB DT', 3019),
#  ('VBZ JJ', 3004),
#  ('PRP IN', 2978),
#  ('VBP TO', 2978),
#  ('PRP ,', 2971),
#  ('VBZ IN', 2970),
#  ('VBD PRP', 2922),
#  ('FW FW', 2900),
#  ('PRP$ NNS', 2879),
#  ('CC VB', 2807),
#  ('VBP JJ', 2804),
#  ('. NN', 2742),
#  ('IN IN', 2706),
#  ('PRP VB', 2698),
#  ('CC JJ', 2691),
#  ('VB VBN', 2690),
#  ('CD NN', 2655),
#  ('CC IN', 2614),
#  ('VBN NN', 2497),
#  ('RB VBG', 2494),
#  ('DT IN', 2429),
#  ('DT .', 2416),
#  ('IN RB', 2366),
#  ('NN PRP', 2350),
#  ('VB ,', 2330),
#  ('NNS RB', 2294),
#  ('WP PRP', 2294),
#  (', JJ', 2270),
#  ('VBZ VBG', 2240),
#  ('RB VBD', 2216),
#  ('NNS VBD', 2188),
#  ('VBD JJ', 2171),
#  ('NNP NN', 2158),
#  ('VBN DT', 2149),
#  ('JJ TO', 2124),
#  ('VBN .', 2118),
#  ('VBG NN', 2109),
#  ('PRP$ JJ', 2109),
#  ('VBP ,', 2096),
#  ('. JJ', 2083),
#  ('VBD VBN', 2074),
#  ('VBD ,', 2018),
#  (', ``', 2013),
#  ('WDT VBZ', 2010),
#  (". ''", 2006),
#  ('VB PRP$', 2006),
#  (', VB', 1972),
#  ('. VB', 1969),
#  ('WDT PRP', 1947),
#  ('NN MD', 1879),
#  ('VB RP', 1860),
#  (', VBG', 1848),
#  ('RB VBP', 1846),
#  ('VB TO', 1841),
#  ('CC NNS', 1782),
#  ('WDT VBP', 1777),
#  ('JJ CC', 1745),
#  ('HYPH NN', 1740),
#  ('DT RB', 1732),
#  ('RP IN', 1729),
#  ('NN JJ', 1723),
#  ('NN HYPH', 1720),
#  ('VBD TO', 1720),
#  ('CD IN', 1642),
#  ('. VBP', 1639),
#  ('NNP FW', 1601),
#  ('PRP DT', 1600),
#  ('VBZ NN', 1592),
#  ('NNP CC', 1584),
#  ('NNP VBZ', 1581),
#  ('EX VBZ', 1559),
#  ('VBD VBG', 1548),
#  ('VBG JJ', 1508),
#  ('VBG RB', 1478),
#  ('NN VBN', 1470),
#  ('FW VBD', 1444),
#  (', WDT', 1443),
#  ('VBN TO', 1437),
#  ('WP VBZ', 1436),
#  ('NNS TO', 1426),
#  ('DT JJS', 1423),
#  ('VB NNS', 1419),
#  ('VBN RB', 1400),
#  ('RB CC', 1396),
#  ('DT ,', 1378),
#  ('VBP NN', 1369),
#  ('VBD NN', 1368),
#  ('VBG NNS', 1361),
#  ('NNS MD', 1347),
#  ('DT CD', 1342),
#  ('CC NNP', 1342),
#  ('VBN ,', 1335),
#  ('VBN JJ', 1328),
#  ('NN CD', 1312),
#  ('NN -RRB-', 1303),
#  ('NN VBG', 1276),
#  ('WDT VBD', 1256),
#  ('NN -LRB-', 1256),
#  ('DT NNP', 1245),
#  ('VBN NNS', 1242),
#  ('PDT DT', 1242),
#  ('RP .', 1230),
#  ('. WRB', 1195),
#  (', NNS', 1166),
#  ('CD ,', 1166),
#  ('NNS VBN', 1165),
#  ('VBZ PRP', 1157),
#  ('UH .', 1146),
#  ('RB VBZ', 1145),
#  ('CC VBD', 1126),
#  ('NNP VBD', 1112),
#  ('VBG PRP', 1109),
#  ('POS NN', 1103),
#  ('. NNS', 1086),
#  (', WRB', 1078),
#  ('RB CD', 1073),
#  (', UH', 1064),
#  ('NNS VBG', 1052),
#  ('NN NNP', 1041),
#  (', CD', 1036),
#  ('VBG RP', 1034),
#  ('VBP .', 1022),
#  ('WP VBD', 991),
#  ('VBG .', 990),
#  ('DT VBD', 989),
#  ('NN POS', 987),
#  ('CC VBG', 960),
#  ('JJR IN', 952),
#  ('DT VBN', 914),
#  ('IN ,', 914),
#  ('CC PRP$', 912),
#  ('-LRB- NN', 902),
#  ('PRP CC', 900),
#  ('CD JJ', 899),
#  ('VBD .', 898),
#  ('CD .', 891),
#  ('VB VBG', 883),
#  ('JJS NN', 881),
#  ('JJ HYPH', 881),
#  ('JJR NN', 879),
#  ('VBN VBN', 878),
#  ('VBP NNS', 871),
#  ('VBD RP', 867),
#  ('NN VBP', 863),
#  (', PRP$', 862),
#  ('VBZ TO', 858),
#  ('WRB DT', 848),
#  ('IN WP', 831),
#  ('-RRB- .', 829),
#  ('. PRP$', 828),
#  ('. VBG', 822),
#  ('PRP TO', 819),
#  ('NNP IN', 819),
#  ('CC VBP', 815),
#  ('RB NN', 797),
#  ('WP VBP', 795),
#  ('RP ,', 795),
#  ('. EX', 790),
#  ('VB CC', 781),
#  ('VBG ,', 780),
#  ('NN DT', 769),
#  (', WP', 762),
#  ('RB TO', 759),
#  ('VBZ ,', 757),
#  ('NNS VBZ', 752),
#  ('NN WRB', 746),
#  ('VBD CD', 746),
#  ('IN VBN', 734),
#  (', VBD', 729),
#  ('. WP', 725),
#  (', VBP', 722),
#  ('IN .', 714),
#  ('PRP RP', 712),
#  ("'' PRP", 707),
#  ('JJ CD', 704),
#  ('RP DT', 694),
#  ('WDT MD', 691),
#  (', VBZ', 687),
#  ('VBZ WRB', 687),
#  ('RBR JJ', 684),
#  ('. CD', 683),
#  ('VBD PRP$', 682),
#  ('MD PRP', 663),
#  ('VB NNP', 662),
#  ('PRP VBG', 658),
#  ('-LRB- VB', 656),
#  ('VBZ WP', 653),
#  ('VB WP', 652),
#  ('IN WRB', 651),
#  ('JJ NNP', 651),
#  ('`` UH', 648),
#  ('VBZ .', 640),
#  ('CD CD', 635),
#  ('VBN VBG', 630),
#  ('VBN CC', 630),
#  ('NNS PRP', 629),
#  ('NN WP', 626),
#  ('CD CC', 624),
#  ('NNS JJ', 621),
#  ('JJR NNS', 611),
#  ('WRB JJ', 610),
#  ('NNS WP', 607),
#  ('VBN RP', 597),
#  ('VBP WP', 590),
#  ('CC CD', 588),
#  ('NNS NN', 587),
#  ('CC VBN', 584),
#  ('JJ RB', 584),
#  ('`` PRP', 581),
#  ('VBG PRP$', 580),
#  ('VBP PRP$', 578),
#  ('VBN PRP', 564),
#  ('RP CC', 564),
#  ('VBD NNS', 559),
#  ('CC WRB', 557),
#  (', EX', 553),
#  ('RP RB', 553),
#  ('DT VBP', 543),
#  ('DT MD', 542),
#  ('VBZ PRP$', 540),
#  ('EX VBD', 539),
#  ('NNP POS', 533),
#  ("'' CC", 533),
#  ('VB CD', 524),
#  ('IN WDT', 515),
#  ('NNS -LRB-', 511),
#  ('IN EX', 487),
#  ('VB WRB', 487),
#  ('NN VB', 486),
#  ('CC VBZ', 484),
#  ('HYPH VBN', 480),
#  ('JJ PRP', 479),
#  (', TO', 474),
#  ('PRP JJ', 474),
#  ('. FW', 470),
#  ('WP DT', 469),
#  ('HYPH JJ', 468),
#  ('PRP NNS', 456),
#  (', VBN', 452),
#  ('PRP NN', 449),
#  ('. VBD', 448),
#  ('DT VBG', 445),
#  ('RBS JJ', 445),
#  ('NNP RB', 444),
#  ('DT JJR', 444),
#  ('VBP CD', 443),
#  ('VBZ CD', 442),
#  ('VBG VBN', 441),
#  ('SYM CD', 441),
#  ('JJS NNS', 439),
#  ('NNP NNPS', 417),
#  ('WDT NN', 410),
#  ('IN CC', 408),
#  ('RB WRB', 407),
#  ('TO RB', 403),
#  ('DT RBS', 397),
#  ('NN RP', 397),
#  ('CC WP', 393),
#  ('NN SYM', 393),
#  ('RB JJR', 391),
#  ('EX VBP', 384),
#  ('VBD NNP', 367),
#  ('IN PDT', 366),
#  ('VBP NNP', 360),
#  ('NNP NNS', 358),
#  ('. MD', 355),
#  ('WRB VBP', 355),
#  ('UH VB', 352),
#  ('VBZ NNS', 351),
#  (', MD', 347),
#  ('VBG CC', 342),
#  ('RB RBR', 341),
#  ('NNP -RRB-', 339),
#  ('. VBZ', 335),
#  ('JJS IN', 335),
#  ('VBP RP', 329),
#  ('CC MD', 324),
#  ('NNS DT', 322),
#  ('IN JJR', 321),
#  ('WRB NN', 314),
#  ('CD HYPH', 309),
#  ('VBP VB', 306),
#  ('NNP MD', 304),
#  ('WDT RB', 300),
#  ('RB WP', 299),
#  ('VBZ NNP', 298),
#  ('CD -LRB-', 295),
#  ('NNP JJ', 294),
#  ('VBP WRB', 291),
#  ('CC EX', 291),
#  ('VB VB', 290),
#  ('VB JJR', 289),
#  ('$ CD', 288),
#  ('VBZ RP', 284),
#  ('NNS WRB', 284),
#  ('DT CC', 284),
#  ('FW VB', 279),
#  ('PRP VBN', 278),
#  (", ''", 278),
#  ('WDT DT', 272),
#  ('RB MD', 272),
#  ('-LRB- NNS', 270),
#  ('WRB VBZ', 269),
#  ('IN JJS', 268),
#  ('VBP CC', 265),
#  ('NN :', 264),
#  ('VBD CC', 262),
#  ('CC ,', 260),
#  ('RBR IN', 257),
#  ('NNS VB', 256),
#  ('JJR .', 256),
#  ('JJ DT', 254),
#  ('-RRB- NN', 254),
#  ('RB NNP', 252),
#  ('RB NNS', 252),
#  ('DT PRP', 251),
#  ('JJ VBN', 250),
#  ('CD JJR', 247),
#  ('WRB NNS', 244),
#  ('HYPH IN', 241),
#  ('CD -RRB-', 239),
#  ('WP .', 234),
#  ('RP PRP$', 233),
#  ('CC TO', 233),
#  ('VBD VB', 233),
#  ('NNS -RRB-', 232),
#  ('IN VB', 229),
#  ('VBG CD', 228),
#  ('CC UH', 226),
#  ('-RRB- ,', 220),
#  ('WP MD', 217),
#  ('SYM NN', 217),
#  ('DT VB', 214),
#  ('RB PRP$', 211),
#  ('`` VB', 208),
#  ('VBN NNP', 207),
#  ('RP NN', 206),
#  ('VBN PRP$', 206),
#  ('NN JJR', 206),
#  ('POS JJ', 204),
#  ('NNPS .', 203),
#  ('VBP JJR', 203),
#  ('NNS NNS', 203),
#  ('RBR .', 202),
#  ('UH UH', 202),
#  ('FW NNP', 195),
#  ('-RRB- VBZ', 195),
#  ('VBZ JJR', 194),
#  ('NNP VBP', 194),
#  ('EX MD', 193),
#  ('POS NNS', 193),
#  ('PRP WP', 192),
#  ('WDT NNS', 188),
#  ('HYPH CD', 188),
#  ('DT DT', 187),
#  ('VBN CD', 186),
#  ("'' RB", 186),
#  ('WRB RB', 181),
#  ('CD SYM', 181),
#  ('VBZ VB', 180),
#  ('RB RP', 177),
#  ("'' DT", 177),
#  ('`` NN', 176),
#  ('NNP CD', 176),
#  ('NNS POS', 175),
#  (': PRP', 174),
#  ('NN RBR', 172),
#  ('-RRB- IN', 170),
#  ('. VBN', 168),
#  ('VBG NNP', 166),
#  ('PRP PRP', 166),
#  ('PRP WRB', 166),
#  ('NNS RP', 165),
#  ('`` DT', 164),
#  ('IN HYPH', 164),
#  ('VB RBR', 164),
#  ('PRP CD', 164),
#  ('RBR ,', 163),
#  ('RBR RB', 163),
#  ('FW VBP', 163),
#  ('PRP$ JJS', 162),
#  (', FW', 162),
#  ('NNS :', 162),
#  ('. ``', 161),
#  ('VB VBZ', 161),
#  ('RB EX', 159),
#  ('CD RB', 158),
#  ('WRB NNP', 156),
#  ('. TO', 154),
#  ('JJ VBZ', 153),
#  ('. .', 150),
#  ("'' IN", 149),
#  ('NNPS ,', 147),
#  ('VBD WRB', 147),
#  ('WRB MD', 146),
#  ('CD DT', 145),
#  ('RB UH', 145),
#  ('-RRB- NNS', 145),
#  ('JJ VBG', 140),
#  ('-LRB- NNP', 140),
#  ('VB PDT', 139),
#  ('NNPS IN', 137),
#  ("'' UH", 137),
#  ('DT RBR', 136),
#  ('VBD JJR', 136),
#  ('WRB TO', 132),
#  ('CC PDT', 132),
#  ('VBP VBZ', 131),
#  ('CC JJR', 131),
#  (', PDT', 131),
#  ('VBP EX', 130),
#  ('MD .', 130),
#  ('WRB VBD', 130),
#  ('FW RB', 130),
#  ('MD ,', 129),
#  ('NNP VB', 127),
#  ("'' ``", 125),
#  ('JJR ,', 121),
#  ('DT WP', 119),
#  ('DT NNPS', 119),
#  ('`` NNP', 118),
#  ('DT RP', 117),
#  (': DT', 117),
#  ('VBZ RBR', 115),
#  ('WP ,', 115),
#  ('VBZ CC', 111),
#  ('VBP RBR', 111),
#  ('JJ WRB', 111),
#  ('HYPH VBG', 111),
#  ('VBD RBR', 110),
#  ('JJ NNPS', 109),
#  ('RP NNS', 109),
#  ('JJS JJ', 108),
#  ('-LRB- CD', 108),
#  ('IN NNPS', 107),
#  ('`` WRB', 107),
#  ('CD VBZ', 104),
#  ('CC WDT', 104),
#  ('VBN JJR', 104),
#  ('-RRB- VBP', 104),
#  ('NNS SYM', 104),
#  ('IN VBZ', 103),
#  ('JJS .', 103),
#  ('WDT JJ', 103),
#  (', JJR', 103),
#  (', ,', 102),
#  ('WRB IN', 101),
#  ('VBD VBD', 101),
#  ('WDT NNP', 100),
#  ('RB HYPH', 100),
#  ('VBP PDT', 99),
#  ('PDT PRP$', 99),
#  ('UH NNP', 99),
#  ('VBD WP', 99),
#  ('RP TO', 99),
#  ('NN FW', 99),
#  ('NNPS VBP', 98),
#  ('RP JJ', 97),
#  ('WRB VBN', 97),
#  ('NNP HYPH', 96),
#  ('CC RBR', 95),
#  ('JJR CC', 95),
#  ('DT WDT', 94),
#  ('VBG JJR', 94),
#  ('WRB PRP$', 93),
#  ('NNP TO', 93),
#  ('-RRB- CC', 93),
#  ('WP RB', 92),
#  ('VBG WP', 92),
#  ('WRB .', 92),
#  ('. WDT', 92),
#  ('VBG WRB', 92),
#  ('NNS RBR', 92),
#  ('`` JJ', 92),
#  ('VBZ EX', 91),
#  ('NNP DT', 90),
#  ('UH NN', 90),
#  ('IN VBD', 90),
#  ('NNS HYPH', 89),
#  ('RP VBG', 88),
#  ('UH PRP', 88),
#  ('FW VBN', 88),
#  ('PRP RBR', 87),
#  ('WDT ,', 86),
#  ('PRP$ CD', 85),
#  ("NN ''", 85),
#  ('VB WDT', 84),
#  ('NNPS NN', 82),
#  ('. JJS', 81),
#  ('NNP VBG', 81),
#  ('JJ VBD', 80),
#  ('MD DT', 79),
#  ("'' NN", 79),
#  ('EX DT', 78),
#  ('IN $', 77),
#  ('CD VBD', 77),
#  ('JJS ,', 77),
#  ('VBN VBZ', 76),
#  ('. ,', 76),
#  ('WDT IN', 75),
#  ('TO ,', 74),
#  ('VBD PDT', 74),
#  ('RB WDT', 73),
#  ('. PDT', 73),
#  ('JJ JJR', 72),
#  ('VBG VBZ', 72),
#  ('JJS CD', 71),
#  ('RBS RB', 71),
#  ('RBR VBN', 70),
#  ('WRB ,', 70),
#  ('VBN RBR', 69),
#  ('VBD EX', 69),
#  ('NNP PRP', 68),
#  ('VBG VBG', 68),
#  ('DT TO', 68),
#  ('CD VBN', 67),
#  ('`` RB', 66),
#  ('PRP PRP$', 66),
#  ('RB :', 66),
#  ('IN :', 66),
#  ('WRB VBG', 66),
#  (': CC', 65),
#  ('PRP$ VBN', 64),
#  ('WP NNP', 64),
#  ('`` WP', 64),
#  (', RBR', 63),
#  ('JJ VBP', 63),
#  ('PRP JJR', 63),
#  (': IN', 63),
#  ('NNS JJR', 62),
#  ('NN PRP$', 61),
#  ('HYPH NNS', 61),
#  ('UH RB', 60),
#  ('VBN WRB', 59),
#  ('VBZ PDT', 59),
#  ('VBZ VBZ', 58),
#  ('CD WDT', 58),
#  ('JJR TO', 58),
#  ('RP CD', 58),
#  ('. JJR', 58),
#  ('WRB EX', 57),
#  ('UH VBP', 57),
#  ('`` IN', 56),
#  ('NNP WDT', 56),
#  ('JJR JJ', 56),
#  ('NNS CD', 55),
#  ('RBR VB', 55),
#  ('WP IN', 55),
#  ('WP PRP$', 55),
#  ('NNP SYM', 55),
#  ('IN RBR', 55),
#  (', JJS', 55),
#  ('-LRB- JJ', 55),
#  ('NNPS CC', 54),
#  ('RP NNP', 53),
#  ('JJ -LRB-', 53),
#  (': NN', 52),
#  ('JJ MD', 52),
#  ('IN TO', 52),
#  ('PRP PDT', 52),
#  ('JJ WP', 52),
#  ('MD TO', 52),
#  ('JJ JJS', 51),
#  ('PRP NNP', 49),
#  ('IN ``', 49),
#  ('CC CC', 49),
#  ('WP TO', 49),
#  ('HYPH CC', 49),
#  (': RB', 48),
#  ('CD NNPS', 48),
#  ('NNPS VBD', 47),
#  ('HYPH NNP', 47),
#  ('RB PDT', 47),
#  ('RBS VBN', 47),
#  (': JJ', 47),
#  ('NNP WRB', 46),
#  ("'' NNP", 46),
#  ('CD NNP', 46),
#  ('DT ``', 46),
#  (": ''", 46),
#  (': UH', 45),
#  ('`` NNS', 45),
#  ('JJS PRP', 45),
#  ('JJ WDT', 44),
#  ('RBR CC', 44),
#  ('RP WRB', 44),
#  ('VBG PDT', 44),
#  ('PRP$ ,', 44),
#  ('NNPS MD', 44),
#  ('NNP WP', 43),
#  ('VBN WP', 43),
#  ('NN EX', 42),
#  ("'' VB", 42),
#  ('FW .', 42),
#  ('NNS NNP', 42),
#  ('FW NN', 42),
#  ('PRP$ RB', 41),
#  ('`` CD', 41),
#  ('MD CC', 40),
#  ('VBD $', 40),
#  ('CD VBP', 40),
#  ('TO .', 39),
#  ('UH DT', 39),
#  ('UH IN', 39),
#  ("'' WRB", 39),
#  ('DT :', 38),
#  ('FW ,', 38),
#  ('CC JJS', 37),
#  ('VBP MD', 37),
#  ('VBZ WDT', 37),
#  ('WDT PRP$', 37),
#  ('`` VBP', 37),
#  ('RP WP', 36),
#  ('DT $', 36),
#  ('RBR DT', 35),
#  ('CD PRP', 35),
#  ('JJ RP', 35),
#  ('CD RP', 35),
#  ('CD TO', 35),
#  ('JJS VBZ', 35),
#  ('-RRB- VBD', 35),
#  ('POS JJS', 34),
#  ('JJS DT', 34),
#  ('VBP VBP', 34),
#  ('CD MD', 34),
#  ('IN RP', 34),
#  ("'' JJ", 34),
#  ('LS -RRB-', 34),
#  ('VBP WDT', 33),
#  ('VB EX', 33),
#  ('IN VBP', 33),
#  (': VB', 33),
#  ('VBN PDT', 33),
#  ('. LS', 33),
#  ('LS .', 33),
#  ('JJS CC', 32),
#  (': NNS', 32),
#  ('MD IN', 32),
#  ('CD VBG', 32),
#  ('VBD VBZ', 31),
#  ('VBP :', 31),
#  ('JJ :', 31),
#  ('VB :', 31),
#  ('VBZ UH', 31),
#  ('HYPH VB', 31),
#  ('NNS FW', 31),
#  ('-RRB- WDT', 31),
#  ('WRB CD', 30),
#  ('IN MD', 30),
#  ("NNS ''", 30),
#  ('. RBR', 30),
#  ('-RRB- MD', 30),
#  (', .', 29),
#  ('CD RBR', 29),
#  ('PRP WDT', 29),
#  ('NN UH', 29),
#  ("'' VBP", 29),
#  ('JJ ``', 29),
#  ('NNP VBN', 28),
#  ('VBG VB', 28),
#  ('IN UH', 28),
#  ('WP NN', 28),
#  ('JJR HYPH', 28),
#  ('-RRB- :', 28),
#  ('JJS RB', 27),
#  ('`` EX', 27),
#  ('VBN VBP', 27),
#  ('NN PDT', 27),
#  ('VBP JJS', 27),
#  ('RB JJS', 27),
#  ("JJ ''", 27),
#  ('VBG RBR', 27),
#  ("'' NNS", 27),
#  ('FW CC', 27),
#  ('JJ -RRB-', 27),
#  ('NNP -LRB-', 27),
#  ('NNPS RB', 26),
#  ('DT HYPH', 26),
#  ('VBN VB', 26),
#  ('POS VBN', 26),
#  ('JJS TO', 26),
#  ('JJ RBR', 26),
#  ('JJR RB', 26),
#  ('EX PRP', 26),
#  ('RP RP', 26),
#  ('VB UH', 26),
#  ('`` MD', 25),
#  ("'' VBD", 25),
#  ('POS VBG', 25),
#  ('VBP VBD', 25),
#  ('VBN WDT', 25),
#  ('CC NNPS', 25),
#  ('CC RBS', 25),
#  (', $', 25),
#  ('SYM NNS', 25),
#  ('SYM LS', 25),
#  ('JJR DT', 24),
#  ('MD NN', 24),
#  ("'' WP", 24),
#  ('VB VBP', 24),
#  ('POS RB', 24),
#  ('ADD ,', 24),
#  ('WDT .', 24),
#  ('-LRB- DT', 24),
#  ('RP VBZ', 23),
#  ('JJ EX', 23),
#  ('VBN HYPH', 23),
#  ('DT PDT', 23),
#  (': VBG', 23),
#  ('IN ADD', 23),
#  (', NNPS', 22),
#  ('WP$ NN', 22),
#  ('VBG NNPS', 22),
#  ('VBP UH', 22),
#  ('NNPS WP', 21),
#  ('PRP$ JJR', 21),
#  (', RBS', 21),
#  ('UH NNS', 21),
#  ('JJ PRP$', 21),
#  ('UH CC', 21),
#  ('PRP$ RBS', 21),
#  ('TO RBR', 21),
#  ('POS CD', 21),
#  ('NNPS VBZ', 21),
#  ('RP PRP', 21),
#  ('RB $', 21),
#  ('PRP UH', 21),
#  ('-RRB- TO', 21),
#  ('PRP :', 20),
#  ("'' .", 20),
#  ('POS IN', 20),
#  (': VBP', 20),
#  ('. RBS', 20),
#  ('WDT TO', 19),
#  ("'' CD", 19),
#  ('HYPH FW', 19),
#  ('RB -LRB-', 19),
#  ('-RRB- -LRB-', 19),
#  (': VBN', 19),
#  ('IN FW', 19),
#  ('TO NN', 18),
#  ('VBG VBD', 18),
#  ('WDT CD', 18),
#  ('CC RP', 18),
#  ('JJ VB', 18),
#  ('`` PRP$', 18),
#  ('VBN MD', 18),
#  ('RBR NN', 18),
#  (': CD', 18),
#  ('UH PRP$', 18),
#  ('PRP$ VBG', 18),
#  ('VBD :', 18),
#  ('CC HYPH', 18),
#  ('VBZ JJS', 18),
#  ('FW -RRB-', 18),
#  ('VBZ :', 17),
#  ('VBG VBP', 17),
#  ('VBD JJS', 17),
#  ('VBD UH', 17),
#  ('EX NN', 17),
#  ('VBD WDT', 17),
#  ('VB MD', 17),
#  ('VBP RBS', 17),
#  ('`` VBZ', 17),
#  ('HYPH RP', 17),
#  ("'' VBZ", 17),
#  ('NNPS JJ', 17),
#  ('NNS PRP$', 17),
#  ('-RRB- JJ', 17),
#  ('JJ FW', 17),
#  ('MD VBP', 16),
#  ('MD NNP', 16),
#  ('VBN :', 16),
#  ('RBR VBP', 16),
#  ('HYPH ,', 16),
#  ('CC .', 16),
#  ('VB $', 16),
#  ('RP RBR', 16),
#  ('DT WRB', 16),
#  ('VBD MD', 16),
#  ("'' ,", 16),
#  ('CD :', 16),
#  ('WRB CC', 16),
#  ('JJR RP', 16),
#  ('JJ POS', 16),
#  ('VBN -LRB-', 16),
#  ('DT -LRB-', 16),
#  ('IN RBS', 15),
#  ('TO IN', 15),
#  ('VB VBD', 15),
#  ('VBN VBD', 15),
#  (': VBZ', 15),
#  ('UH JJ', 15),
#  ('VBG WDT', 15),
#  ('`` CC', 15),
#  ("'' WDT", 15),
#  ('-RRB- CD', 15),
#  ('-RRB- VBN', 15),
#  ('WP JJ', 14),
#  ('WDT EX', 14),
#  ("'' PRP$", 14),
#  ('VBD VBP', 14),
#  ('VBD ``', 14),
#  ('RBR PRP', 14),
#  ('EX RB', 14),
#  ('UH CD', 14),
#  ('NN NNPS', 14),
#  ('RBR VBG', 14),
#  ('`` VBG', 14),
#  ("'' MD", 14),
#  ('. $', 14),
#  ('-RRB- RB', 14),
#  ('-LRB- RB', 14),
#  ('SYM CC', 14),
#  (': NNP', 13),
#  ('WRB VB', 13),
#  ('CD WRB', 13),
#  ('VBN NNPS', 13),
#  ('RP JJR', 13),
#  ('WRB PDT', 13),
#  ("'' ''", 13),
#  ('POS NNP', 13),
#  ('WDT VB', 13),
#  ('POS ,', 13),
#  ('NNS PDT', 13),
#  ('VBP ``', 13),
#  ('ADD .', 13),
#  ('NNS $', 13),
#  ('CC ``', 13),
#  ('-LRB- VBN', 13),
#  ('-RRB- VBG', 13),
#  ('RBS VB', 12),
#  ('PRP JJS', 12),
#  ('VBZ RBS', 12),
#  ('VBN ``', 12),
#  (', RP', 12),
#  ('JJR PRP', 12),
#  ('VB JJS', 12),
#  ('NN WP$', 12),
#  ('NNPS TO', 12),
#  ('PRP$ NNP', 12),
#  ('NN ``', 12),
#  ('`` VBD', 12),
#  ('MD JJ', 12),
#  ('CC FW', 12),
#  ("'' VBG", 11),
#  ("NNP ''", 11),
#  ('PRP EX', 11),
#  ('DT PRP$', 11),
#  ('NNS WP$', 11),
#  ('UH WRB', 11),
#  ('`` VBN', 11),
#  ('RB -RRB-', 11),
#  ("VB ''", 11),
#  ('POS CC', 10),
#  ('UH WP', 10),
#  ('JJS VB', 10),
#  ('CD POS', 10),
#  ('RBR VBZ', 10),
#  ('WP$ NNS', 10),
#  ('POS .', 10),
#  ('WRB JJS', 10),
#  ('FW JJ', 10),
#  ('VBG :', 10),
#  ('VBG MD', 10),
#  ('TO DT', 10),
#  ('JJS VBG', 10),
#  ('NNS EX', 10),
#  ('PRP$ IN', 10),
#  ('PRP$ DT', 10),
#  (', WP$', 10),
#  ('SYM -RRB-', 10),
#  ('-LRB- IN', 10),
#  ('MD PRP$', 9),
#  ('CD WP', 9),
#  ('NNPS VBG', 9),
#  ('RP PDT', 9),
#  ('MD VBN', 9),
#  ('VBG EX', 9),
#  ("'' TO", 9),
#  ('VB HYPH', 9),
#  ('VBZ MD', 9),
#  ('RB ``', 9),
#  ('VBD RBS', 9),
#  ('VBP NNPS', 9),
#  ('NNP :', 9),
#  ('NNP UH', 9),
#  ('VBG $', 9),
#  ('PRP $', 9),
#  ('`` WDT', 9),
#  ('VBD FW', 9),
#  (': WDT', 9),
#  ('-LRB- LS', 9),
#  ('MD NNS', 8),
#  ('RP HYPH', 8),
#  ('. NNPS', 8),
#  ('RP VBD', 8),
#  ('POS VBD', 8),
#  ('WDT VBG', 8),
#  ...]

# %%
trigram_freq = {}

for docs in dataset_pos.items():
  for el in docs[1]:
    for trigram in el[2]: 
      if trigram not in trigram_freq:
        trigram_freq[trigram] = 1
      else:
        trigram_freq[trigram] += 1

trigram_freq = sorted(trigram_freq.items(), key = lambda x:x[1], reverse=True)
trigram_freq
# Out:
# [('IN DT NN', 21678),
#  ('DT NN IN', 15278),
#  ('DT JJ NN', 15257),
#  ('NN IN DT', 11439),
#  ('. PRP VBP', 10596),
#  ('IN DT JJ', 8026),
#  ('DT NN .', 7349),
#  ('NN . PRP', 7336),
#  ('NN IN NN', 7283),
#  ('JJ NN IN', 6935),
#  ('PRP VBP RB', 6101),
#  ('VB DT NN', 6101),
#  ('PRP MD VB', 6037),
#  ('JJ NN .', 5984),
#  ('DT NN ,', 5942),
#  (', PRP VBP', 5919),
#  ('DT NN NN', 5758),
#  ('TO VB DT', 5038),
#  ('. PRP VBD', 4930),
#  ('PRP VBP VBG', 4596),
#  ('CC PRP VBP', 4550),
#  ('VBG TO VB', 4531),
#  ('NNS IN DT', 4392),
#  ('NN , CC', 4068),
#  ('JJ NN ,', 4058),
#  ('NN NN .', 4010),
#  ('IN DT NNS', 3982),
#  ('IN PRP VBP', 3953),
#  ('JJ NN NN', 3937),
#  (', CC PRP', 3793),
#  ('IN JJ NN', 3707),
#  ('NN IN JJ', 3640),
#  ('IN JJ NNS', 3629),
#  ('PRP VBP DT', 3548),
#  ('NN , PRP', 3515),
#  ('JJ NNS IN', 3482),
#  ('PRP VBP VBN', 3477),
#  ('TO VB IN', 3359),
#  ('NN TO VB', 3356),
#  ('VBD DT NN', 3344),
#  ('NN NN IN', 3329),
#  ('IN PRP$ NN', 3307),
#  ('NN . DT', 3220),
#  ('VBZ DT NN', 3185),
#  ('NN NN ,', 3152),
#  ('. PRP VBZ', 3084),
#  ('NN IN NNS', 3083),
#  ('. CC PRP', 3050),
#  ('IN NN NN', 3008),
#  ('PRP VBP PRP', 2922),
#  ('MD RB VB', 2898),
#  ('PRP VBD DT', 2893),
#  (', PRP VBD', 2882),
#  ('VBP TO VB', 2879),
#  ('VBN IN DT', 2856),
#  ('NN NN NN', 2838),
#  ('JJ NNS .', 2763),
#  ('NN . CC', 2760),
#  ('VB IN DT', 2752),
#  ('. DT NN', 2751),
#  ('RB IN DT', 2734),
#  ('IN NN .', 2713),
#  ('PRP VBP IN', 2701),
#  ('IN NN IN', 2672),
#  ('NNS IN NN', 2646),
#  ('NN CC NN', 2610),
#  ('DT NN VBZ', 2554),
#  ('IN NN ,', 2550),
#  ('PRP VBD RB', 2472),
#  (', DT NN', 2396),
#  ('VBP DT NN', 2393),
#  ('DT NN CC', 2390),
#  ('IN PRP VBD', 2390),
#  ('VBP RB VB', 2390),
#  ('NNS . PRP', 2342),
#  ('CC PRP VBD', 2337),
#  ('JJ JJ NN', 2336),
#  ('DT JJ NNS', 2326),
#  ('NN . RB', 2298),
#  ('PRP VBP TO', 2290),
#  ('JJ NN NNS', 2280),
#  ('NN , DT', 2246),
#  ('VBP VBG TO', 2244),
#  ('PRP VBD IN', 2223),
#  ('. PRP MD', 2216),
#  ('RB . PRP', 2212),
#  ('VB DT JJ', 2180),
#  ('NN IN PRP', 2180),
#  ('JJ NNS ,', 2164),
#  ('PRP VBZ RB', 2153),
#  ('PRP MD RB', 2145),
#  ('VBZ DT JJ', 2144),
#  ('IN PRP .', 2107),
#  ('TO VB PRP', 2095),
#  ('NN IN NNP', 2068),
#  ('JJ TO VB', 2060),
#  ('MD VB DT', 2055),
#  ('DT NNS IN', 1965),
#  ('IN NNS IN', 1964),
#  ('NN NNS IN', 1951),
#  ('NN NNS .', 1943),
#  ('CC DT NN', 1919),
#  ('. UH ,', 1902),
#  ('. DT VBZ', 1879),
#  ('NNS IN JJ', 1859),
#  ('PRP VBP ,', 1834),
#  ('PRP$ NN .', 1831),
#  ('JJ . PRP', 1795),
#  ('VB TO VB', 1794),
#  ('VBG DT NN', 1781),
#  ('NN , IN', 1766),
#  ('. RB ,', 1758),
#  ('TO VB JJ', 1751),
#  ('NNS , CC', 1750),
#  ('JJ IN DT', 1718),
#  ('PRP . PRP', 1717),
#  ('VBD DT JJ', 1709),
#  (', PRP MD', 1697),
#  (', PRP VBZ', 1680),
#  ('RB , PRP', 1677),
#  ('VBD TO VB', 1676),
#  ('NN . IN', 1648),
#  ('NN , NN', 1642),
#  ('IN NN NNS', 1638),
#  ('RB VB DT', 1627),
#  ('RB PRP VBP', 1623),
#  ('JJ NN CC', 1610),
#  (', IN PRP', 1590),
#  ('. VBP PRP', 1587),
#  ('PRP$ NN ,', 1581),
#  ('PRP VBZ DT', 1568),
#  ('NN MD VB', 1556),
#  ('NN , RB', 1546),
#  ('NNS . DT', 1545),
#  ('NNS IN NNS', 1543),
#  ('PRP VBD PRP', 1541),
#  ('NN IN PRP$', 1532),
#  ('NN NNS ,', 1528),
#  ('NN NN CC', 1521),
#  ('IN NN CC', 1516),
#  ('WRB PRP VBP', 1510),
#  ('DT NN WDT', 1507),
#  ('DT JJ JJ', 1505),
#  ('VBD IN DT', 1498),
#  ('JJ JJ NNS', 1498),
#  ('VBP IN DT', 1496),
#  ('MD VB VBN', 1496),
#  ('RB RB .', 1478),
#  ('. RB PRP', 1471),
#  ('PRP VBD ,', 1446),
#  ('VBG IN DT', 1444),
#  ('PRP VBP JJ', 1441),
#  (', CC DT', 1441),
#  ('FW FW VBD', 1440),
#  ('NNP FW FW', 1436),
#  ('. CC RB', 1434),
#  ('TO VB NN', 1425),
#  ('TO VB .', 1404),
#  ('VB IN PRP', 1401),
#  ('VBN TO VB', 1399),
#  ('UH , PRP', 1393),
#  ('IN NNP .', 1392),
#  ('NNS TO VB', 1382),
#  ('DT NN RB', 1367),
#  ('IN NNP ,', 1360),
#  ('MD VB IN', 1355),
#  ('PRP$ JJ NN', 1355),
#  ('RB RB IN', 1354),
#  ('TO VB RB', 1351),
#  ('DT NN TO', 1349),
#  ('DT NNS VBP', 1333),
#  ('RB JJ IN', 1332),
#  (', IN DT', 1330),
#  ('RB DT NN', 1310),
#  ('NNS WDT VBP', 1304),
#  ('NN . NNP', 1304),
#  ('NN NN NNS', 1296),
#  ('. NNP FW', 1295),
#  ('VBP RB VBN', 1290),
#  ('DT NNS .', 1261),
#  ('NN IN VBG', 1257),
#  ('WP PRP VBP', 1252),
#  ('DT VBZ DT', 1252),
#  ('PRP RB VBD', 1250),
#  ('VBP VBN IN', 1249),
#  ('. IN DT', 1248),
#  ('RB VB PRP', 1240),
#  ('. DT JJ', 1237),
#  ('CC PRP VBZ', 1236),
#  ('RB VB IN', 1235),
#  ('RB JJ .', 1232),
#  ('IN PRP ,', 1228),
#  ('VBN IN NN', 1226),
#  ('NN VBZ RB', 1212),
#  ('CC PRP MD', 1210),
#  ('NN WDT VBZ', 1204),
#  ('DT IN DT', 1200),
#  ('IN DT .', 1196),
#  ('RB IN PRP', 1195),
#  ('PRP RB VBP', 1192),
#  ('DT NNS ,', 1183),
#  ('PRP IN DT', 1178),
#  (', CC RB', 1170),
#  ('IN NNS .', 1169),
#  ('NN VBZ VBN', 1161),
#  ('NNP . PRP', 1145),
#  ('NNS , PRP', 1143),
#  ('VBZ RB JJ', 1141),
#  ('VB PRP$ NN', 1138),
#  ('JJ NN VBZ', 1137),
#  ('NN CC DT', 1136),
#  ('VB PRP .', 1135),
#  ('DT NN VBD', 1134),
#  ('PRP$ NN IN', 1133),
#  ('PRP VBD TO', 1125),
#  ('VBP DT JJ', 1121),
#  ('DT NN NNS', 1120),
#  ('NNS MD VB', 1118),
#  ('NN . NN', 1106),
#  ('. DT NNS', 1103),
#  ('RB JJ NN', 1097),
#  ('. CC DT', 1094),
#  ('RB VBN IN', 1094),
#  ('VBN DT NN', 1083),
#  ('. PRP RB', 1078),
#  ('NN VBZ DT', 1078),
#  ('NN NN VBZ', 1067),
#  ('VBP PRP .', 1066),
#  ('NNS CC NNS', 1065),
#  ('IN PRP$ NNS', 1060),
#  ('VB . PRP', 1059),
#  ('PRP VBZ JJ', 1056),
#  ('. IN PRP', 1041),
#  ('NN CC PRP', 1035),
#  ('NN WDT PRP', 1024),
#  ('IN NNS ,', 1017),
#  ('NN PRP VBP', 1010),
#  (', DT JJ', 1007),
#  ('MD VB PRP', 1005),
#  ('VBN IN JJ', 1001),
#  ('VB DT NNS', 997),
#  ('PRP VBD VBG', 992),
#  ('JJ IN PRP', 989),
#  ('DT NN PRP', 988),
#  ('WRB PRP VBD', 982),
#  ('CC JJ NN', 977),
#  ('WDT PRP VBP', 970),
#  ('IN PRP MD', 969),
#  ('NN . UH', 969),
#  ('IN JJ JJ', 969),
#  ('VB PRP IN', 968),
#  ('NNS . CC', 961),
#  ('VBZ JJ .', 958),
#  ('IN CD NNS', 955),
#  ('VBP RB JJ', 942),
#  ('VBD , ``', 941),
#  ('JJ NNS CC', 939),
#  ('VB VBN IN', 936),
#  ('PRP VBZ VBN', 935),
#  ('IN VBG DT', 933),
#  ('IN PRP VBZ', 933),
#  ('CC RB PRP', 929),
#  ('JJ NNS VBP', 929),
#  ('NNS VBP VBN', 921),
#  ('IN PRP$ JJ', 921),
#  ('VBZ VBG TO', 919),
#  ('NNS , DT', 906),
#  ('IN IN DT', 904),
#  ('VB PRP VB', 904),
#  ('CC IN DT', 903),
#  ('TO VB PRP$', 902),
#  ('CC DT VBZ', 901),
#  ('VBP RB VBG', 900),
#  ('. CC IN', 898),
#  ('VBZ VBN IN', 894),
#  ('NN . JJ', 892),
#  ('CC JJ NNS', 887),
#  ('VBZ RB VBN', 886),
#  ('VBD RB VB', 884),
#  ('CC NN IN', 881),
#  ('CD NNS IN', 879),
#  ('NNS . RB', 876),
#  ('RB . CC', 875),
#  ('RB , CC', 871),
#  ('VBZ IN DT', 867),
#  ('TO VB RP', 864),
#  ('VB IN NN', 854),
#  ('MD VB JJ', 851),
#  ('JJ CC JJ', 851),
#  ('PRP VBZ IN', 851),
#  ('VBD VBN IN', 850),
#  ('RB RB ,', 850),
#  ('. JJ NN', 849),
#  ('CD IN DT', 844),
#  (', DT VBZ', 844),
#  ('TO VB ,', 844),
#  ('NN VBZ IN', 842),
#  ('NN , NNP', 840),
#  ('VBZ TO VB', 839),
#  (', JJ NN', 839),
#  ('PRP VBD JJ', 836),
#  ('NNP NNP ,', 831),
#  ('DT VBZ RB', 830),
#  ('NNP , PRP', 827),
#  ('IN DT IN', 826),
#  ('HYPH NN NN', 826),
#  ('CC DT JJ', 825),
#  ('RB , RB', 822),
#  ('PRP VBP .', 802),
#  ('VBG DT JJ', 801),
#  ('VB NN IN', 799),
#  (', NN ,', 799),
#  ('PRP TO VB', 792),
#  ('NNS VBN IN', 791),
#  ('VBP VBG IN', 787),
#  ('NN IN CD', 785),
#  ('IN DT NNP', 784),
#  ('NN NNS CC', 781),
#  ('CD NNS .', 773),
#  ('NNS VBP RB', 771),
#  ('PRP VBZ VBG', 768),
#  ('RB DT JJ', 766),
#  ('RB , DT', 764),
#  ('DT RB JJ', 763),
#  ('NN VBN IN', 762),
#  ('NN NNS VBP', 762),
#  ('DT NNS WDT', 758),
#  ('DT . PRP', 755),
#  ('RB IN NN', 753),
#  ('PRP VBP NN', 753),
#  ('-LRB- NN -RRB-', 749),
#  ('IN DT ,', 741),
#  ('NN , VBG', 739),
#  ('RB TO VB', 735),
#  ('JJ IN NN', 734),
#  (', DT NNS', 730),
#  ('VBP VBN DT', 728),
#  ('IN NNP NNP', 727),
#  ('NNS . IN', 726),
#  ('NNS IN NNP', 723),
#  ('VBP RB RB', 719),
#  ('EX VBZ DT', 718),
#  ('VB JJ NN', 712),
#  ('RB PRP VBD', 712),
#  (', RB IN', 711),
#  ('RP IN DT', 710),
#  ('TO VB VBN', 708),
#  ('DT JJS NN', 707),
#  ('CD NNS ,', 702),
#  ('PRP VBD VBN', 696),
#  (', CC NN', 695),
#  ('TO VB NNS', 691),
#  ('NN VBZ JJ', 691),
#  ('IN NNP CC', 686),
#  ('NN , WDT', 685),
#  ('PRP RB RB', 682),
#  ('IN NNS CC', 679),
#  ('VB JJ IN', 676),
#  (', RB .', 675),
#  ('IN NNP NN', 673),
#  ('DT NNS VBD', 672),
#  (', CC IN', 671),
#  ('NNP NNP .', 671),
#  ('JJ NN WDT', 670),
#  ('NNS , IN', 670),
#  ('NNP , NNP', 670),
#  ('NN -LRB- NN', 667),
#  ('JJ , CC', 665),
#  (', NNP .', 664),
#  ('JJ HYPH NN', 663),
#  ('JJ NNS WDT', 662),
#  ('CC NN NN', 661),
#  ('NN POS NN', 660),
#  ('NNS VBP IN', 660),
#  ('FW FW FW', 659),
#  ('MD VB RB', 658),
#  ('NN CC JJ', 656),
#  ('-LRB- VB DT', 653),
#  ('NN RB IN', 650),
#  ('VBP , PRP', 650),
#  ('NN RB .', 649),
#  ('PRP . CC', 649),
#  ('PRP , PRP', 647),
#  (', NNP ,', 647),
#  ('VBP IN PRP', 647),
#  ('NNS . NNP', 645),
#  ('VB PRP RB', 643),
#  ('NN , JJ', 642),
#  (". '' PRP", 640),
#  ('JJ NN TO', 637),
#  ("NN . ''", 634),
#  ('RB VBG TO', 633),
#  ('VBZ RB DT', 632),
#  ('RB VB TO', 631),
#  ('VBD RB JJ', 628),
#  ('RB , IN', 626),
#  ('VBP PRP VB', 626),
#  ('NNP CC NNP', 625),
#  ('VB RB IN', 623),
#  ('RB IN NNP', 622),
#  ('NNS , RB', 622),
#  ('RB JJ NNS', 621),
#  ('. IN NN', 620),
#  (', NNP NNP', 620),
#  ('RB . RB', 620),
#  (', RB PRP', 620),
#  ('PRP$ NNS ,', 619),
#  ('PRP$ NN CC', 618),
#  ('VBN NN IN', 618),
#  ('NN , VB', 617),
#  ('NN CC VB', 616),
#  ('FW VBD DT', 615),
#  ('PRP$ NN VBZ', 614),
#  ('JJ . CC', 614),
#  ('CC IN PRP', 613),
#  ('RB VB .', 611),
#  ('NNP NN ,', 609),
#  ('DT NNS CC', 609),
#  ('NN PRP VBD', 609),
#  (', WDT VBZ', 608),
#  ('VBP PRP ,', 602),
#  ('JJ , JJ', 601),
#  ('. NNP NNP', 600),
#  ('VBP PRP RB', 598),
#  ('VBZ RB RB', 597),
#  ('VBP PRP VBP', 597),
#  ('VBD IN PRP', 595),
#  ('NN CC RB', 595),
#  ('VBN . PRP', 593),
#  ('NN JJ NN', 591),
#  ('NN HYPH NN', 590),
#  ('IN CD NN', 590),
#  ('RB . DT', 590),
#  ('NNS VBP JJ', 588),
#  ('VBZ JJ IN', 586),
#  ('NNS WDT PRP', 585),
#  ('CC NN .', 584),
#  ('IN PRP IN', 584),
#  ('WDT MD VB', 584),
#  ('DT NN MD', 583),
#  ('VBN DT JJ', 583),
#  ('. UH .', 583),
#  ('NN . VB', 582),
#  ('VB PRP ,', 581),
#  (', NN .', 578),
#  ('CD NN IN', 573),
#  ('JJ NN RB', 573),
#  ('VB RB .', 572),
#  ('MD PRP VB', 571),
#  ('. RB IN', 569),
#  ('PRP DT NN', 569),
#  ('PRP$ NN NN', 568),
#  ('PRP$ NNS .', 568),
#  ('VBD IN NN', 568),
#  ('NN RB RB', 568),
#  (', PRP RB', 565),
#  ('NN NN -LRB-', 565),
#  ('VBP JJ NNS', 556),
#  ('`` UH ,', 553),
#  ('IN PRP RB', 552),
#  (', PRP$ NN', 550),
#  ('RB PRP MD', 550),
#  ('. PRP$ NN', 549),
#  ('VB , PRP', 549),
#  (', RB RB', 547),
#  ('WP PRP VBD', 546),
#  ('IN DT CD', 544),
#  ('DT JJ CD', 543),
#  ('IN VBG NN', 542),
#  ('VBP JJ IN', 540),
#  ('VBZ VBN DT', 539),
#  (', `` UH', 538),
#  ('NNS , NN', 537),
#  ('CC PRP RB', 537),
#  ('MD VB NN', 537),
#  ('RB JJ ,', 537),
#  ('CC PRP$ NN', 536),
#  ('VB DT .', 536),
#  ('NNS VBP DT', 535),
#  ('NNS IN PRP$', 534),
#  (', NN NN', 534),
#  ('DT VBN NN', 534),
#  ('. JJ NNS', 530),
#  ('NN NN VBD', 530),
#  ('NN IN RB', 529),
#  ('VB JJ NNS', 524),
#  ('PRP , CC', 524),
#  ('CD NNS RB', 523),
#  ('PRP VBP WP', 523),
#  ('NNS IN PRP', 520),
#  ('WDT PRP VBD', 520),
#  ('NNS . NN', 520),
#  ('VB PRP$ NNS', 519),
#  ('VBP DT NNS', 519),
#  ('JJ NN VBD', 517),
#  (', IN NN', 517),
#  ('VBP PRP IN', 516),
#  ('. VB PRP', 515),
#  ('NNP NN .', 513),
#  (', `` PRP', 513),
#  ('VBN IN NNS', 512),
#  ('CC NN NNS', 512),
#  ('NN VBZ VBG', 511),
#  ('NNS IN VBG', 510),
#  ('NNS , VBG', 508),
#  ('RB RB VB', 507),
#  ('VBN NN NN', 507),
#  ('VB NNS IN', 506),
#  ('VBZ IN NN', 503),
#  ('NNS WDT VBD', 503),
#  ('NNP , CC', 502),
#  ('CC VB DT', 500),
#  ('CC RB ,', 500),
#  ('PRP VBD NN', 498),
#  ('VB PRP DT', 497),
#  ('DT NNP NN', 495),
#  ('RB VB NN', 493),
#  ('PRP VB DT', 492),
#  ('NNS . JJ', 490),
#  ('NNS CC NN', 490),
#  ('DT IN PRP', 489),
#  ('. RB DT', 489),
#  ('VBP IN NN', 486),
#  ('IN NN VBZ', 483),
#  ('NN VBD VBN', 481),
#  ('MD VB TO', 481),
#  ('. EX VBZ', 480),
#  (', JJ NNS', 480),
#  ('VB CC VB', 480),
#  ('RB VB RB', 479),
#  ('DT NN HYPH', 479),
#  (', RB ,', 478),
#  ('NN WDT VBD', 477),
#  ('NN IN IN', 475),
#  ('VBG NN IN', 475),
#  ('NN -RRB- .', 475),
#  ('JJ . DT', 474),
#  ('VBZ RB VB', 469),
#  ('PRP VBD RP', 469),
#  ('RB PRP VBZ', 469),
#  ('VBD RB IN', 468),
#  ('DT JJ ,', 468),
#  ('DT VBZ WRB', 468),
#  ('DT VBZ WP', 468),
#  ('VBG JJ NN', 468),
#  ('NN VBD DT', 467),
#  ('NN . VBP', 465),
#  ('PRP VBD .', 465),
#  ('VBD RB VBN', 462),
#  ('CC RB IN', 461),
#  ('PRP VB IN', 461),
#  ('VB NN .', 461),
#  ('. FW FW', 461),
#  ('CC DT NNS', 460),
#  ('NN VBD IN', 457),
#  ('VB JJ TO', 457),
#  ('NNS RB .', 457),
#  ('RB VBD DT', 455),
#  (', WRB PRP', 455),
#  ('VBZ IN PRP', 454),
#  ('VBZ WP PRP', 454),
#  ('PDT DT NN', 454),
#  ('VBP RB IN', 453),
#  (', TO VB', 453),
#  ('RB VBN .', 453),
#  ('VBD JJ NN', 453),
#  ('JJ , PRP', 452),
#  ('IN VBG JJ', 451),
#  ('NN VBD RB', 450),
#  (', CC JJ', 449),
#  ('NN . NNS', 449),
#  ('PRP VB PRP', 448),
#  (', UH ,', 446),
#  ('NNS , NNS', 441),
#  ('NN RB ,', 441),
#  ('JJ NN PRP', 441),
#  ('DT MD VB', 440),
#  ('NN NN WDT', 440),
#  ('CD JJ NNS', 440),
#  ('RB RB JJ', 439),
#  ('JJ IN JJ', 438),
#  ('CC NN ,', 438),
#  ('CC NNS IN', 438),
#  ('VBG NNS IN', 437),
#  ('VBZ RB IN', 437),
#  ('VBP VBN TO', 435),
#  ('NN . WRB', 434),
#  ('DT NN VBN', 433),
#  ('PRP$ JJ NNS', 433),
#  ('PDT DT NNS', 433),
#  ('NN DT NN', 432),
#  ('RP . PRP', 432),
#  ('IN DT RB', 431),
#  ('IN IN PRP', 430),
#  ('VBP VBG DT', 429),
#  ('RB CD NNS', 428),
#  ('PRP$ NNS IN', 427),
#  ('WRB DT NN', 427),
#  ('VBN IN PRP', 426),
#  ('IN PRP CC', 426),
#  ('VBD PRP$ NN', 425),
#  ('TO VB CC', 425),
#  ('NN NNS WDT', 425),
#  ('VBP PRP VBZ', 425),
#  ('NN WRB PRP', 424),
#  ('PRP RB .', 424),
#  ('IN DT VBZ', 423),
#  ('NNP NNP VBZ', 422),
#  ('CC RB RB', 422),
#  (', VB PRP', 420),
#  ('DT VBZ JJ', 418),
#  ('CC VB PRP', 418),
#  ('VBG IN NN', 417),
#  ('VBZ WRB PRP', 416),
#  ('VBD RB RB', 416),
#  ('. NN NN', 416),
#  ('. RB RB', 415),
#  ('VBD PRP IN', 414),
#  ('IN NNS WDT', 414),
#  ('PRP VBP NNS', 412),
#  ('PRP IN PRP', 411),
#  ('PRP VBD CD', 410),
#  ('IN VBG NNS', 409),
#  ('VBG IN PRP', 409),
#  (". '' CC", 408),
#  (', RB JJ', 407),
#  ('DT CD NN', 406),
#  ('RB VBG IN', 406),
#  ('VBN JJ NN', 405),
#  ('UH . PRP', 404),
#  ('VBG JJ NNS', 403),
#  ('TO VB TO', 402),
#  ('NNS CC DT', 401),
#  ('VBZ NN IN', 400),
#  ('RB RB RB', 400),
#  ('VB JJ .', 398),
#  ('DT NNP NNPS', 396),
#  ('VB RP IN', 396),
#  ('VB IN PRP$', 394),
#  ('IN WP PRP', 394),
#  (', VBP PRP', 393),
#  ('VBG DT NNS', 393),
#  ('DT NN JJ', 392),
#  ('NN NN CD', 391),
#  ('NNS , JJ', 391),
#  ('PRP . DT', 390),
#  ('VB DT IN', 390),
#  ('HYPH NN NNS', 390),
#  ('IN DT JJS', 389),
#  ('. NNP ,', 389),
#  ('RB IN JJ', 388),
#  ('DT . CC', 387),
#  ('NNS RB ,', 386),
#  ('VBN VBN IN', 385),
#  ('VBZ PRP$ NN', 385),
#  ('VB VBN .', 385),
#  ('RB VBN DT', 383),
#  ('VB NN NN', 383),
#  ('JJ CD NNS', 383),
#  ('PRP VBP PRP$', 382),
#  ('VBZ RB VBG', 382),
#  ('DT NN POS', 381),
#  ('RP DT NN', 381),
#  ('TO RB VB', 380),
#  ('VB IN NNP', 379),
#  ('IN DT VBN', 377),
#  ('RB JJ TO', 377),
#  ('VB PRP RP', 377),
#  ('NN NN TO', 377),
#  ('CD NN NN', 377),
#  ('DT NN VBG', 376),
#  ('VBP JJ .', 376),
#  ('. NN IN', 376),
#  (', VBG DT', 375),
#  ('DT CD NNS', 375),
#  ('DT , PRP', 373),
#  ('MD VB .', 372),
#  ('PRP . RB', 372),
#  ('NNS CC JJ', 372),
#  ('RB VB JJ', 372),
#  ('NNS VBP VBG', 372),
#  ('VB , CC', 371),
#  ('NN CC IN', 370),
#  ('DT NN WRB', 370),
#  ('JJ NNS RB', 370),
#  ('NNS RB IN', 370),
#  ('VBG NN NN', 370),
#  ('IN VBG IN', 370),
#  ('NN CC VBD', 369),
#  ('VBD VBG IN', 369),
#  ('. NN VBZ', 368),
#  ('JJ NNS VBD', 368),
#  ('JJ JJ JJ', 367),
#  ('NN NN RB', 367),
#  (', VBG IN', 365),
#  ('JJ . RB', 365),
#  ('VBP VBN RB', 363),
#  ('RB CC VB', 363),
#  ('NN NNS VBD', 363),
#  ('NNS CC PRP', 362),
#  ('NNS , WDT', 362),
#  ('VBP VBN VBG', 360),
#  ('VBG . PRP', 359),
#  ('DT JJ .', 358),
#  ('IN NNS VBP', 357),
#  ('NN . VBG', 357),
#  (', RB DT', 356),
#  ('RB VB VBN', 355),
#  ('VB IN JJ', 353),
#  ('VBD IN NNP', 352),
#  ('CC VB IN', 352),
#  ('WDT VBZ DT', 351),
#  ('CC RB DT', 351),
#  ('. WRB PRP', 351),
#  ('VBD , PRP', 351),
#  ('DT RBS JJ', 350),
#  ('NNS VBD VBN', 350),
#  ('PRP$ NNS CC', 350),
#  ('VBP . PRP', 350),
#  ('CD NN .', 350),
#  ('VBD JJ IN', 350),
#  ('IN IN NN', 349),
#  ('VBP NN IN', 348),
#  ('UH , UH', 347),
#  ('DT NNS RB', 347),
#  ('`` PRP VBP', 346),
#  ('MD VB ,', 345),
#  ('WP VBZ VBG', 345),
#  ('IN NN HYPH', 344),
#  (', NNS ,', 344),
#  ('RB . UH', 344),
#  ('VB RB RB', 343),
#  ('NN -LRB- VB', 343),
#  ('VBG RP IN', 342),
#  ('VBN NNS IN', 340),
#  ('VBD PRP VB', 340),
#  ("'' PRP VBD", 340),
#  ('NNS JJ IN', 339),
#  ('VBD . PRP', 339),
#  ('VB RB JJ', 339),
#  ('NNS PRP VBP', 338),
#  ('NN , PRP$', 338),
#  ('JJ NNS TO', 337),
#  ('CD NN ,', 336),
#  ('VB . CC', 335),
#  ('VBP JJ NN', 335),
#  ('RB IN PRP$', 334),
#  (', CC VB', 334),
#  ('. NNP VBZ', 333),
#  ('JJ NN MD', 333),
#  ('VBZ JJ NN', 333),
#  ('IN PDT DT', 332),
#  ('VBG RB IN', 332),
#  ('TO VB VBG', 332),
#  ('RB VBD IN', 330),
#  (', UH .', 330),
#  ('VBD DT NNS', 329),
#  ('NNP . CC', 329),
#  ('NN , WRB', 329),
#  ('NNS VBD IN', 329),
#  ('RB VBG DT', 325),
#  ('VBP VBG RB', 325),
#  ('RB . IN', 324),
#  ('NN NN MD', 324),
#  ('WRB PRP VBZ', 323),
#  ('NNP , DT', 322),
#  ('JJ NN -LRB-', 322),
#  ('NNP POS NN', 321),
#  ('NNS WP VBP', 321),
#  ('JJS NN IN', 321),
#  ('VBD PRP .', 320),
#  ('VBD JJ .', 319),
#  ('VBP IN JJ', 318),
#  ('VBD NN IN', 318),
#  ('NN HYPH VBN', 318),
#  ('PRP VBZ NN', 317),
#  ('VB RB ,', 317),
#  ('NNP IN DT', 317),
#  ('VBP PRP$ NN', 316),
#  ('VBG RB .', 314),
#  ('JJ IN VBG', 314),
#  ('VBP VBN VBN', 314),
#  ('CC IN NN', 314),
#  ('NNP VBZ DT', 314),
#  ('CC RB VB', 313),
#  ('NNP VBZ VBN', 313),
#  ('VBG PRP$ NN', 312),
#  ('PRP VBP NNP', 312),
#  ('NN PRP MD', 310),
#  ('UH , DT', 310),
#  ('NNP NNP CC', 308),
#  ('DT JJR NN', 308),
#  ('NNP , IN', 308),
#  ('JJ NN VBN', 308),
#  ('PRP VBD PRP$', 307),
#  ('NN VBZ NN', 306),
#  ('IN RB .', 306),
#  ('NNS IN CD', 306),
#  ('CD JJ NN', 306),
#  ('FW VBD IN', 305),
#  ('JJ NNS MD', 304),
#  ('JJR IN DT', 304),
#  ('VBD PRP VBD', 304),
#  ('PRP VBP CD', 304),
#  ('IN NNP IN', 304),
#  ('DT NN WP', 303),
#  ('VB RP DT', 302),
#  ('NNS VBD RB', 302),
#  ('. VB IN', 302),
#  ('NN . PRP$', 301),
#  ('VBD JJ NNS', 301),
#  ('NN , CD', 300),
#  ('IN WRB PRP', 300),
#  ('NN . EX', 300),
#  ('RB VBP IN', 299),
#  ('JJ , RB', 299),
#  ('. NN ,', 298),
#  ('NN VBZ TO', 297),
#  (', EX VBZ', 297),
#  ('NN NNS RB', 296),
#  ('NNS IN RB', 296),
#  ('IN RB JJ', 296),
#  ('VBN NN NNS', 295),
#  ('CC NNS .', 294),
#  ('VBZ JJ ,', 294),
#  ('PRP , NNP', 294),
#  ('NNP NNP VBD', 293),
#  ('DT , CC', 293),
#  ('WDT VBZ VBN', 293),
#  ('VBN IN NNP', 292),
#  ('RB VBP DT', 292),
#  ('RB VB ,', 292),
#  ('RB VBN NN', 292),
#  ('VBP VBN JJ', 291),
#  ('VBP PRP VBG', 291),
#  ('VB WP PRP', 291),
#  ('NN HYPH JJ', 290),
#  ('NN , NNS', 290),
#  ('VBN , CC', 290),
#  ('. NNS VBP', 290),
#  ('JJR NN IN', 289),
#  ('PRP$ NN NNS', 289),
#  ('VB PRP$ JJ', 288),
#  ('PRP$ NN VBD', 287),
#  ('NN VBD JJ', 287),
#  ('RB IN VBG', 287),
#  ('JJ NNS VBN', 287),
#  ('IN CD ,', 285),
#  ('VB RB CC', 285),
#  ('VBN RB IN', 285),
#  ('. DT VBD', 285),
#  ('NN NN VBN', 284),
#  ('WRB VBP PRP', 284),
#  ('PRP . VBP', 284),
#  ('IN CD IN', 282),
#  (', CD NNS', 282),
#  ('NN , VBD', 282),
#  ('NNS , VB', 281),
#  ('PRP . UH', 281),
#  (', NN IN', 281),
#  ('RB CC PRP', 280),
#  ('PRP$ NN RB', 279),
#  ('IN NN TO', 279),
#  ('PRP RP .', 279),
#  ('VBN IN VBG', 278),
#  ('WDT VBP VBN', 277),
#  ('VBD IN JJ', 277),
#  ('VBP VBN .', 277),
#  ('UH , NNP', 277),
#  ('FW FW VB', 277),
#  ('DT NNS PRP', 276),
#  ('MD VB PRP$', 276),
#  ('NN NNP NNP', 276),
#  ('NNS VBD DT', 276),
#  ('VBN IN PRP$', 275),
#  ('NN CC VBG', 275),
#  ('EX VBZ RB', 274),
#  ('CD NN NNS', 274),
#  ('PRP VB .', 273),
#  ('-RRB- . DT', 273),
#  ('NN WDT MD', 272),
#  ('NN MD RB', 272),
#  ('VBD NNS IN', 272),
#  ('NNP . RB', 272),
#  ('DT NN DT', 271),
#  ('DT VBZ IN', 271),
#  ('VBN . CC', 271),
#  ('VBZ JJ TO', 271),
#  ('VBG NN NNS', 270),
#  ('PRP$ NNS VBP', 270),
#  ('DT JJS NNS', 270),
#  ('IN NN CD', 270),
#  ('NN WP VBZ', 269),
#  ('VB . DT', 269),
#  ('VBP PRP VBD', 269),
#  ('VBD CD NNS', 269),
#  ('VBP NNS IN', 269),
#  ('VBZ VBG IN', 269),
#  ('NN RB VBZ', 268),
#  ('CC WRB PRP', 268),
#  ('IN RB ,', 268),
#  ('WP DT NN', 268),
#  ('NN IN VBN', 268),
#  ('DT VBD DT', 268),
#  ('PRP IN NN', 267),
#  ('NN VBG IN', 267),
#  ('RB VBZ DT', 267),
#  ('RB , NN', 267),
#  ('. MD PRP', 267),
#  ('CC NNP NNP', 267),
#  ('VBD VBG TO', 267),
#  ('VBP RB .', 266),
#  ('RB VBP TO', 266),
#  ('IN JJ CC', 266),
#  ('WDT VBZ RB', 265),
#  ('DT . RB', 265),
#  ('NN JJ IN', 263),
#  ('NN , VBZ', 263),
#  (', CC NNS', 262),
#  ('VBN NN .', 262),
#  ('NNS CC VB', 261),
#  ('HYPH VBN NN', 261),
#  ('EX VBD DT', 261),
#  ('NNS WDT MD', 261),
#  ('IN PRP TO', 260),
#  ('IN NN RB', 260),
#  ('VBP JJ TO', 260),
#  ('CC NNS ,', 260),
#  ('VBP WP PRP', 260),
#  ('JJ IN NNS', 260),
#  ('NNP , RB', 259),
#  ('. VB ,', 259),
#  ('CD . PRP', 259),
#  (', JJ ,', 258),
#  ('. VBG DT', 258),
#  ('VB IN IN', 258),
#  ('NNP . DT', 258),
#  ('TO VB NNP', 258),
#  ('JJ . NNP', 257),
#  ('DT NNS MD', 257),
#  ('VB NN ,', 257),
#  ("'' CC PRP", 257),
#  (', VB DT', 256),
#  ('VBD RB VBG', 256),
#  ('NNS CC RB', 256),
#  ('VBD RB DT', 256),
#  ('VBP VBG PRP', 256),
#  ('NNS . NNS', 256),
#  ('HYPH JJ NN', 255),
#  ('VBN . DT', 255),
#  ('NN CC NNS', 255),
#  ('IN CD JJ', 255),
#  ('VBN JJ NNS', 255),
#  ('NN NNS VBN', 254),
#  ('WP PRP VBZ', 254),
#  ('WDT VBP RB', 253),
#  ('WDT PRP MD', 253),
#  ('VBZ VBN JJ', 253),
#  ('JJ . IN', 252),
#  ('VBN RB .', 252),
#  ('IN EX VBZ', 252),
#  ('VBG RB RB', 252),
#  ('RB , NNP', 252),
#  ('IN NN NNP', 252),
#  ('JJ IN PRP$', 251),
#  ('NNS RB RB', 251),
#  ('VBP RB ,', 250),
#  (', NNP NN', 250),
#  ('IN VBN NN', 249),
#  ('MD VB VBG', 248),
#  ('MD VB NNS', 248),
#  ('PRP RB ,', 248),
#  ('NN VBZ ,', 248),
#  ('RB RB VBN', 248),
#  ('NN . CD', 246),
#  ('VBP PRP MD', 246),
#  ('VB RP .', 246),
#  ('PRP VBZ .', 246),
#  ('POS NN .', 245),
#  ('VBG IN JJ', 245),
#  ('PRP CC PRP', 245),
#  ('WDT VBZ JJ', 245),
#  ('WDT VBP JJ', 245),
#  ('NN PRP VBZ', 244),
#  ('RB DT VBZ', 244),
#  ('PRP VBP VB', 244),
#  ('VBZ VBN TO', 244),
#  ('CD CC CD', 243),
#  ('VB . RB', 243),
#  ('DT JJ CC', 243),
#  ('NN NNS MD', 243),
#  ('NN CD -LRB-', 243),
#  (', IN PRP$', 242),
#  ('NNP VBZ RB', 241),
#  ('IN JJ NNP', 241),
#  ('VBZ VBN RB', 240),
#  ('NN CC PRP$', 240),
#  ('IN NN POS', 240),
#  ('RB IN CD', 239),
#  ('NN NNS TO', 238),
#  ...]

# %%
features = []
for el in functors_freq[:405]:
  features.append(el[0])

for el in bigram_freq[:100]:
  features.append(el[0])

for el in trigram_freq[:500]:
  features.append(el[0])

file = open("features.txt", "w")
for el in features:
  file.write(el + "\n")
file.close()

# %%
print("Number of features: ", len(features))
# Out:
# Number of features:  1005

# %% [markdown]
# ## Documents Vector Representation

# %%
import pandas as pd

# %%
feature_to_idx = {}
for idx,f in enumerate(features):
  feature_to_idx[f] = idx

# feature_to_idx = sorted(feature_to_idx.items(), key=lambda x:x[1])

# %%
political_matrix = np.zeros((len(political_out_docs),len(features)))

for idx,tup in enumerate(dataset_pos['politics']):
  for item in tup:
    for el in item:
      if el in feature_to_idx:
        political_matrix[idx,feature_to_idx[el]] += 1
      else:
        continue
  political_matrix[idx] /= len(tup[0])

# %%
save_pickle(political_matrix,"political_matrix.pickle")

# %%
pd.DataFrame(political_matrix)
# Out:
#         0         1         2     ...      1002      1003      1004
# 0   0.038089  0.030342  0.029051  ...  0.000000  0.000646  0.000000
# 1   0.037869  0.035188  0.021783  ...  0.001005  0.000000  0.000335
# 2   0.033373  0.026222  0.025030  ...  0.000000  0.000000  0.000000
# 3   0.052381  0.039683  0.028571  ...  0.000000  0.000000  0.000000
# 4   0.056511  0.049140  0.034398  ...  0.000000  0.002457  0.000000
# ..       ...       ...       ...  ...       ...       ...       ...
# 91  0.029950  0.023122  0.020174  ...  0.000543  0.000310  0.001319
# 92  0.042706  0.028388  0.029129  ...  0.001975  0.000987  0.000987
# 93  0.045840  0.034866  0.027643  ...  0.000695  0.000278  0.000278
# 94  0.028553  0.023647  0.021451  ...  0.000805  0.000439  0.001537
# 95  0.032103  0.025040  0.030337  ...  0.000321  0.000482  0.001284
#
# [96 rows x 1005 columns]

# %%
science_matrix = np.zeros((len(science_out_docs),len(features)))

for idx,tup in enumerate(dataset_pos['scientist']):
  for item in tup:
    for el in item:
      if el in feature_to_idx:
        science_matrix[idx,feature_to_idx[el]] += 1
      else:
        continue
  science_matrix[idx] /= len(tup[0])

# %%
pd.DataFrame(science_matrix)
# Out:
#          0         1         2         3     ...  1001  1002      1003  1004
# 0    0.042316  0.027283  0.021158  0.030067  ...   0.0   0.0  0.000000   0.0
# 1    0.046647  0.023810  0.016521  0.041788  ...   0.0   0.0  0.000000   0.0
# 2    0.039395  0.025653  0.018781  0.027485  ...   0.0   0.0  0.000000   0.0
# 3    0.045387  0.021214  0.024667  0.030587  ...   0.0   0.0  0.000000   0.0
# 4    0.043606  0.025928  0.020625  0.031821  ...   0.0   0.0  0.000000   0.0
# ..        ...       ...       ...       ...  ...   ...   ...       ...   ...
# 131  0.048432  0.027675  0.018450  0.036900  ...   0.0   0.0  0.000000   0.0
# 132  0.040966  0.021561  0.018542  0.029323  ...   0.0   0.0  0.000000   0.0
# 133  0.046289  0.026689  0.024187  0.031276  ...   0.0   0.0  0.000417   0.0
# 134  0.041041  0.026037  0.024713  0.030891  ...   0.0   0.0  0.000000   0.0
# 135  0.041702  0.025795  0.018917  0.031814  ...   0.0   0.0  0.000000   0.0
#
# [136 rows x 1005 columns]

# %%
sport_matrix = np.zeros((len(sport_out_docs),len(features)))

for idx,tup in enumerate(dataset_pos['sport']):
  for item in tup:
    for el in item:
      if el in feature_to_idx:
        sport_matrix[idx,feature_to_idx[el]] += 1
      else:
        continue
  sport_matrix[idx] /= len(tup[0])

# %%
pd.DataFrame(sport_matrix)
# Out:
#         0         1         2     ...      1002      1003      1004
# 0   0.032146  0.029625  0.036243  ...  0.000315  0.000000  0.000000
# 1   0.040748  0.026052  0.028724  ...  0.000000  0.000668  0.001336
# 2   0.038857  0.033143  0.029143  ...  0.000000  0.000000  0.000000
# 3   0.021056  0.014989  0.028194  ...  0.000714  0.000357  0.000357
# 4   0.048389  0.027401  0.035855  ...  0.000000  0.000292  0.000000
# ..       ...       ...       ...  ...       ...       ...       ...
# 90  0.035533  0.005076  0.025381  ...  0.000000  0.000000  0.000000
# 91  0.034207  0.034207  0.024616  ...  0.000000  0.000639  0.000320
# 92  0.022823  0.036630  0.025077  ...  0.000000  0.000564  0.000564
# 93  0.060150  0.045113  0.022556  ...  0.000000  0.000000  0.000000
# 94  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
#
# [95 rows x 1005 columns]

# %% [markdown]
# ## Dimensionality reduction

# %%
from sklearn.decomposition import PCA

NCOMPONENTS = 64

pca = PCA(n_components=NCOMPONENTS)
pca_pol = pca.fit_transform(political_matrix)
pca_science = pca.fit_transform(science_matrix)
pca_sport = pca.fit_transform(sport_matrix)

# %%
pca_pol.shape
# Out:
# (96, 64)

# %%
pca_science.shape
# Out:
# (136, 64)

# %%
pca_sport.shape
# Out:
# (95, 64)

# %% [markdown]
# ## Model

# %%
from sklearn import svm
from sklearn import metrics

# %%
final_dataset = {"featuers_name" : features, 
                 "target_names" : ["politician", "scientist","sport"]}

data = np.concatenate((pca_pol,pca_science,pca_sport))
final_dataset["data"] = data
target = np.concatenate((np.zeros(96, dtype=int),np.ones(136, dtype=int),np.full(shape=95,fill_value=2,dtype=np.int)))
final_dataset["target"] = target

# %%
save_pickle(final_dataset,"final_dataset.pickle")

# %%
X_train, X_test, y_train, y_test = train_test_split(final_dataset["data"], final_dataset["target"], test_size=0.3)

# %%
#Create a svm Classifier
clf = svm.SVC(decision_function_shape='ovr',break_ties=True) # Linear Kernel
 
#Train the model using the training sets
clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
unique, counts = np.unique(y_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0: 67, 1: 93, 2: 68}

# %%
unique, counts = np.unique(y_test, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0: 29, 1: 43, 2: 27}

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(y_test, y_pred, average='weighted'))
# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(y_test, y_pred, average='weighted'))
print("F1-Score:",metrics.f1_score(y_test, y_pred, average='weighted'))
# Out:
# Accuracy: 0.7070707070707071
# Precision: 0.6947250280583613
# Recall: 0.7070707070707071
# F1-Score: 0.6873295357612094

# %%
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt

fig = plt.figure()
# Generate confusion matrix
matrix = plot_confusion_matrix(clf, X_test, y_test,
                                 cmap=plt.cm.Blues,
                                 normalize='true')
plt.title('Confusion matrix for our classifier')
plt.savefig("confusion_matrix.png", dpi=199)
plt.show(matrix)
plt.show()
